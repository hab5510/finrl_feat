# %% [markdown]
# <a href="https://colab.research.google.com/github/hab5510/finrl_project/blob/main/FinRL_without_SentimentAnalysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Deep Reinforcement Learning for Stock Trading with Sentiment Analysis, Multiple Stock Trading
#
# * **Pytorch Version**

# %% [markdown]
# # Content

# %% [markdown]
# * [1. Task Description](#0)
# * [2. Install Python packages](#1)
#     * [2.1. Install Packages](#1.1)
#     * [2.2. A List of Python Packages](#1.2)
#     * [2.3. Import Packages](#1.3)
#     * [2.4. Create Folders](#1.4)
# * [3. Download and Preprocess Data](#2)
# * [4. Preprocess Data](#3)
#     * [4.1. Technical Indicators](#3.1)
#     * [4.2. Perform Feature Engineering](#3.2)
# * [5. Build Market Environment in OpenAI Gym-style](#4)
#     * [5.1. Data Split](#4.1)
#     * [5.3. Environment for Training](#4.2)
# * [6. Train DRL Agents](#5)
# * [7. Backtesting Performance](#6)
#     * [7.1. BackTestStats](#6.1)
#     * [7.2. BackTestPlot](#6.2)

# %% [markdown]
# <a id='0'></a>
# # Part 1. Task Discription

# %% [markdown]
# We train a DRL agent for stock trading. This task is modeled as a Markov Decision Process (MDP), and the objective function is maximizing (expected) cumulative return.
#
# We specify the state-action-reward as follows:
#
# * **State s**: The state space represents an agent's perception of the market environment. Just like a human trader analyzing various information, here our agent passively observes many features and learns by interacting with the market environment (usually by replaying historical data).
#
# * **Action a**: The action space includes allowed actions that an agent can take at each state. For example, a ∈ {−1, 0, 1}, where −1, 0, 1 represent
# selling, holding, and buying. When an action operates multiple shares, a ∈{−k, ..., −1, 0, 1, ..., k}, e.g.. "Buy
# 10 shares of AAPL" or "Sell 10 shares of AAPL" are 10 or −10, respectively
#
# * **Reward function r(s, a, s′)**: Reward is an incentive for an agent to learn a better policy. For example, it can be the change of the portfolio value when taking a at state s and arriving at new state s',  i.e., r(s, a, s′) = v′ − v, where v′ and v represent the portfolio values at state s′ and s, respectively
#
#
# **Market environment**: 30 consituent stocks of Dow Jones Industrial Average (DJIA) index. Accessed at the starting date of the testing period.
#
#
# The data for this case study is obtained from Yahoo Finance API. The data contains Open-High-Low-Close price and volume.

# %% [markdown]
# <a id='1.1'></a>
# ## 2.1. Install packages

# %%
# !pip install numpy==1.26.4 --force-reinstall

# %%
# !pip install --upgrade pip

# !pip install torch==2.2.2 torchvision==0.17.2 torchaudio==2.2.2 --extra-index-url https://download.pytorch.org/whl/cpu
# !pip install stable-baselines3==2.2.1 sb3-contrib==2.2.1 gymnasium==0.29.1

# !pip install git+https://github.com/AI4Finance-Foundation/FinRL.git

# !pip install transformers==4.41.0 tokenizers==0.19.1 huggingface-hub==0.28.1

# %% [markdown]
# <a id='1.2'></a>
# ## 2.2. A list of Python packages
# * Yahoo Finance API
# * pandas
# * numpy
# * matplotlib
# * stockstats
# * OpenAI gym
# * stable-baselines
# * tensorflow
# * pyfolio

# %% [markdown]
# <a id='1.3'></a>
# ## 2.3. Import Packages

# %%
# !pip install pandas_market_calendars

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# matplotlib.use('Agg')
import datetime

# %matplotlib inline
from finrl.meta.preprocessor.yahoodownloader import YahooDownloader
from finrl.meta.preprocessor.preprocessors import FeatureEngineer, data_split
from finrl.meta.env_stock_trading.env_stocktrading import StockTradingEnv
from finrl.agents.stablebaselines3.models import DRLAgent
from stable_baselines3.common.logger import configure
from finrl.meta.data_processor import DataProcessor

from finrl.plot import backtest_stats, backtest_plot, get_daily_return, get_baseline
from pprint import pprint

import sys
sys.path.append("../FinRL")

import itertools
# Out:
# /usr/local/lib/python3.11/dist-packages/pandas_datareader/compat/__init__.py:11: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   PANDAS_VERSION = LooseVersion(pd.__version__)
# /usr/local/lib/python3.11/dist-packages/pyfolio/pos.py:25: UserWarning: Module "zipline.assets" not found; multipliers will not be applied to position notionals.
#   warnings.warn(

# %% [markdown]
# <a id='1.4'></a>
# ## 2.4. Create Folders

# %%
from finrl import config
from finrl import config_tickers
import os
from finrl.main import check_and_make_directories
from finrl.config import (
    DATA_SAVE_DIR,
    TRAINED_MODEL_DIR,
    TENSORBOARD_LOG_DIR,
    RESULTS_DIR,
    INDICATORS,
    TRAIN_START_DATE,
    TRAIN_END_DATE,
    TEST_START_DATE,
    TEST_END_DATE,
    TRADE_START_DATE,
    TRADE_END_DATE,
)
check_and_make_directories([DATA_SAVE_DIR, TRAINED_MODEL_DIR, TENSORBOARD_LOG_DIR, RESULTS_DIR])

# %% [markdown]
# <a id='2'></a>
# # Part 3. Download Data
# Yahoo Finance provides stock data, financial news, financial reports, etc. Yahoo Finance is free.
# * FinRL uses a class **YahooDownloader** in FinRL-Meta to fetch data via Yahoo Finance API
# * Call Limit: Using the Public API (without authentication), you are limited to 2,000 requests per hour per IP (or up to a total of 48,000 requests a day).

# %% [markdown]
# -----
# class YahooDownloader:
#     Retrieving daily stock data from
#     Yahoo Finance API
#
#     Attributes
#     ----------
#         start_date : str
#             start date of the data (modified from config.py)
#         end_date : str
#             end date of the data (modified from config.py)
#         ticker_list : list
#             a list of stock tickers (modified from config.py)
#
#     Methods
#     -------
#     fetch_data()

# %%
TRAIN_START_DATE = '2020-01-01'
TRAIN_END_DATE = '2023-01-01'
TRADE_START_DATE = '2023-01-01'
TRADE_END_DATE = '2023-12-31'

# %%
top10_tickers = ['AAPL','MSFT','AMZN','GOOGL','META',
                 'NVDA','JPM','TSLA','BA','DIS']

df = YahooDownloader(start_date = TRAIN_START_DATE,
                     end_date = TRADE_END_DATE,
                     ticker_list = top10_tickers).fetch_data()
# Out:
# YF deprecation warning: set proxy via new config function: yf.set_config(proxy=proxy)
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (10060, 8)

# %%
df.shape
# Out:
# (10060, 8)

# %%
df.sort_values(['date','tic'],ignore_index=True).head()
# Out:
# Price        date       close        high         low        open     volume  \
# 0      2020-01-02   72.620842   72.681289   71.373218   71.627092  135480400
# 1      2020-01-02   94.900497   94.900497   93.207497   93.750000   80580000
# 2      2020-01-02  331.348572  331.378393  325.761816  326.606765    4544400
# 3      2020-01-02  145.769897  145.769897  142.720739  142.907610    9502100
# 4      2020-01-02   68.026016   68.026016   66.923134   67.018562   27278000
#
# Price    tic  day
# 0       AAPL    3
# 1       AMZN    3
# 2         BA    3
# 3        DIS    3
# 4      GOOGL    3

# %% [markdown]
# # Part 4: Preprocess Data
# We need to check for missing data and do feature engineering to convert the data point into a state.
# * **Adding technical indicators**. In practical trading, various information needs to be taken into account, such as historical prices, current holding shares, technical indicators, etc. Here, we demonstrate two trend-following technical indicators: MACD and RSI.
# * **Adding turbulence index**. Risk-aversion reflects whether an investor prefers to protect the capital. It also influences one's trading strategy when facing different market volatility level. To control the risk in a worst-case scenario, such as financial crisis of 2007–2008, FinRL employs the turbulence index that measures extreme fluctuation of asset price.

# %%
fe = FeatureEngineer(
                    use_technical_indicator=True,
                    tech_indicator_list = INDICATORS,
                    use_vix=True,
                    use_turbulence=True,
                    user_defined_feature = False)

processed = fe.preprocess_data(df)
# Out:
# Successfully added technical indicators
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (1005, 8)
# Successfully added vix
# Successfully added turbulence index

# %%
# build processed_full so the RL environment sees every (date, ticker)
list_ticker = processed["tic"].unique().tolist()
list_date   = list(pd.date_range(processed['date'].min(),
                                 processed['date'].max()).astype(str))
combination = list(itertools.product(list_date, list_ticker))

processed_full = (
    pd.DataFrame(combination, columns=["date", "tic"])
      .merge(processed, on=["date", "tic"], how="left")
)
processed_full = processed_full[processed_full['date'].isin(processed['date'])]
processed_full = processed_full.sort_values(['date', 'tic'])
processed_full = processed_full.fillna(0)

# %%
processed_full.to_csv("processed_full_noSA.csv", index=False)

# %% [markdown]
# <a id='4'></a>
# # Part 5. Build A Market Environment in OpenAI Gym-style
# The training process involves observing stock price change, taking an action and reward's calculation. By interacting with the market environment, the agent will eventually derive a trading strategy that may maximize (expected) rewards.
#
# Our market environment, based on OpenAI Gym, simulates stock markets with historical market data.

# %% [markdown]
# ## Data Split
# We split the data into training set and testing set as follows:
#
# Training data period: 2009-01-01 to 2020-07-01
#
# Trading data period: 2020-07-01 to 2021-10-31

# %%
INDICATORS =[
    'macd', 'boll_ub', 'boll_lb', 'rsi_30', 'cci_30', 'dx_30',
    'close_30_sma', 'close_60_sma', 'vix', 'turbulence'
]

# %%
# Keep only the valid columns

VALID_COLUMNS = ['date', 'tic', 'open', 'high', 'low', 'close', 'volume','day'] + INDICATORS
processed_full = pd.read_csv("processed_full_noSA.csv")
processed_full = processed_full[VALID_COLUMNS]
processed_full.dropna(inplace=True)

# %%
processed_full.sort_values(['date','tic'],ignore_index=True).head(20)
# Out:
#           date    tic        open        high         low       close  \
# 0   2020-01-02   AAPL   71.627092   72.681289   71.373218   72.620842
# 1   2020-01-02   AMZN   93.750000   94.900497   93.207497   94.900497
# 2   2020-01-02     BA  326.606765  331.378393  325.761816  331.348572
# 3   2020-01-02    DIS  142.907610  145.769897  142.720739  145.769897
# 4   2020-01-02  GOOGL   67.018562   68.026016   66.923134   68.026016
# 5   2020-01-02    JPM  119.621127  120.742132  119.167597  120.733566
# 6   2020-01-02   META  205.621940  208.645346  205.144563  208.635406
# 7   2020-01-02   MSFT  151.289093  153.147093  150.860326  153.042282
# 8   2020-01-02   NVDA    5.942871    5.971745    5.892342    5.971745
# 9   2020-01-02   TSLA   28.299999   28.713333   28.114000   28.684000
# 10  2020-01-03   AAPL   71.847102   72.676431   71.689942   71.914803
# 11  2020-01-03   AMZN   93.224998   94.309998   93.224998   93.748497
# 12  2020-01-03     BA  328.674494  332.909308  328.346428  330.791901
# 13  2020-01-03    DIS  143.999412  145.474816  143.655160  144.097778
# 14  2020-01-03  GOOGL   66.998193   68.278016   66.964392   67.670158
# 15  2020-01-03    JPM  118.416873  119.906769  118.055165  119.140289
# 16  2020-01-03   META  206.079438  209.252020  205.820847  207.531464
# 17  2020-01-03   MSFT  150.850823  152.403913  150.603080  151.136658
# 18  2020-01-03   NVDA    5.852018    5.919972    5.827126    5.876163
# 19  2020-01-03   TSLA   29.366667   30.266666   29.128000   29.534000
#
#          volume  day      macd     boll_ub     boll_lb  rsi_30     cci_30  \
# 0   135480400.0  3.0  0.000000   73.266313   71.269332     0.0 -66.666667
# 1    80580000.0  3.0  0.000000   73.266313   71.269332     0.0 -66.666667
# 2     4544400.0  3.0  0.000000   73.266313   71.269332     0.0 -66.666667
# 3     9502100.0  3.0  0.000000   73.266313   71.269332     0.0 -66.666667
# 4    27278000.0  3.0  0.000000   73.266313   71.269332     0.0 -66.666667
# 5    10803700.0  3.0  0.000000   73.266313   71.269332     0.0 -66.666667
# 6    12077100.0  3.0  0.000000   73.266313   71.269332     0.0 -66.666667
# 7    22622100.0  3.0  0.000000   73.266313   71.269332     0.0 -66.666667
# 8   237536000.0  3.0  0.000000   73.266313   71.269332     0.0 -66.666667
# 9   142981500.0  3.0  0.000000   73.266313   71.269332     0.0 -66.666667
# 10  146322800.0  4.0 -0.015841   73.266313   71.269332     0.0 -66.666667
# 11   75288000.0  4.0 -0.025846   95.953672   92.695323     0.0 -66.666667
# 12    3875900.0  4.0 -0.012489  331.857488  330.282984     0.0  66.666667
# 13    7320200.0  4.0 -0.037515  147.298571  142.569104     0.0 -66.666667
# 14   23408000.0  4.0 -0.007984   68.351346   67.344828     0.0 -66.666667
# 15   10386800.0  4.0 -0.035747  122.190162  117.683694     0.0 -66.666667
# 16   11188400.0  4.0 -0.024768  209.644646  206.522224     0.0  66.666667
# 17   21116200.0  4.0 -0.042754  154.784430  149.394510     0.0 -66.666667
# 18  205384000.0  4.0 -0.002144    6.059129    5.788779     0.0 -66.666667
# 19  266677500.0  4.0  0.019071   30.311082   27.906918   100.0  66.666667
#
#     dx_30  close_30_sma  close_60_sma    vix  turbulence
# 0   100.0     72.620842     72.620842  12.47         0.0
# 1   100.0     94.900497     94.900497  12.47         0.0
# 2   100.0    331.348572    331.348572  12.47         0.0
# 3   100.0    145.769897    145.769897  12.47         0.0
# 4   100.0     68.026016     68.026016  12.47         0.0
# 5   100.0    120.733566    120.733566  12.47         0.0
# 6   100.0    208.635406    208.635406  12.47         0.0
# 7   100.0    153.042282    153.042282  12.47         0.0
# 8   100.0      5.971745      5.971745  12.47         0.0
# 9   100.0     28.684000     28.684000  12.47         0.0
# 10  100.0     72.267822     72.267822  14.02         0.0
# 11  100.0     94.324497     94.324497  14.02         0.0
# 12  100.0    331.070236    331.070236  14.02         0.0
# 13  100.0    144.933838    144.933838  14.02         0.0
# 14  100.0     67.848087     67.848087  14.02         0.0
# 15  100.0    119.936928    119.936928  14.02         0.0
# 16  100.0    208.083435    208.083435  14.02         0.0
# 17  100.0    152.089470    152.089470  14.02         0.0
# 18  100.0      5.923954      5.923954  14.02         0.0
# 19  100.0     29.109000     29.109000  14.02         0.0

# %%
train = data_split(processed_full, TRAIN_START_DATE,TRAIN_END_DATE)
trade = data_split(processed_full, TRADE_START_DATE,TRADE_END_DATE)
print(len(train))
print(len(trade))
# Out:
# 7560
# 2490

# %%
train.tail()
# Out:
#            date   tic        open        high         low       close  \
# 755  2022-12-30   JPM  124.543641  125.969037  124.196675  125.753357
# 755  2022-12-30  META  117.515312  119.762976  117.097598  119.683411
# 755  2022-12-30  MSFT  233.466236  235.181386  231.947100  235.044174
# 755  2022-12-30  NVDA   14.321269   14.616007   14.220359   14.601021
# 755  2022-12-30  TSLA  119.949997  124.480003  119.750000  123.180000
#
#           volume  day       macd     boll_ub     boll_lb     rsi_30  \
# 755    9292500.0  4.0   0.423462  126.849696  120.917199  57.144000
# 755   19583800.0  4.0   0.952232  122.984846  111.411246  49.419035
# 755   21938500.0  4.0  -1.366763  253.270820  227.343636  48.258156
# 755  310490000.0  4.0  -0.309794   18.503089   13.800796  47.045441
# 755  157777300.0  4.0 -19.258998  202.513339   99.254662  32.790586
#
#          cci_30      dx_30  close_30_sma  close_60_sma    vix  turbulence
# 755   20.442540  11.345756    124.882473    119.589299  21.67     0.76624
# 755   78.427333   9.186721    115.435051    115.697444  21.67     0.76624
# 755  -86.505050   5.313302    240.472864    234.587170  21.67     0.76624
# 755 -141.558985  13.239317     16.120590     14.735053  21.67     0.76624
# 755 -121.998583  47.953532    161.267667    186.598834  21.67     0.76624

# %%
trade.head()
# Out:
#          date    tic        open        high         low       close  \
# 0  2023-01-03   AAPL  128.613993  129.226060  122.582127  123.470619
# 0  2023-01-03   AMZN   85.459999   86.959999   84.209999   85.820000
# 0  2023-01-03     BA  192.949997  197.179993  192.399994  195.389999
# 0  2023-01-03    DIS   87.520969   88.494734   86.389825   87.511131
# 0  2023-01-03  GOOGL   89.055899   90.507201   87.992278   88.588707
#
#         volume  day      macd     boll_ub     boll_lb     rsi_30      cci_30  \
# 0  112117500.0  1.0 -4.648600  147.860278  121.091834  39.011486 -130.963503
# 0   76706000.0  1.0 -3.075118   93.357149   80.929850  41.195599  -71.360174
# 0    8624600.0  1.0  5.326285  196.702727  176.154272  62.905353  141.206999
# 0   14997100.0  1.0 -2.395931   95.452679   81.433501  44.489016  -57.420614
# 0   28131200.0  1.0 -2.129974   98.089503   83.452725  43.976965  -67.730747
#
#        dx_30  close_30_sma  close_60_sma   vix  turbulence
# 0  35.956364    138.293932    140.567284  22.9   29.954546
# 0  10.198927     89.424999     97.181000  22.9   29.954546
# 0  44.456630    182.859667    166.269167  22.9   29.954546
# 0   3.756592     90.752425     93.693724  22.9   29.954546
# 0   2.932386     92.974731     93.988817  22.9   29.954546

# %%
stock_dimension = len(train.tic.unique())
state_space = 1 + 2*stock_dimension + len(INDICATORS)*stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")
# Out:
# Stock Dimension: 10, State Space: 121

# %%
from finrl.meta.env_stock_trading.env_stocktrading import StockTradingEnv
import numpy as np

EXPECTED_STATE_DIM = state_space

def force_fixed_state(obs):
    obs = np.asarray(obs, dtype=np.float32).flatten()
    if obs.shape[0] != EXPECTED_STATE_DIM:
        print(f"Auto-fixing bad obs shape {obs.shape[0]} → {EXPECTED_STATE_DIM}")
        if obs.shape[0] < EXPECTED_STATE_DIM:
            # Pad with zeros
            obs = np.pad(obs, (0, EXPECTED_STATE_DIM - obs.shape[0]), mode='constant')
        else:
            # Truncate
            obs = obs[:EXPECTED_STATE_DIM]
    return obs.reshape(1, -1)


class PatchedStockTradingEnv(StockTradingEnv):
    def reset(self, *, seed=None, options=None):
        obs, info = super().reset(seed=seed, options=options)
        obs = force_fixed_state(obs)
        return obs, info

    def step(self, action):
        obs, reward, terminated, truncated, info = super().step(action)
        obs = force_fixed_state(obs)
        return obs, reward, terminated, truncated, info

# %%
buy_cost_list = sell_cost_list = [0.001] * stock_dimension
num_stock_shares = [0] * stock_dimension

env_kwargs = {
    "hmax": 100,
    "initial_amount": 1000000,
    "num_stock_shares": num_stock_shares,
    "buy_cost_pct": buy_cost_list,
    "sell_cost_pct": sell_cost_list,
    "state_space": state_space,
    "stock_dim": stock_dimension,
    "tech_indicator_list": INDICATORS,
    "action_space": stock_dimension,
    "reward_scaling": 1e-4
}

from stable_baselines3.common.vec_env import DummyVecEnv

env_train = DummyVecEnv([lambda: PatchedStockTradingEnv(df=train, **env_kwargs)])

# %% [markdown]
# ## Environment for Training

# %%
obs = env_train.reset()
print("obs shape:", obs.shape, "dtype:", obs.dtype)

action = np.zeros(stock_dimension)
obs, reward, done, info = env_train.step(action)
print("step shape:", obs.shape, "dtype:", obs.dtype)
# Out:
# obs shape: (1, 121) dtype: float32
# step shape: (1, 121) dtype: float32
# /usr/local/lib/python3.11/dist-packages/finrl/meta/env_stock_trading/env_stocktrading.py:328: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   sell_index = argsort_actions[: np.where(actions < 0)[0].shape[0]]

# %%
obs = env_train.reset()
print("Training reset shape:", obs.shape, obs.dtype)

obs, reward, done, info = env_train.step(np.zeros(stock_dimension))
print("Training step shape:", obs.shape, obs.dtype)
# Out:
# Training reset shape: (1, 121) float32
# Training step shape: (1, 121) float32

# %% [markdown]
# <a id='5'></a>
# # Part 6: Train  DRL Agents
# * The DRL algorithms are from **Stable Baselines 3**.
# * FinRL includes fine-tuned standard DRL algorithms, such as DQN, DDPG, Multi-Agent DDPG, PPO, SAC, A2C and TD3.

# %% [markdown]
# ### Agent Training: 3 algorithms (A2C,PPO, TD3)

# %% [markdown]
# ### Agent 1: A2C

# %%
agent = DRLAgent(env = env_train)
model_a2c = agent.get_model("a2c")


# set up logger
tmp_path = RESULTS_DIR + '/a2c'
new_logger_a2c = configure(tmp_path, ["stdout", "csv", "tensorboard"])
# Set new logger
model_a2c.set_logger(new_logger_a2c)
# Out:
# {'n_steps': 5, 'ent_coef': 0.01, 'learning_rate': 0.0007}
# Using cpu device
# Logging to results/a2c

# %%
print(repr(env_train.reset()))
# Out:
# array([[ 1.0000000e+06,  7.2620842e+01,  9.4900497e+01,  3.3134857e+02,
#          1.4576990e+02,  6.8026016e+01,  1.2073357e+02,  2.0863541e+02,
#          1.5304228e+02,  5.9717455e+00,  2.8684000e+01,  0.0000000e+00,
#          0.0000000e+00,  0.0000000e+00,  0.0000000e+00,  0.0000000e+00,
#          0.0000000e+00,  0.0000000e+00,  0.0000000e+00,  0.0000000e+00,
#          0.0000000e+00,  0.0000000e+00,  0.0000000e+00,  0.0000000e+00,
#          0.0000000e+00,  0.0000000e+00,  0.0000000e+00,  0.0000000e+00,
#          0.0000000e+00,  0.0000000e+00,  0.0000000e+00,  7.3266312e+01,
#          7.3266312e+01,  7.3266312e+01,  7.3266312e+01,  7.3266312e+01,
#          7.3266312e+01,  7.3266312e+01,  7.3266312e+01,  7.3266312e+01,
#          7.3266312e+01,  7.1269333e+01,  7.1269333e+01,  7.1269333e+01,
#          7.1269333e+01,  7.1269333e+01,  7.1269333e+01,  7.1269333e+01,
#          7.1269333e+01,  7.1269333e+01,  7.1269333e+01,  0.0000000e+00,
#          0.0000000e+00,  0.0000000e+00,  0.0000000e+00,  0.0000000e+00,
#          0.0000000e+00,  0.0000000e+00,  0.0000000e+00,  0.0000000e+00,
#          0.0000000e+00, -6.6666664e+01, -6.6666664e+01, -6.6666664e+01,
#         -6.6666664e+01, -6.6666664e+01, -6.6666664e+01, -6.6666664e+01,
#         -6.6666664e+01, -6.6666664e+01, -6.6666664e+01,  1.0000000e+02,
#          1.0000000e+02,  1.0000000e+02,  1.0000000e+02,  1.0000000e+02,
#          1.0000000e+02,  1.0000000e+02,  1.0000000e+02,  1.0000000e+02,
#          1.0000000e+02,  7.2620842e+01,  9.4900497e+01,  3.3134857e+02,
#          1.4576990e+02,  6.8026016e+01,  1.2073357e+02,  2.0863541e+02,
#          1.5304228e+02,  5.9717455e+00,  2.8684000e+01,  7.2620842e+01,
#          9.4900497e+01,  3.3134857e+02,  1.4576990e+02,  6.8026016e+01,
#          1.2073357e+02,  2.0863541e+02,  1.5304228e+02,  5.9717455e+00,
#          2.8684000e+01,  1.2470000e+01,  1.2470000e+01,  1.2470000e+01,
#          1.2470000e+01,  1.2470000e+01,  1.2470000e+01,  1.2470000e+01,
#          1.2470000e+01,  1.2470000e+01,  1.2470000e+01,  0.0000000e+00,
#          0.0000000e+00,  0.0000000e+00,  0.0000000e+00,  0.0000000e+00,
#          0.0000000e+00,  0.0000000e+00,  0.0000000e+00,  0.0000000e+00,
#          0.0000000e+00]], dtype=float32)

# %%
trained_a2c  = agent.train_model(model=model_a2c,
                             tb_log_name='a2c',
                             total_timesteps=50000)
# Out:
# --------------------------------------
# | time/                 |            |
# |    fps                | 239        |
# |    iterations         | 100        |
# |    time_elapsed       | 2          |
# |    total_timesteps    | 500        |
# | train/                |            |
# |    entropy_loss       | -14.3      |
# |    explained_variance | -0.0607    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 99         |
# |    policy_loss        | -164       |
# |    reward             | 7.881215   |
# |    reward_max         | 17.285742  |
# |    reward_mean        | 8.405773   |
# |    reward_min         | -8.0888405 |
# |    std                | 1.01       |
# |    value_loss         | 195        |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 245        |
# |    iterations         | 200        |
# |    time_elapsed       | 4          |
# |    total_timesteps    | 1000       |
# | train/                |            |
# |    entropy_loss       | -14.3      |
# |    explained_variance | -0.00184   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 199        |
# |    policy_loss        | -44.3      |
# |    reward             | 8.739731   |
# |    reward_max         | 8.739731   |
# |    reward_mean        | 3.7478771  |
# |    reward_min         | -2.6298292 |
# |    std                | 1.01       |
# |    value_loss         | 38.4       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 246        |
# |    iterations         | 300        |
# |    time_elapsed       | 6          |
# |    total_timesteps    | 1500       |
# | train/                |            |
# |    entropy_loss       | -14.3      |
# |    explained_variance | -0.0396    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 299        |
# |    policy_loss        | -187       |
# |    reward             | -3.379529  |
# |    reward_max         | 4.369237   |
# |    reward_mean        | -2.1254086 |
# |    reward_min         | -7.445912  |
# |    std                | 1.01       |
# |    value_loss         | 238        |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 223        |
# |    iterations         | 400        |
# |    time_elapsed       | 8          |
# |    total_timesteps    | 2000       |
# | train/                |            |
# |    entropy_loss       | -14.3      |
# |    explained_variance | 0.0754     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 399        |
# |    policy_loss        | -105       |
# |    reward             | 1.329464   |
# |    reward_max         | 7.7573504  |
# |    reward_mean        | 0.45233995 |
# |    reward_min         | -9.289348  |
# |    std                | 1.01       |
# |    value_loss         | 60.3       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 229        |
# |    iterations         | 500        |
# |    time_elapsed       | 10         |
# |    total_timesteps    | 2500       |
# | train/                |            |
# |    entropy_loss       | -14.3      |
# |    explained_variance | 0.00618    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 499        |
# |    policy_loss        | 179        |
# |    reward             | -1.8809721 |
# |    reward_max         | 4.193227   |
# |    reward_mean        | 0.7407298  |
# |    reward_min         | -4.2025747 |
# |    std                | 1.01       |
# |    value_loss         | 171        |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 233        |
# |    iterations         | 600        |
# |    time_elapsed       | 12         |
# |    total_timesteps    | 3000       |
# | train/                |            |
# |    entropy_loss       | -14.3      |
# |    explained_variance | -0.117     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 599        |
# |    policy_loss        | -78.5      |
# |    reward             | -2.7869058 |
# |    reward_max         | 6.077719   |
# |    reward_mean        | 0.15175572 |
# |    reward_min         | -4.605744  |
# |    std                | 1.01       |
# |    value_loss         | 23.4       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 236        |
# |    iterations         | 700        |
# |    time_elapsed       | 14         |
# |    total_timesteps    | 3500       |
# | train/                |            |
# |    entropy_loss       | -14.3      |
# |    explained_variance | 0.0217     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 699        |
# |    policy_loss        | -54.4      |
# |    reward             | 3.2783031  |
# |    reward_max         | 3.2783031  |
# |    reward_mean        | 1.9617217  |
# |    reward_min         | -1.3655562 |
# |    std                | 1.02       |
# |    value_loss         | 39.7       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 237        |
# |    iterations         | 800        |
# |    time_elapsed       | 16         |
# |    total_timesteps    | 4000       |
# | train/                |            |
# |    entropy_loss       | -14.3      |
# |    explained_variance | -0.0105    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 799        |
# |    policy_loss        | 110        |
# |    reward             | 0.8986589  |
# |    reward_max         | 2.4250994  |
# |    reward_mean        | -0.6927678 |
# |    reward_min         | -3.6789727 |
# |    std                | 1.01       |
# |    value_loss         | 86.4       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 216        |
# |    iterations         | 900        |
# |    time_elapsed       | 20         |
# |    total_timesteps    | 4500       |
# | train/                |            |
# |    entropy_loss       | -14.3      |
# |    explained_variance | 0.308      |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 899        |
# |    policy_loss        | -109       |
# |    reward             | -3.2743971 |
# |    reward_max         | 4.1114025  |
# |    reward_mean        | -0.2266989 |
# |    reward_min         | -4.424524  |
# |    std                | 1.02       |
# |    value_loss         | 85.3       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 209        |
# |    iterations         | 1000       |
# |    time_elapsed       | 23         |
# |    total_timesteps    | 5000       |
# | train/                |            |
# |    entropy_loss       | -14.4      |
# |    explained_variance | -0.00302   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 999        |
# |    policy_loss        | 194        |
# |    reward             | 4.651689   |
# |    reward_max         | 5.6663303  |
# |    reward_mean        | 3.3243291  |
# |    reward_min         | -0.5913983 |
# |    std                | 1.02       |
# |    value_loss         | 227        |
# --------------------------------------
# day: 755, episode: 10
# begin_total_asset: 1000000.00
# end_total_asset: 1478564.93
# total_reward: 478564.93
# total_cost: 49056.89
# total_trades: 6663
# Sharpe: 0.549
# =================================
# --------------------------------------
# | time/                 |            |
# |    fps                | 212        |
# |    iterations         | 1100       |
# |    time_elapsed       | 25         |
# |    total_timesteps    | 5500       |
# | train/                |            |
# |    entropy_loss       | -14.3      |
# |    explained_variance | -0.155     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1099       |
# |    policy_loss        | -25.4      |
# |    reward             | -6.101798  |
# |    reward_max         | 1.5003493  |
# |    reward_mean        | -1.2168813 |
# |    reward_min         | -6.101798  |
# |    std                | 1.02       |
# |    value_loss         | 5.74       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 216        |
# |    iterations         | 1200       |
# |    time_elapsed       | 27         |
# |    total_timesteps    | 6000       |
# | train/                |            |
# |    entropy_loss       | -14.4      |
# |    explained_variance | -0.0341    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1199       |
# |    policy_loss        | 23.3       |
# |    reward             | 0.6940661  |
# |    reward_max         | 3.5605946  |
# |    reward_mean        | 0.56643385 |
# |    reward_min         | -2.302223  |
# |    std                | 1.02       |
# |    value_loss         | 10.8       |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 219         |
# |    iterations         | 1300        |
# |    time_elapsed       | 29          |
# |    total_timesteps    | 6500        |
# | train/                |             |
# |    entropy_loss       | -14.4       |
# |    explained_variance | -0.26       |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1299        |
# |    policy_loss        | 16.1        |
# |    reward             | 2.588479    |
# |    reward_max         | 3.392175    |
# |    reward_mean        | 1.8968031   |
# |    reward_min         | -0.73718476 |
# |    std                | 1.02        |
# |    value_loss         | 8.85        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 213        |
# |    iterations         | 1400       |
# |    time_elapsed       | 32         |
# |    total_timesteps    | 7000       |
# | train/                |            |
# |    entropy_loss       | -14.3      |
# |    explained_variance | -0.0151    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1399       |
# |    policy_loss        | 9.2        |
# |    reward             | 3.470032   |
# |    reward_max         | 3.470032   |
# |    reward_mean        | 1.1334405  |
# |    reward_min         | -2.4878283 |
# |    std                | 1.02       |
# |    value_loss         | 5.06       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 210        |
# |    iterations         | 1500       |
# |    time_elapsed       | 35         |
# |    total_timesteps    | 7500       |
# | train/                |            |
# |    entropy_loss       | -14.3      |
# |    explained_variance | -0.0467    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1499       |
# |    policy_loss        | -116       |
# |    reward             | -2.026312  |
# |    reward_max         | 5.675818   |
# |    reward_mean        | -4.1568174 |
# |    reward_min         | -16.001282 |
# |    std                | 1.01       |
# |    value_loss         | 101        |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 213        |
# |    iterations         | 1600       |
# |    time_elapsed       | 37         |
# |    total_timesteps    | 8000       |
# | train/                |            |
# |    entropy_loss       | -14.3      |
# |    explained_variance | -0.0932    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1599       |
# |    policy_loss        | 46.3       |
# |    reward             | -2.1515336 |
# |    reward_max         | 7.847694   |
# |    reward_mean        | 1.3626215  |
# |    reward_min         | -6.513998  |
# |    std                | 1.01       |
# |    value_loss         | 35         |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 216        |
# |    iterations         | 1700       |
# |    time_elapsed       | 39         |
# |    total_timesteps    | 8500       |
# | train/                |            |
# |    entropy_loss       | -14.3      |
# |    explained_variance | 0.000919   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1699       |
# |    policy_loss        | 19.2       |
# |    reward             | 3.0557618  |
# |    reward_max         | 4.1704173  |
# |    reward_mean        | -2.5724962 |
# |    reward_min         | -16.563654 |
# |    std                | 1.01       |
# |    value_loss         | 119        |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 218         |
# |    iterations         | 1800        |
# |    time_elapsed       | 41          |
# |    total_timesteps    | 9000        |
# | train/                |             |
# |    entropy_loss       | -14.3       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1799        |
# |    policy_loss        | -9.26       |
# |    reward             | -0.57068956 |
# |    reward_max         | 13.237842   |
# |    reward_mean        | 4.1880755   |
# |    reward_min         | -0.57068956 |
# |    std                | 1.01        |
# |    value_loss         | 197         |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 215         |
# |    iterations         | 1900        |
# |    time_elapsed       | 44          |
# |    total_timesteps    | 9500        |
# | train/                |             |
# |    entropy_loss       | -14.3       |
# |    explained_variance | -1.34       |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1899        |
# |    policy_loss        | 91.2        |
# |    reward             | -0.08218488 |
# |    reward_max         | 2.1945744   |
# |    reward_mean        | -1.2252373  |
# |    reward_min         | -7.576761   |
# |    std                | 1.01        |
# |    value_loss         | 49.7        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 208        |
# |    iterations         | 2000       |
# |    time_elapsed       | 48         |
# |    total_timesteps    | 10000      |
# | train/                |            |
# |    entropy_loss       | -14.3      |
# |    explained_variance | 0.187      |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1999       |
# |    policy_loss        | 312        |
# |    reward             | -29.775234 |
# |    reward_max         | 2.3895738  |
# |    reward_mean        | -11.311222 |
# |    reward_min         | -29.775234 |
# |    std                | 1.01       |
# |    value_loss         | 463        |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 210        |
# |    iterations         | 2100       |
# |    time_elapsed       | 49         |
# |    total_timesteps    | 10500      |
# | train/                |            |
# |    entropy_loss       | -14.3      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 2099       |
# |    policy_loss        | -5.25      |
# |    reward             | 1.4031044  |
# |    reward_max         | 1.4031044  |
# |    reward_mean        | -5.0728836 |
# |    reward_min         | -10.682774 |
# |    std                | 1.01       |
# |    value_loss         | 30.2       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 212        |
# |    iterations         | 2200       |
# |    time_elapsed       | 51         |
# |    total_timesteps    | 11000      |
# | train/                |            |
# |    entropy_loss       | -14.3      |
# |    explained_variance | 1.19e-07   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 2199       |
# |    policy_loss        | -126       |
# |    reward             | -4.2522674 |
# |    reward_max         | 11.772667  |
# |    reward_mean        | 2.7017584  |
# |    reward_min         | -4.2522674 |
# |    std                | 1.01       |
# |    value_loss         | 165        |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 213         |
# |    iterations         | 2300        |
# |    time_elapsed       | 53          |
# |    total_timesteps    | 11500       |
# | train/                |             |
# |    entropy_loss       | -14.3       |
# |    explained_variance | 0.015       |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 2299        |
# |    policy_loss        | 179         |
# |    reward             | 9.013846    |
# |    reward_max         | 11.252804   |
# |    reward_mean        | 5.038059    |
# |    reward_min         | -0.49993902 |
# |    std                | 1.01        |
# |    value_loss         | 142         |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 215        |
# |    iterations         | 2400       |
# |    time_elapsed       | 55         |
# |    total_timesteps    | 12000      |
# | train/                |            |
# |    entropy_loss       | -14.3      |
# |    explained_variance | -0.00245   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 2399       |
# |    policy_loss        | -278       |
# |    reward             | -3.2454264 |
# |    reward_max         | 16.63949   |
# |    reward_mean        | 5.882105   |
# |    reward_min         | -9.188535  |
# |    std                | 1.01       |
# |    value_loss         | 418        |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 216         |
# |    iterations         | 2500        |
# |    time_elapsed       | 57          |
# |    total_timesteps    | 12500       |
# | train/                |             |
# |    entropy_loss       | -14.3       |
# |    explained_variance | -1.19e-07   |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 2499        |
# |    policy_loss        | 210         |
# |    reward             | -1.5961313  |
# |    reward_max         | 5.5338655   |
# |    reward_mean        | -0.08392056 |
# |    reward_min         | -6.1143703  |
# |    std                | 1.01        |
# |    value_loss         | 278         |
# ---------------------------------------
# day: 755, episode: 20
# begin_total_asset: 1000000.00
# end_total_asset: 1894990.49
# total_reward: 894990.49
# total_cost: 8603.98
# total_trades: 4724
# Sharpe: 0.666
# =================================
# ---------------------------------------
# | time/                 |             |
# |    fps                | 216         |
# |    iterations         | 2600        |
# |    time_elapsed       | 60          |
# |    total_timesteps    | 13000       |
# | train/                |             |
# |    entropy_loss       | -14.4       |
# |    explained_variance | 0.0442      |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 2599        |
# |    policy_loss        | -44.9       |
# |    reward             | 0.59039545  |
# |    reward_max         | 4.048505    |
# |    reward_mean        | 1.652801    |
# |    reward_min         | -0.22757642 |
# |    std                | 1.02        |
# |    value_loss         | 23.9        |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 216       |
# |    iterations         | 2700      |
# |    time_elapsed       | 62        |
# |    total_timesteps    | 13500     |
# | train/                |           |
# |    entropy_loss       | -14.4     |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2699      |
# |    policy_loss        | 298       |
# |    reward             | 17.172644 |
# |    reward_max         | 17.172644 |
# |    reward_mean        | 5.142395  |
# |    reward_min         | -9.296006 |
# |    std                | 1.02      |
# |    value_loss         | 534       |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 218         |
# |    iterations         | 2800        |
# |    time_elapsed       | 64          |
# |    total_timesteps    | 14000       |
# | train/                |             |
# |    entropy_loss       | -14.4       |
# |    explained_variance | -1.19e-07   |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 2799        |
# |    policy_loss        | -74         |
# |    reward             | -0.86826557 |
# |    reward_max         | 4.2999105   |
# |    reward_mean        | 0.14088795  |
# |    reward_min         | -1.3314434  |
# |    std                | 1.02        |
# |    value_loss         | 35.4        |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 219         |
# |    iterations         | 2900        |
# |    time_elapsed       | 66          |
# |    total_timesteps    | 14500       |
# | train/                |             |
# |    entropy_loss       | -14.3       |
# |    explained_variance | 1.79e-07    |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 2899        |
# |    policy_loss        | 122         |
# |    reward             | -0.5021896  |
# |    reward_max         | 2.0487955   |
# |    reward_mean        | -0.52458113 |
# |    reward_min         | -3.3108597  |
# |    std                | 1.02        |
# |    value_loss         | 73.1        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 220        |
# |    iterations         | 3000       |
# |    time_elapsed       | 67         |
# |    total_timesteps    | 15000      |
# | train/                |            |
# |    entropy_loss       | -14.3      |
# |    explained_variance | 5.96e-08   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 2999       |
# |    policy_loss        | 42.2       |
# |    reward             | 4.1169477  |
# |    reward_max         | 13.258927  |
# |    reward_mean        | 1.0820104  |
# |    reward_min         | -17.051653 |
# |    std                | 1.01       |
# |    value_loss         | 17.4       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 221        |
# |    iterations         | 3100       |
# |    time_elapsed       | 69         |
# |    total_timesteps    | 15500      |
# | train/                |            |
# |    entropy_loss       | -14.3      |
# |    explained_variance | 0.0241     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 3099       |
# |    policy_loss        | -24.6      |
# |    reward             | -2.836467  |
# |    reward_max         | 1.0616426  |
# |    reward_mean        | -0.9160824 |
# |    reward_min         | -2.836467  |
# |    std                | 1.01       |
# |    value_loss         | 9.65       |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 219         |
# |    iterations         | 3200        |
# |    time_elapsed       | 72          |
# |    total_timesteps    | 16000       |
# | train/                |             |
# |    entropy_loss       | -14.3       |
# |    explained_variance | -0.00549    |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 3199        |
# |    policy_loss        | 7.49        |
# |    reward             | 0.16865553  |
# |    reward_max         | 5.370553    |
# |    reward_mean        | -0.11442433 |
# |    reward_min         | -3.570368   |
# |    std                | 1.01        |
# |    value_loss         | 0.541       |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 219        |
# |    iterations         | 3300       |
# |    time_elapsed       | 75         |
# |    total_timesteps    | 16500      |
# | train/                |            |
# |    entropy_loss       | -14.3      |
# |    explained_variance | -0.229     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 3299       |
# |    policy_loss        | -115       |
# |    reward             | 5.6855426  |
# |    reward_max         | 8.020748   |
# |    reward_mean        | 3.2950454  |
# |    reward_min         | -0.3156639 |
# |    std                | 1.01       |
# |    value_loss         | 86.9       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 220        |
# |    iterations         | 3400       |
# |    time_elapsed       | 77         |
# |    total_timesteps    | 17000      |
# | train/                |            |
# |    entropy_loss       | -14.3      |
# |    explained_variance | -0.229     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 3399       |
# |    policy_loss        | 18         |
# |    reward             | 0.8033375  |
# |    reward_max         | 2.7558591  |
# |    reward_mean        | 0.64021814 |
# |    reward_min         | -2.648209  |
# |    std                | 1.02       |
# |    value_loss         | 2.08       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 221        |
# |    iterations         | 3500       |
# |    time_elapsed       | 79         |
# |    total_timesteps    | 17500      |
# | train/                |            |
# |    entropy_loss       | -14.4      |
# |    explained_variance | 1.79e-07   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 3499       |
# |    policy_loss        | 18.4       |
# |    reward             | 0.47483975 |
# |    reward_max         | 1.5718602  |
# |    reward_mean        | 0.1612578  |
# |    reward_min         | -3.64612   |
# |    std                | 1.02       |
# |    value_loss         | 1.57       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 222        |
# |    iterations         | 3600       |
# |    time_elapsed       | 81         |
# |    total_timesteps    | 18000      |
# | train/                |            |
# |    entropy_loss       | -14.4      |
# |    explained_variance | 0.0133     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 3599       |
# |    policy_loss        | 195        |
# |    reward             | 0.34893557 |
# |    reward_max         | 6.83232    |
# |    reward_mean        | -1.5670251 |
# |    reward_min         | -13.717753 |
# |    std                | 1.02       |
# |    value_loss         | 260        |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 222        |
# |    iterations         | 3700       |
# |    time_elapsed       | 83         |
# |    total_timesteps    | 18500      |
# | train/                |            |
# |    entropy_loss       | -14.4      |
# |    explained_variance | 0.247      |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 3699       |
# |    policy_loss        | 56.7       |
# |    reward             | -3.0799718 |
# |    reward_max         | 2.5935318  |
# |    reward_mean        | 0.08215916 |
# |    reward_min         | -3.0799718 |
# |    std                | 1.02       |
# |    value_loss         | 20.1       |
# --------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 222          |
# |    iterations         | 3800         |
# |    time_elapsed       | 85           |
# |    total_timesteps    | 19000        |
# | train/                |              |
# |    entropy_loss       | -14.4        |
# |    explained_variance | 0.032        |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 3799         |
# |    policy_loss        | 39.3         |
# |    reward             | -0.036763396 |
# |    reward_max         | 3.7937       |
# |    reward_mean        | 0.9492967    |
# |    reward_min         | -0.036763396 |
# |    std                | 1.02         |
# |    value_loss         | 7.92         |
# ----------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 222         |
# |    iterations         | 3900        |
# |    time_elapsed       | 87          |
# |    total_timesteps    | 19500       |
# | train/                |             |
# |    entropy_loss       | -14.4       |
# |    explained_variance | -0.017      |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 3899        |
# |    policy_loss        | -273        |
# |    reward             | -0.75678015 |
# |    reward_max         | 9.587353    |
# |    reward_mean        | -0.7636062  |
# |    reward_min         | -12.30408   |
# |    std                | 1.02        |
# |    value_loss         | 476         |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 223        |
# |    iterations         | 4000       |
# |    time_elapsed       | 89         |
# |    total_timesteps    | 20000      |
# | train/                |            |
# |    entropy_loss       | -14.4      |
# |    explained_variance | 0.00676    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 3999       |
# |    policy_loss        | -53.2      |
# |    reward             | 5.586428   |
# |    reward_max         | 5.586428   |
# |    reward_mean        | -4.226095  |
# |    reward_min         | -12.166532 |
# |    std                | 1.02       |
# |    value_loss         | 34.4       |
# --------------------------------------
# day: 755, episode: 30
# begin_total_asset: 1000000.00
# end_total_asset: 1195265.07
# total_reward: 195265.07
# total_cost: 25489.15
# total_trades: 6069
# Sharpe: 0.373
# =================================
# --------------------------------------
# | time/                 |            |
# |    fps                | 223        |
# |    iterations         | 4100       |
# |    time_elapsed       | 91         |
# |    total_timesteps    | 20500      |
# | train/                |            |
# |    entropy_loss       | -14.3      |
# |    explained_variance | 0.0112     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 4099       |
# |    policy_loss        | 6.19       |
# |    reward             | 1.8472447  |
# |    reward_max         | 2.8696196  |
# |    reward_mean        | 1.4590302  |
# |    reward_min         | 0.66878426 |
# |    std                | 1.02       |
# |    value_loss         | 7.17       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 224        |
# |    iterations         | 4200       |
# |    time_elapsed       | 93         |
# |    total_timesteps    | 21000      |
# | train/                |            |
# |    entropy_loss       | -14.4      |
# |    explained_variance | 0.00488    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 4199       |
# |    policy_loss        | -563       |
# |    reward             | 2.3745878  |
# |    reward_max         | 11.317469  |
# |    reward_mean        | 2.6628165  |
# |    reward_min         | -4.2735586 |
# |    std                | 1.02       |
# |    value_loss         | 1.59e+03   |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 225        |
# |    iterations         | 4300       |
# |    time_elapsed       | 95         |
# |    total_timesteps    | 21500      |
# | train/                |            |
# |    entropy_loss       | -14.4      |
# |    explained_variance | -0.0241    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 4299       |
# |    policy_loss        | -4.39      |
# |    reward             | -1.7801051 |
# |    reward_max         | 3.491196   |
# |    reward_mean        | -1.7082405 |
# |    reward_min         | -6.362696  |
# |    std                | 1.02       |
# |    value_loss         | 7.98       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 225        |
# |    iterations         | 4400       |
# |    time_elapsed       | 97         |
# |    total_timesteps    | 22000      |
# | train/                |            |
# |    entropy_loss       | -14.4      |
# |    explained_variance | -0.175     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 4399       |
# |    policy_loss        | 69.9       |
# |    reward             | 4.629631   |
# |    reward_max         | 4.629631   |
# |    reward_mean        | 0.33063716 |
# |    reward_min         | -4.4398656 |
# |    std                | 1.02       |
# |    value_loss         | 32.3       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 224        |
# |    iterations         | 4500       |
# |    time_elapsed       | 100        |
# |    total_timesteps    | 22500      |
# | train/                |            |
# |    entropy_loss       | -14.4      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 4499       |
# |    policy_loss        | -164       |
# |    reward             | -13.749868 |
# |    reward_max         | 12.559434  |
# |    reward_mean        | -5.197287  |
# |    reward_min         | -17.72081  |
# |    std                | 1.02       |
# |    value_loss         | 270        |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 225        |
# |    iterations         | 4600       |
# |    time_elapsed       | 101        |
# |    total_timesteps    | 23000      |
# | train/                |            |
# |    entropy_loss       | -14.4      |
# |    explained_variance | 0.00586    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 4599       |
# |    policy_loss        | 253        |
# |    reward             | 6.834083   |
# |    reward_max         | 6.834083   |
# |    reward_mean        | 1.0872698  |
# |    reward_min         | -5.1870923 |
# |    std                | 1.02       |
# |    value_loss         | 311        |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 226         |
# |    iterations         | 4700        |
# |    time_elapsed       | 103         |
# |    total_timesteps    | 23500       |
# | train/                |             |
# |    entropy_loss       | -14.4       |
# |    explained_variance | -0.196      |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 4699        |
# |    policy_loss        | 22.8        |
# |    reward             | -0.90367454 |
# |    reward_max         | 3.615388    |
# |    reward_mean        | -0.26475736 |
# |    reward_min         | -3.8187895  |
# |    std                | 1.03        |
# |    value_loss         | 19.5        |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 226         |
# |    iterations         | 4800        |
# |    time_elapsed       | 105         |
# |    total_timesteps    | 24000       |
# | train/                |             |
# |    entropy_loss       | -14.5       |
# |    explained_variance | -0.0134     |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 4799        |
# |    policy_loss        | 595         |
# |    reward             | 3.7489362   |
# |    reward_max         | 26.86856    |
# |    reward_mean        | 7.6427007   |
# |    reward_min         | -0.84141916 |
# |    std                | 1.03        |
# |    value_loss         | 2.08e+03    |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 227         |
# |    iterations         | 4900        |
# |    time_elapsed       | 107         |
# |    total_timesteps    | 24500       |
# | train/                |             |
# |    entropy_loss       | -14.5       |
# |    explained_variance | 2.38e-07    |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 4899        |
# |    policy_loss        | 79.2        |
# |    reward             | -13.4079685 |
# |    reward_max         | 7.188748    |
# |    reward_mean        | -5.953848   |
# |    reward_min         | -20.632202  |
# |    std                | 1.03        |
# |    value_loss         | 63.4        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 227        |
# |    iterations         | 5000       |
# |    time_elapsed       | 109        |
# |    total_timesteps    | 25000      |
# | train/                |            |
# |    entropy_loss       | -14.5      |
# |    explained_variance | 0.0392     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 4999       |
# |    policy_loss        | -65.5      |
# |    reward             | -3.3380504 |
# |    reward_max         | 7.65619    |
# |    reward_mean        | -2.7340436 |
# |    reward_min         | -12.624667 |
# |    std                | 1.03       |
# |    value_loss         | 46         |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 226        |
# |    iterations         | 5100       |
# |    time_elapsed       | 112        |
# |    total_timesteps    | 25500      |
# | train/                |            |
# |    entropy_loss       | -14.5      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 5099       |
# |    policy_loss        | -88.5      |
# |    reward             | -16.196259 |
# |    reward_max         | 13.627922  |
# |    reward_mean        | -3.4622817 |
# |    reward_min         | -16.196259 |
# |    std                | 1.03       |
# |    value_loss         | 116        |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 227       |
# |    iterations         | 5200      |
# |    time_elapsed       | 114       |
# |    total_timesteps    | 26000     |
# | train/                |           |
# |    entropy_loss       | -14.5     |
# |    explained_variance | -0.00024  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5199      |
# |    policy_loss        | 68.9      |
# |    reward             | -11.21672 |
# |    reward_max         | -5.143409 |
# |    reward_mean        | -9.025157 |
# |    reward_min         | -11.21672 |
# |    std                | 1.03      |
# |    value_loss         | 77.6      |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 227         |
# |    iterations         | 5300        |
# |    time_elapsed       | 116         |
# |    total_timesteps    | 26500       |
# | train/                |             |
# |    entropy_loss       | -14.5       |
# |    explained_variance | 0.0881      |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 5299        |
# |    policy_loss        | -105        |
# |    reward             | 4.359703    |
# |    reward_max         | 4.359703    |
# |    reward_mean        | -0.27991083 |
# |    reward_min         | -5.729134   |
# |    std                | 1.03        |
# |    value_loss         | 59.5        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 228        |
# |    iterations         | 5400       |
# |    time_elapsed       | 118        |
# |    total_timesteps    | 27000      |
# | train/                |            |
# |    entropy_loss       | -14.5      |
# |    explained_variance | 1.19e-07   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 5399       |
# |    policy_loss        | 97.3       |
# |    reward             | -17.191925 |
# |    reward_max         | 0.25736648 |
# |    reward_mean        | -9.575278  |
# |    reward_min         | -17.191925 |
# |    std                | 1.03       |
# |    value_loss         | 117        |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 229        |
# |    iterations         | 5500       |
# |    time_elapsed       | 120        |
# |    total_timesteps    | 27500      |
# | train/                |            |
# |    entropy_loss       | -14.4      |
# |    explained_variance | -0.02      |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 5499       |
# |    policy_loss        | -186       |
# |    reward             | -2.875312  |
# |    reward_max         | 1.8608285  |
# |    reward_mean        | -0.9178587 |
# |    reward_min         | -5.440431  |
# |    std                | 1.03       |
# |    value_loss         | 190        |
# --------------------------------------
# day: 755, episode: 40
# begin_total_asset: 1000000.00
# end_total_asset: 1174446.12
# total_reward: 174446.12
# total_cost: 23783.55
# total_trades: 5681
# Sharpe: 0.374
# =================================
# --------------------------------------
# | time/                 |            |
# |    fps                | 229        |
# |    iterations         | 5600       |
# |    time_elapsed       | 121        |
# |    total_timesteps    | 28000      |
# | train/                |            |
# |    entropy_loss       | -14.5      |
# |    explained_variance | -0.0791    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 5599       |
# |    policy_loss        | 20.4       |
# |    reward             | 0.87542874 |
# |    reward_max         | 1.4958339  |
# |    reward_mean        | 0.32131672 |
# |    reward_min         | -2.1545837 |
# |    std                | 1.03       |
# |    value_loss         | 4.25       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 228        |
# |    iterations         | 5700       |
# |    time_elapsed       | 124        |
# |    total_timesteps    | 28500      |
# | train/                |            |
# |    entropy_loss       | -14.4      |
# |    explained_variance | -0.0719    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 5699       |
# |    policy_loss        | -104       |
# |    reward             | 6.3092756  |
# |    reward_max         | 17.77184   |
# |    reward_mean        | 1.2973526  |
# |    reward_min         | -15.037152 |
# |    std                | 1.03       |
# |    value_loss         | 108        |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 228         |
# |    iterations         | 5800        |
# |    time_elapsed       | 126         |
# |    total_timesteps    | 29000       |
# | train/                |             |
# |    entropy_loss       | -14.4       |
# |    explained_variance | -0.00464    |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 5799        |
# |    policy_loss        | 103         |
# |    reward             | 6.689411    |
# |    reward_max         | 6.689411    |
# |    reward_mean        | -0.64584696 |
# |    reward_min         | -6.049383   |
# |    std                | 1.03        |
# |    value_loss         | 57.3        |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 229         |
# |    iterations         | 5900        |
# |    time_elapsed       | 128         |
# |    total_timesteps    | 29500       |
# | train/                |             |
# |    entropy_loss       | -14.4       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 5899        |
# |    policy_loss        | -3.4        |
# |    reward             | -1.0371784  |
# |    reward_max         | 0.05353302  |
# |    reward_mean        | -0.29479843 |
# |    reward_min         | -1.0371784  |
# |    std                | 1.03        |
# |    value_loss         | 0.0507      |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 229        |
# |    iterations         | 6000       |
# |    time_elapsed       | 130        |
# |    total_timesteps    | 30000      |
# | train/                |            |
# |    entropy_loss       | -14.4      |
# |    explained_variance | -0.0788    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 5999       |
# |    policy_loss        | -18.3      |
# |    reward             | -4.713701  |
# |    reward_max         | 5.9543676  |
# |    reward_mean        | -2.7650683 |
# |    reward_min         | -13.384919 |
# |    std                | 1.03       |
# |    value_loss         | 54.3       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 229        |
# |    iterations         | 6100       |
# |    time_elapsed       | 132        |
# |    total_timesteps    | 30500      |
# | train/                |            |
# |    entropy_loss       | -14.5      |
# |    explained_variance | 0.01       |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 6099       |
# |    policy_loss        | 67.1       |
# |    reward             | 0.9647666  |
# |    reward_max         | 11.018187  |
# |    reward_mean        | 2.460451   |
# |    reward_min         | -12.989681 |
# |    std                | 1.03       |
# |    value_loss         | 28.2       |
# --------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 229          |
# |    iterations         | 6200         |
# |    time_elapsed       | 134          |
# |    total_timesteps    | 31000        |
# | train/                |              |
# |    entropy_loss       | -14.5        |
# |    explained_variance | -0.401       |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 6199         |
# |    policy_loss        | 24.8         |
# |    reward             | 0.13728318   |
# |    reward_max         | 0.13728318   |
# |    reward_mean        | 0.019032922  |
# |    reward_min         | -0.054262433 |
# |    std                | 1.03         |
# |    value_loss         | 11.1         |
# ----------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 228        |
# |    iterations         | 6300       |
# |    time_elapsed       | 137        |
# |    total_timesteps    | 31500      |
# | train/                |            |
# |    entropy_loss       | -14.5      |
# |    explained_variance | -0.0982    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 6299       |
# |    policy_loss        | 59.3       |
# |    reward             | -2.9492543 |
# |    reward_max         | 5.6620026  |
# |    reward_mean        | 0.14197229 |
# |    reward_min         | -2.9492543 |
# |    std                | 1.03       |
# |    value_loss         | 25.2       |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 229         |
# |    iterations         | 6400        |
# |    time_elapsed       | 139         |
# ...
# ---------------------------------------
# | time/                 |             |
# |    fps                | 228         |
# |    iterations         | 8000        |
# |    time_elapsed       | 175         |
# |    total_timesteps    | 40000       |
# | train/                |             |
# |    entropy_loss       | -14.6       |
# |    explained_variance | -0.0964     |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 7999        |
# |    policy_loss        | -54.4       |
# |    reward             | -0.6703953  |
# |    reward_max         | 0.35663986  |
# |    reward_mean        | -0.97996813 |
# |    reward_min         | -1.9277602  |
# |    std                | 1.04        |
# |    value_loss         | 25          |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 228         |
# |    iterations         | 8100        |
# |    time_elapsed       | 177         |
# |    total_timesteps    | 40500       |
# | train/                |             |
# |    entropy_loss       | -14.6       |
# |    explained_variance | -0.257      |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 8099        |
# |    policy_loss        | 3           |
# |    reward             | -3.3443043  |
# |    reward_max         | 1.4605312   |
# |    reward_mean        | -0.74621403 |
# |    reward_min         | -3.3443043  |
# |    std                | 1.04        |
# |    value_loss         | 0.52        |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 228         |
# |    iterations         | 8200        |
# |    time_elapsed       | 179         |
# |    total_timesteps    | 41000       |
# | train/                |             |
# |    entropy_loss       | -14.6       |
# |    explained_variance | -0.00951    |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 8199        |
# |    policy_loss        | -32         |
# |    reward             | 0.07114888  |
# |    reward_max         | 0.49187088  |
# |    reward_mean        | -0.27366552 |
# |    reward_min         | -0.7940737  |
# |    std                | 1.05        |
# |    value_loss         | 5.05        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 228        |
# |    iterations         | 8300       |
# |    time_elapsed       | 181        |
# |    total_timesteps    | 41500      |
# | train/                |            |
# |    entropy_loss       | -14.6      |
# |    explained_variance | 0.258      |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 8299       |
# |    policy_loss        | -39.6      |
# |    reward             | 0.7150678  |
# |    reward_max         | 2.4956486  |
# |    reward_mean        | 0.39638048 |
# |    reward_min         | -1.6091086 |
# |    std                | 1.05       |
# |    value_loss         | 11.7       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 229        |
# |    iterations         | 8400       |
# |    time_elapsed       | 183        |
# |    total_timesteps    | 42000      |
# | train/                |            |
# |    entropy_loss       | -14.6      |
# |    explained_variance | -0.11      |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 8399       |
# |    policy_loss        | 33         |
# |    reward             | 1.1869755  |
# |    reward_max         | 2.4173017  |
# |    reward_mean        | 0.58895636 |
# |    reward_min         | -1.4249523 |
# |    std                | 1.05       |
# |    value_loss         | 8.38       |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 229         |
# |    iterations         | 8500        |
# |    time_elapsed       | 185         |
# |    total_timesteps    | 42500       |
# | train/                |             |
# |    entropy_loss       | -14.6       |
# |    explained_variance | -1.37       |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 8499        |
# |    policy_loss        | 0.206       |
# |    reward             | 2.0334775   |
# |    reward_max         | 2.0334775   |
# |    reward_mean        | 0.9741343   |
# |    reward_min         | -0.39635545 |
# |    std                | 1.05        |
# |    value_loss         | 0.356       |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 229        |
# |    iterations         | 8600       |
# |    time_elapsed       | 187        |
# |    total_timesteps    | 43000      |
# | train/                |            |
# |    entropy_loss       | -14.6      |
# |    explained_variance | 0.0599     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 8599       |
# |    policy_loss        | 134        |
# |    reward             | -3.9198732 |
# |    reward_max         | 0.4086563  |
# |    reward_mean        | -1.642744  |
# |    reward_min         | -3.9198732 |
# |    std                | 1.04       |
# |    value_loss         | 94.2       |
# --------------------------------------
# day: 755, episode: 60
# begin_total_asset: 1000000.00
# end_total_asset: 841755.85
# total_reward: -158244.15
# total_cost: 47540.38
# total_trades: 6127
# Sharpe: 0.019
# =================================
# --------------------------------------
# | time/                 |            |
# |    fps                | 228        |
# |    iterations         | 8700       |
# |    time_elapsed       | 189        |
# |    total_timesteps    | 43500      |
# | train/                |            |
# |    entropy_loss       | -14.5      |
# |    explained_variance | -0.626     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 8699       |
# |    policy_loss        | 24.6       |
# |    reward             | -1.4221307 |
# |    reward_max         | 0.6832717  |
# |    reward_mean        | 0.13261685 |
# |    reward_min         | -1.4221307 |
# |    std                | 1.04       |
# |    value_loss         | 4.37       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 229        |
# |    iterations         | 8800       |
# |    time_elapsed       | 192        |
# |    total_timesteps    | 44000      |
# | train/                |            |
# |    entropy_loss       | -14.5      |
# |    explained_variance | -0.0879    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 8799       |
# |    policy_loss        | 28.7       |
# |    reward             | 1.6526717  |
# |    reward_max         | 4.7001414  |
# |    reward_mean        | 1.5199926  |
# |    reward_min         | -1.2224739 |
# |    std                | 1.04       |
# |    value_loss         | 3.51       |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 229         |
# |    iterations         | 8900        |
# |    time_elapsed       | 194         |
# |    total_timesteps    | 44500       |
# | train/                |             |
# |    entropy_loss       | -14.6       |
# |    explained_variance | -0.861      |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 8899        |
# |    policy_loss        | 4.88        |
# |    reward             | 0.029003486 |
# |    reward_max         | 4.6908727   |
# |    reward_mean        | 0.82618433  |
# |    reward_min         | -2.7323174  |
# |    std                | 1.04        |
# |    value_loss         | 2.93        |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 229         |
# |    iterations         | 9000        |
# |    time_elapsed       | 196         |
# |    total_timesteps    | 45000       |
# | train/                |             |
# |    entropy_loss       | -14.6       |
# |    explained_variance | -2.43e-05   |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 8999        |
# |    policy_loss        | 17.1        |
# |    reward             | -0.05353096 |
# |    reward_max         | 3.7003553   |
# |    reward_mean        | 1.1027361   |
# |    reward_min         | -1.4270881  |
# |    std                | 1.04        |
# |    value_loss         | 12.3        |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 229         |
# |    iterations         | 9100        |
# |    time_elapsed       | 198         |
# |    total_timesteps    | 45500       |
# | train/                |             |
# |    entropy_loss       | -14.6       |
# |    explained_variance | 0.233       |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 9099        |
# |    policy_loss        | -18.9       |
# |    reward             | -3.7321136  |
# |    reward_max         | 3.5083866   |
# |    reward_mean        | -0.14472845 |
# |    reward_min         | -3.7321136  |
# |    std                | 1.05        |
# |    value_loss         | 2.5         |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 228        |
# |    iterations         | 9200       |
# |    time_elapsed       | 201        |
# |    total_timesteps    | 46000      |
# | train/                |            |
# |    entropy_loss       | -14.6      |
# |    explained_variance | 0.127      |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 9199       |
# |    policy_loss        | -60.8      |
# |    reward             | 3.3703923  |
# |    reward_max         | 3.3703923  |
# |    reward_mean        | 0.9962771  |
# |    reward_min         | -0.2727381 |
# |    std                | 1.05       |
# |    value_loss         | 21         |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 228         |
# |    iterations         | 9300        |
# |    time_elapsed       | 203         |
# |    total_timesteps    | 46500       |
# | train/                |             |
# |    entropy_loss       | -14.6       |
# |    explained_variance | -0.0968     |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 9299        |
# |    policy_loss        | 3.67        |
# |    reward             | -0.5317632  |
# |    reward_max         | 2.4712448   |
# |    reward_mean        | 0.46008256  |
# |    reward_min         | -0.88279754 |
# |    std                | 1.05        |
# |    value_loss         | 0.719       |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 228        |
# |    iterations         | 9400       |
# |    time_elapsed       | 205        |
# |    total_timesteps    | 47000      |
# | train/                |            |
# |    entropy_loss       | -14.7      |
# |    explained_variance | 0.0301     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 9399       |
# |    policy_loss        | -5.01      |
# |    reward             | -1.2982445 |
# |    reward_max         | 2.6569476  |
# |    reward_mean        | 0.48651108 |
# |    reward_min         | -1.2982445 |
# |    std                | 1.05       |
# |    value_loss         | 8.43       |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 228         |
# |    iterations         | 9500        |
# |    time_elapsed       | 207         |
# |    total_timesteps    | 47500       |
# | train/                |             |
# |    entropy_loss       | -14.7       |
# |    explained_variance | -0.146      |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 9499        |
# |    policy_loss        | 5.12        |
# |    reward             | -1.1469346  |
# |    reward_max         | 3.1310825   |
# |    reward_mean        | -0.20144986 |
# |    reward_min         | -1.6518909  |
# |    std                | 1.05        |
# |    value_loss         | 0.969       |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 229        |
# |    iterations         | 9600       |
# |    time_elapsed       | 209        |
# |    total_timesteps    | 48000      |
# | train/                |            |
# |    entropy_loss       | -14.6      |
# |    explained_variance | -0.00271   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 9599       |
# |    policy_loss        | -22.6      |
# |    reward             | 2.151727   |
# |    reward_max         | 2.151727   |
# |    reward_mean        | 0.66362077 |
# |    reward_min         | -1.435198  |
# |    std                | 1.05       |
# |    value_loss         | 3.33       |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 229         |
# |    iterations         | 9700        |
# |    time_elapsed       | 211         |
# |    total_timesteps    | 48500       |
# | train/                |             |
# |    entropy_loss       | -14.7       |
# |    explained_variance | 0.0846      |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 9699        |
# |    policy_loss        | -116        |
# |    reward             | 0.18104196  |
# |    reward_max         | 3.2627563   |
# |    reward_mean        | 1.1554477   |
# |    reward_min         | -0.77636135 |
# |    std                | 1.05        |
# |    value_loss         | 75.6        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 228        |
# |    iterations         | 9800       |
# |    time_elapsed       | 214        |
# |    total_timesteps    | 49000      |
# | train/                |            |
# |    entropy_loss       | -14.7      |
# |    explained_variance | -0.166     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 9799       |
# |    policy_loss        | -20.4      |
# |    reward             | -4.6643887 |
# |    reward_max         | 0.27770224 |
# |    reward_mean        | -2.626924  |
# |    reward_min         | -4.6643887 |
# |    std                | 1.05       |
# |    value_loss         | 3.69       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 228        |
# |    iterations         | 9900       |
# |    time_elapsed       | 216        |
# |    total_timesteps    | 49500      |
# | train/                |            |
# |    entropy_loss       | -14.7      |
# |    explained_variance | -0.365     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 9899       |
# |    policy_loss        | -3.56      |
# |    reward             | -0.3284296 |
# |    reward_max         | 1.8541152  |
# |    reward_mean        | 0.16308896 |
# |    reward_min         | -1.0876113 |
# |    std                | 1.05       |
# |    value_loss         | 0.423      |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 228         |
# |    iterations         | 10000       |
# |    time_elapsed       | 218         |
# |    total_timesteps    | 50000       |
# | train/                |             |
# |    entropy_loss       | -14.7       |
# |    explained_variance | -0.0209     |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 9999        |
# |    policy_loss        | 23.9        |
# |    reward             | 0.19550759  |
# |    reward_max         | 1.0521353   |
# |    reward_mean        | 0.021219492 |
# |    reward_min         | -1.6654255  |
# |    std                | 1.05        |
# |    value_loss         | 4.13        |
# ---------------------------------------

# %% [markdown]
# ### Agent 3: PPO

# %%
agent = DRLAgent(env = env_train)
PPO_PARAMS = {
    "n_steps": 2048,
    "ent_coef": 0.01,
    "learning_rate": 0.00025,
    "batch_size": 128,
}
model_ppo = agent.get_model("ppo",model_kwargs = PPO_PARAMS)

  # set up logger
tmp_path = RESULTS_DIR + '/ppo'
new_logger_ppo = configure(tmp_path, ["stdout", "csv", "tensorboard"])
  # Set new logger
model_ppo.set_logger(new_logger_ppo)
# Out:
# {'n_steps': 2048, 'ent_coef': 0.01, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to results/ppo

# %%
trained_ppo = agent.train_model(model=model_ppo,
                             tb_log_name='ppo',
                             total_timesteps=50000)
# Out:
# Auto-fixing bad obs shape 143 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 176 → 121
# Auto-fixing bad obs shape 165 → 121
# Auto-fixing bad obs shape 330 → 121
# Auto-fixing bad obs shape 385 → 121
# Auto-fixing bad obs shape 143 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 176 → 121
# Auto-fixing bad obs shape 165 → 121
# Auto-fixing bad obs shape 330 → 121
# Auto-fixing bad obs shape 385 → 121
# Auto-fixing bad obs shape 143 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 176 → 121
# Auto-fixing bad obs shape 165 → 121
# Auto-fixing bad obs shape 330 → 121
# Auto-fixing bad obs shape 385 → 121
# ------------------------------------
# | time/              |             |
# |    fps             | 310         |
# |    iterations      | 1           |
# |    time_elapsed    | 6           |
# |    total_timesteps | 2048        |
# | train/             |             |
# |    reward          | 0.050368156 |
# |    reward_max      | 14.514661   |
# |    reward_mean     | -0.0687029  |
# |    reward_min      | -28.412418  |
# ------------------------------------
# Auto-fixing bad obs shape 143 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 176 → 121
# Auto-fixing bad obs shape 165 → 121
# Auto-fixing bad obs shape 330 → 121
# Auto-fixing bad obs shape 385 → 121
# Auto-fixing bad obs shape 143 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 176 → 121
# Auto-fixing bad obs shape 165 → 121
# Auto-fixing bad obs shape 330 → 121
# Auto-fixing bad obs shape 385 → 121
# Auto-fixing bad obs shape 143 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 176 → 121
# Auto-fixing bad obs shape 165 → 121
# Auto-fixing bad obs shape 330 → 121
# Auto-fixing bad obs shape 385 → 121
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 278          |
# |    iterations           | 2            |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0075885793 |
# |    clip_fraction        | 0.0968       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -14.2        |
# |    explained_variance   | -0.00179     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 17.5         |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00703     |
# |    reward               | -0.4170204   |
# |    reward_max           | 10.370041    |
# |    reward_mean          | -0.065356545 |
# |    reward_min           | -28.168644   |
# |    std                  | 1            |
# |    value_loss           | 35.6         |
# ------------------------------------------
# Auto-fixing bad obs shape 143 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 176 → 121
# Auto-fixing bad obs shape 165 → 121
# Auto-fixing bad obs shape 330 → 121
# Auto-fixing bad obs shape 385 → 121
# Auto-fixing bad obs shape 143 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 176 → 121
# Auto-fixing bad obs shape 165 → 121
# Auto-fixing bad obs shape 330 → 121
# Auto-fixing bad obs shape 385 → 121
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 260         |
# |    iterations           | 3           |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.008903682 |
# |    clip_fraction        | 0.0782      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -14.2       |
# |    explained_variance   | 0.016       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 10.1        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00642    |
# |    reward               | 2.349252    |
# |    reward_max           | 9.036365    |
# |    reward_mean          | -0.08839107 |
# |    reward_min           | -62.579166  |
# |    std                  | 1.01        |
# |    value_loss           | 23.8        |
# -----------------------------------------
# Auto-fixing bad obs shape 143 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 176 → 121
# Auto-fixing bad obs shape 165 → 121
# Auto-fixing bad obs shape 330 → 121
# Auto-fixing bad obs shape 385 → 121
# Auto-fixing bad obs shape 143 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 176 → 121
# Auto-fixing bad obs shape 165 → 121
# Auto-fixing bad obs shape 330 → 121
# Auto-fixing bad obs shape 385 → 121
# day: 755, episode: 80
# begin_total_asset: 1000000.00
# end_total_asset: 536824.28
# total_reward: -463175.72
# total_cost: 59705.09
# total_trades: 7014
# Sharpe: -0.264
# =================================
# Auto-fixing bad obs shape 143 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 176 → 121
# Auto-fixing bad obs shape 165 → 121
# Auto-fixing bad obs shape 330 → 121
# Auto-fixing bad obs shape 385 → 121
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 254         |
# |    iterations           | 4           |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.010202792 |
# |    clip_fraction        | 0.123       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -14.3       |
# |    explained_variance   | 0.0445      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 43.2        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0142     |
# |    reward               | 0.63284147  |
# |    reward_max           | 19.966396   |
# |    reward_mean          | -0.08366413 |
# |    reward_min           | -57.169754  |
# |    std                  | 1.01        |
# |    value_loss           | 39.7        |
# -----------------------------------------
# Auto-fixing bad obs shape 143 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 176 → 121
# Auto-fixing bad obs shape 165 → 121
# Auto-fixing bad obs shape 330 → 121
# Auto-fixing bad obs shape 385 → 121
# Auto-fixing bad obs shape 143 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 176 → 121
# Auto-fixing bad obs shape 165 → 121
# Auto-fixing bad obs shape 330 → 121
# Auto-fixing bad obs shape 385 → 121
# Auto-fixing bad obs shape 143 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 176 → 121
# Auto-fixing bad obs shape 165 → 121
# Auto-fixing bad obs shape 330 → 121
# Auto-fixing bad obs shape 385 → 121
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 250          |
# |    iterations           | 5            |
# |    time_elapsed         | 40           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.009332268  |
# |    clip_fraction        | 0.0598       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -14.3        |
# |    explained_variance   | 0.0469       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 32.4         |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00587     |
# |    reward               | 0.5850747    |
# |    reward_max           | 15.779701    |
# |    reward_mean          | -0.072229594 |
# |    reward_min           | -36.78794    |
# |    std                  | 1.01         |
# |    value_loss           | 48.5         |
# ------------------------------------------
# Auto-fixing bad obs shape 143 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 176 → 121
# Auto-fixing bad obs shape 165 → 121
# Auto-fixing bad obs shape 330 → 121
# Auto-fixing bad obs shape 385 → 121
# Auto-fixing bad obs shape 143 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 176 → 121
# Auto-fixing bad obs shape 165 → 121
# Auto-fixing bad obs shape 330 → 121
# Auto-fixing bad obs shape 385 → 121
# Auto-fixing bad obs shape 143 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 176 → 121
# Auto-fixing bad obs shape 165 → 121
# Auto-fixing bad obs shape 330 → 121
# Auto-fixing bad obs shape 385 → 121
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 249          |
# |    iterations           | 6            |
# |    time_elapsed         | 49           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.009117365  |
# |    clip_fraction        | 0.0869       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -14.3        |
# |    explained_variance   | 0.0769       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 19.2         |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00569     |
# |    reward               | -1.1591872   |
# |    reward_max           | 14.398421    |
# |    reward_mean          | -0.060737032 |
# |    reward_min           | -36.418232   |
# |    std                  | 1.01         |
# |    value_loss           | 38.6         |
# ------------------------------------------
# Auto-fixing bad obs shape 143 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 176 → 121
# Auto-fixing bad obs shape 165 → 121
# Auto-fixing bad obs shape 330 → 121
# Auto-fixing bad obs shape 385 → 121
# Auto-fixing bad obs shape 143 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 176 → 121
# Auto-fixing bad obs shape 165 → 121
# Auto-fixing bad obs shape 330 → 121
# Auto-fixing bad obs shape 385 → 121
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 249          |
# |    iterations           | 7            |
# |    time_elapsed         | 57           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.006160559  |
# |    clip_fraction        | 0.0425       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -14.3        |
# |    explained_variance   | 0.056        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 14.3         |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00653     |
# |    reward               | -0.6189664   |
# |    reward_max           | 12.139173    |
# |    reward_mean          | -0.039555393 |
# |    reward_min           | -21.852102   |
# |    std                  | 1.01         |
# |    value_loss           | 25.5         |
# ------------------------------------------
# Auto-fixing bad obs shape 143 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 176 → 121
# Auto-fixing bad obs shape 165 → 121
# Auto-fixing bad obs shape 330 → 121
# Auto-fixing bad obs shape 385 → 121
# day: 755, episode: 90
# begin_total_asset: 1000000.00
# end_total_asset: 412741.51
# total_reward: -587258.49
# total_cost: 53770.43
# total_trades: 6782
# Sharpe: -0.431
# =================================
# Auto-fixing bad obs shape 143 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 176 → 121
# Auto-fixing bad obs shape 165 → 121
# Auto-fixing bad obs shape 330 → 121
# Auto-fixing bad obs shape 385 → 121
# Auto-fixing bad obs shape 143 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 176 → 121
# Auto-fixing bad obs shape 165 → 121
# Auto-fixing bad obs shape 330 → 121
# Auto-fixing bad obs shape 385 → 121
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 247          |
# |    iterations           | 8            |
# |    time_elapsed         | 66           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.010316129  |
# |    clip_fraction        | 0.0907       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -14.3        |
# |    explained_variance   | 0.0905       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 13.6         |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.0112      |
# |    reward               | 0.040861253  |
# |    reward_max           | 12.85724     |
# |    reward_mean          | -0.069250844 |
# |    reward_min           | -43.79625    |
# |    std                  | 1.01         |
# |    value_loss           | 33.7         |
# ------------------------------------------
# Auto-fixing bad obs shape 143 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 176 → 121
# Auto-fixing bad obs shape 165 → 121
# Auto-fixing bad obs shape 330 → 121
# Auto-fixing bad obs shape 385 → 121
# Auto-fixing bad obs shape 143 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 176 → 121
# Auto-fixing bad obs shape 165 → 121
# Auto-fixing bad obs shape 330 → 121
# Auto-fixing bad obs shape 385 → 121
# Auto-fixing bad obs shape 143 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 176 → 121
# Auto-fixing bad obs shape 165 → 121
# Auto-fixing bad obs shape 330 → 121
# Auto-fixing bad obs shape 385 → 121
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 238         |
# |    iterations           | 9           |
# |    time_elapsed         | 77          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.010653753 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -14.3       |
# |    explained_variance   | 0.154       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 22.8        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00702    |
# |    reward               | 1.2649338   |
# |    reward_max           | 10.45089    |
# |    reward_mean          | -0.06958713 |
# |    reward_min           | -33.705536  |
# |    std                  | 1.01        |
# |    value_loss           | 35.6        |
# -----------------------------------------
# Auto-fixing bad obs shape 143 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 176 → 121
# Auto-fixing bad obs shape 165 → 121
# Auto-fixing bad obs shape 330 → 121
# Auto-fixing bad obs shape 385 → 121
# Auto-fixing bad obs shape 143 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 176 → 121
# Auto-fixing bad obs shape 165 → 121
# Auto-fixing bad obs shape 330 → 121
# Auto-fixing bad obs shape 385 → 121
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 242          |
# |    iterations           | 10           |
# |    time_elapsed         | 84           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.010500916  |
# |    clip_fraction        | 0.108        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -14.3        |
# |    explained_variance   | 0.0462       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 11.1         |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00832     |
# |    reward               | 1.225322     |
# |    reward_max           | 11.751748    |
# |    reward_mean          | -0.046987444 |
# |    reward_min           | -54.18256    |
# |    std                  | 1.02         |
# |    value_loss           | 33.6         |
# ------------------------------------------
# Auto-fixing bad obs shape 143 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 176 → 121
# Auto-fixing bad obs shape 165 → 121
# Auto-fixing bad obs shape 330 → 121
# Auto-fixing bad obs shape 385 → 121
# Auto-fixing bad obs shape 143 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 176 → 121
# Auto-fixing bad obs shape 165 → 121
# Auto-fixing bad obs shape 330 → 121
# Auto-fixing bad obs shape 385 → 121
# Auto-fixing bad obs shape 143 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 176 → 121
# Auto-fixing bad obs shape 165 → 121
# Auto-fixing bad obs shape 330 → 121
# Auto-fixing bad obs shape 385 → 121
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 244         |
# |    iterations           | 11          |
# |    time_elapsed         | 92          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.009354491 |
# |    clip_fraction        | 0.105       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -14.4       |
# |    explained_variance   | 0.0199      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 26.1        |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00765    |
# |    reward               | 0.70883274  |
# |    reward_max           | 11.111513   |
# |    reward_mean          | -0.10965781 |
# |    reward_min           | -57.035603  |
# |    std                  | 1.02        |
# |    value_loss           | 35.7        |
# -----------------------------------------
# day: 755, episode: 100
# begin_total_asset: 1000000.00
# end_total_asset: 314830.90
# total_reward: -685169.10
# total_cost: 47342.61
# total_trades: 6618
# Sharpe: -0.551
# =================================
# Auto-fixing bad obs shape 143 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 176 → 121
# Auto-fixing bad obs shape 165 → 121
# Auto-fixing bad obs shape 330 → 121
# Auto-fixing bad obs shape 385 → 121
# Auto-fixing bad obs shape 143 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 176 → 121
# Auto-fixing bad obs shape 165 → 121
# Auto-fixing bad obs shape 330 → 121
# Auto-fixing bad obs shape 385 → 121
# Auto-fixing bad obs shape 143 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 176 → 121
# Auto-fixing bad obs shape 165 → 121
# Auto-fixing bad obs shape 330 → 121
# Auto-fixing bad obs shape 385 → 121
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 246         |
# |    iterations           | 12          |
# |    time_elapsed         | 99          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.009165229 |
# |    clip_fraction        | 0.119       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -14.4       |
# |    explained_variance   | 0.0494      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 5.43        |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00873    |
# |    reward               | -0.46883988 |
# |    reward_max           | 10.90148    |
# |    reward_mean          | -0.0761273  |
# |    reward_min           | -48.222607  |
# |    std                  | 1.02        |
# |    value_loss           | 69.3        |
# -----------------------------------------
# Auto-fixing bad obs shape 143 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 176 → 121
# Auto-fixing bad obs shape 165 → 121
# Auto-fixing bad obs shape 330 → 121
# Auto-fixing bad obs shape 385 → 121
# Auto-fixing bad obs shape 143 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 176 → 121
# Auto-fixing bad obs shape 165 → 121
# Auto-fixing bad obs shape 330 → 121
# Auto-fixing bad obs shape 385 → 121
# Auto-fixing bad obs shape 143 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 176 → 121
# Auto-fixing bad obs shape 165 → 121
# Auto-fixing bad obs shape 330 → 121
# Auto-fixing bad obs shape 385 → 121
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 247          |
# |    iterations           | 13           |
# |    time_elapsed         | 107          |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0082926415 |
# |    clip_fraction        | 0.0672       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -14.4        |
# |    explained_variance   | 0.193        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 35.9         |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00576     |
# |    reward               | 0.8124133    |
# |    reward_max           | 15.218708    |
# |    reward_mean          | -0.07289047  |
# |    reward_min           | -45.71776    |
# |    std                  | 1.02         |
# |    value_loss           | 55.9         |
# ------------------------------------------
# Auto-fixing bad obs shape 143 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 176 → 121
# Auto-fixing bad obs shape 165 → 121
# Auto-fixing bad obs shape 330 → 121
# Auto-fixing bad obs shape 385 → 121
# Auto-fixing bad obs shape 143 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 176 → 121
# Auto-fixing bad obs shape 165 → 121
# Auto-fixing bad obs shape 330 → 121
# Auto-fixing bad obs shape 385 → 121
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 248          |
# |    iterations           | 14           |
# |    time_elapsed         | 115          |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.009064858  |
# |    clip_fraction        | 0.0836       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -14.4        |
# |    explained_variance   | 0.214        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 16.2         |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00951     |
# |    reward               | 0.12845632   |
# |    reward_max           | 13.380719    |
# |    reward_mean          | -0.063790135 |
# |    reward_min           | -40.097473   |
# |    std                  | 1.02         |
# |    value_loss           | 43           |
# ------------------------------------------
# Auto-fixing bad obs shape 143 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 176 → 121
# Auto-fixing bad obs shape 165 → 121
# Auto-fixing bad obs shape 330 → 121
# Auto-fixing bad obs shape 385 → 121
# Auto-fixing bad obs shape 143 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 176 → 121
# Auto-fixing bad obs shape 165 → 121
# Auto-fixing bad obs shape 330 → 121
# Auto-fixing bad obs shape 385 → 121
# day: 755, episode: 110
# begin_total_asset: 1000000.00
# end_total_asset: 268760.30
# total_reward: -731239.70
# total_cost: 43127.35
# total_trades: 6375
# Sharpe: -0.075
# =================================
# Auto-fixing bad obs shape 143 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 176 → 121
# Auto-fixing bad obs shape 165 → 121
# Auto-fixing bad obs shape 330 → 121
# Auto-fixing bad obs shape 385 → 121
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 250         |
# |    iterations           | 15          |
# |    time_elapsed         | 122         |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.00893511  |
# |    clip_fraction        | 0.0785      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -14.4       |
# |    explained_variance   | 0.128       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 32.4        |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00998    |
# |    reward               | -2.5473304  |
# |    reward_max           | 17.719702   |
# |    reward_mean          | -0.07663941 |
# |    reward_min           | -63.01986   |
# |    std                  | 1.02        |
# |    value_loss           | 33.7        |
# -----------------------------------------
# Auto-fixing bad obs shape 143 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 176 → 121
# Auto-fixing bad obs shape 165 → 121
# Auto-fixing bad obs shape 330 → 121
# Auto-fixing bad obs shape 385 → 121
# Auto-fixing bad obs shape 143 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 176 → 121
# Auto-fixing bad obs shape 165 → 121
# Auto-fixing bad obs shape 330 → 121
# Auto-fixing bad obs shape 385 → 121
# Auto-fixing bad obs shape 143 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 176 → 121
# Auto-fixing bad obs shape 165 → 121
# Auto-fixing bad obs shape 330 → 121
# Auto-fixing bad obs shape 385 → 121
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 251          |
# |    iterations           | 16           |
# |    time_elapsed         | 130          |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0105672255 |
# |    clip_fraction        | 0.11         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -14.4        |
# |    explained_variance   | 0.113        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 52.8         |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00994     |
# |    reward               | 0.1672985    |
# |    reward_max           | 13.431715    |
# |    reward_mean          | -0.08880598  |
# |    reward_min           | -41.51091    |
# |    std                  | 1.03         |
# |    value_loss           | 61.6         |
# ------------------------------------------
# Auto-fixing bad obs shape 143 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 176 → 121
# Auto-fixing bad obs shape 165 → 121
# Auto-fixing bad obs shape 330 → 121
# Auto-fixing bad obs shape 385 → 121
# Auto-fixing bad obs shape 143 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 176 → 121
# Auto-fixing bad obs shape 165 → 121
# Auto-fixing bad obs shape 330 → 121
# Auto-fixing bad obs shape 385 → 121
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 252          |
# |    iterations           | 17           |
# |    time_elapsed         | 137          |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.007307846  |
# |    clip_fraction        | 0.0651       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -14.5        |
# |    explained_variance   | 0.221        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 16.5         |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00601     |
# |    reward               | 2.1062002    |
# |    reward_max           | 13.052648    |
# |    reward_mean          | -0.045870382 |
# |    reward_min           | -38.430042   |
# |    std                  | 1.03         |
# |    value_loss           | 54.8         |
# ------------------------------------------
# Auto-fixing bad obs shape 143 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 176 → 121
# Auto-fixing bad obs shape 165 → 121
# Auto-fixing bad obs shape 330 → 121
# Auto-fixing bad obs shape 385 → 121
# Auto-fixing bad obs shape 143 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 176 → 121
# Auto-fixing bad obs shape 165 → 121
# Auto-fixing bad obs shape 330 → 121
# Auto-fixing bad obs shape 385 → 121
# Auto-fixing bad obs shape 143 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 176 → 121
# Auto-fixing bad obs shape 165 → 121
# Auto-fixing bad obs shape 330 → 121
# Auto-fixing bad obs shape 385 → 121
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 253          |
# |    iterations           | 18           |
# |    time_elapsed         | 145          |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.008653885  |
# |    clip_fraction        | 0.074        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -14.5        |
# |    explained_variance   | 0.336        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 16.3         |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00742     |
# |    reward               | -1.1437471   |
# |    reward_max           | 7.4201593    |
# |    reward_mean          | -0.091915146 |
# |    reward_min           | -53.746006   |
# |    std                  | 1.03         |
# |    value_loss           | 28.7         |
# ------------------------------------------
# Auto-fixing bad obs shape 143 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 176 → 121
# Auto-fixing bad obs shape 165 → 121
# Auto-fixing bad obs shape 330 → 121
# Auto-fixing bad obs shape 385 → 121
# day: 755, episode: 120
# begin_total_asset: 1000000.00
# end_total_asset: 461921.93
# total_reward: -538078.07
# total_cost: 42702.01
# total_trades: 6460
# Sharpe: -0.226
# =================================
# Auto-fixing bad obs shape 143 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 176 → 121
# Auto-fixing bad obs shape 165 → 121
# Auto-fixing bad obs shape 330 → 121
# Auto-fixing bad obs shape 385 → 121
# Auto-fixing bad obs shape 143 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 176 → 121
# Auto-fixing bad obs shape 165 → 121
# Auto-fixing bad obs shape 330 → 121
# Auto-fixing bad obs shape 385 → 121
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 253          |
# |    iterations           | 19           |
# |    time_elapsed         | 153          |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.010711899  |
# |    clip_fraction        | 0.101        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -14.5        |
# |    explained_variance   | 0.103        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 21.4         |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00724     |
# |    reward               | -0.3127246   |
# |    reward_max           | 10.263886    |
# |    reward_mean          | -0.101956844 |
# |    reward_min           | -56.06344    |
# |    std                  | 1.03         |
# |    value_loss           | 62.3         |
# ------------------------------------------
# Auto-fixing bad obs shape 143 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 176 → 121
# Auto-fixing bad obs shape 165 → 121
# Auto-fixing bad obs shape 330 → 121
# Auto-fixing bad obs shape 385 → 121
# Auto-fixing bad obs shape 143 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 176 → 121
# Auto-fixing bad obs shape 165 → 121
# Auto-fixing bad obs shape 330 → 121
# Auto-fixing bad obs shape 385 → 121
# Auto-fixing bad obs shape 143 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 176 → 121
# Auto-fixing bad obs shape 165 → 121
# Auto-fixing bad obs shape 330 → 121
# Auto-fixing bad obs shape 385 → 121
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 255          |
# |    iterations           | 20           |
# |    time_elapsed         | 160          |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.010027183  |
# |    clip_fraction        | 0.0945       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -14.5        |
# |    explained_variance   | 0.281        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 31.7         |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.0101      |
# |    reward               | -0.1514292   |
# |    reward_max           | 16.606659    |
# |    reward_mean          | -0.118699394 |
# |    reward_min           | -58.519382   |
# |    std                  | 1.03         |
# |    value_loss           | 61.3         |
# ------------------------------------------
# Auto-fixing bad obs shape 143 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 176 → 121
# Auto-fixing bad obs shape 165 → 121
# Auto-fixing bad obs shape 330 → 121
# Auto-fixing bad obs shape 385 → 121
# Auto-fixing bad obs shape 143 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 176 → 121
# Auto-fixing bad obs shape 165 → 121
# Auto-fixing bad obs shape 330 → 121
# Auto-fixing bad obs shape 385 → 121
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 255         |
# |    iterations           | 21          |
# |    time_elapsed         | 168         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.009173614 |
# |    clip_fraction        | 0.127       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -14.5       |
# |    explained_variance   | 0.378       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 21          |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00596    |
# |    reward               | -0.2707236  |
# |    reward_max           | 11.776829   |
# |    reward_mean          | -0.06446737 |
# |    reward_min           | -52.753563  |
# |    std                  | 1.04        |
# |    value_loss           | 55.3        |
# -----------------------------------------
# Auto-fixing bad obs shape 143 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 176 → 121
# Auto-fixing bad obs shape 165 → 121
# Auto-fixing bad obs shape 330 → 121
# Auto-fixing bad obs shape 385 → 121
# Auto-fixing bad obs shape 143 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 176 → 121
# Auto-fixing bad obs shape 165 → 121
# Auto-fixing bad obs shape 330 → 121
# Auto-fixing bad obs shape 385 → 121
# Auto-fixing bad obs shape 143 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 176 → 121
# Auto-fixing bad obs shape 165 → 121
# Auto-fixing bad obs shape 330 → 121
# Auto-fixing bad obs shape 385 → 121
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 256          |
# |    iterations           | 22           |
# |    time_elapsed         | 175          |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.009513363  |
# |    clip_fraction        | 0.11         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -14.6        |
# |    explained_variance   | 0.468        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 9.42         |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00778     |
# |    reward               | 2.1118288    |
# |    reward_max           | 13.233691    |
# |    reward_mean          | -0.050955985 |
# |    reward_min           | -56.02017    |
# |    std                  | 1.04         |
# |    value_loss           | 42.7         |
# ------------------------------------------
# day: 755, episode: 130
# begin_total_asset: 1000000.00
# end_total_asset: 951388.15
# total_reward: -48611.85
# total_cost: 40926.72
# total_trades: 6318
# Sharpe: 0.123
# =================================
# Auto-fixing bad obs shape 143 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 176 → 121
# Auto-fixing bad obs shape 165 → 121
# Auto-fixing bad obs shape 330 → 121
# Auto-fixing bad obs shape 385 → 121
# Auto-fixing bad obs shape 143 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 176 → 121
# Auto-fixing bad obs shape 165 → 121
# Auto-fixing bad obs shape 330 → 121
# Auto-fixing bad obs shape 385 → 121
# Auto-fixing bad obs shape 143 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 176 → 121
# Auto-fixing bad obs shape 165 → 121
# Auto-fixing bad obs shape 330 → 121
# Auto-fixing bad obs shape 385 → 121
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 257         |
# |    iterations           | 23          |
# |    time_elapsed         | 183         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.010659062 |
# |    clip_fraction        | 0.114       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -14.6       |
# |    explained_variance   | 0.499       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 11.5        |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00984    |
# |    reward               | -0.15738615 |
# |    reward_max           | 21.299614   |
# |    reward_mean          | -0.12008942 |
# |    reward_min           | -52.728474  |
# |    std                  | 1.04        |
# |    value_loss           | 45.6        |
# -----------------------------------------
# Auto-fixing bad obs shape 143 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 176 → 121
# Auto-fixing bad obs shape 165 → 121
# Auto-fixing bad obs shape 330 → 121
# Auto-fixing bad obs shape 385 → 121
# Auto-fixing bad obs shape 143 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 176 → 121
# Auto-fixing bad obs shape 165 → 121
# Auto-fixing bad obs shape 330 → 121
# Auto-fixing bad obs shape 385 → 121
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 255          |
# |    iterations           | 24           |
# |    time_elapsed         | 192          |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.011078851  |
# |    clip_fraction        | 0.0987       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -14.6        |
# |    explained_variance   | 0.253        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 43.9         |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.0138      |
# |    reward               | 0.03240339   |
# |    reward_max           | 12.599048    |
# |    reward_mean          | -0.082039714 |
# |    reward_min           | -41.038296   |
# |    std                  | 1.04         |
# |    value_loss           | 83.1         |
# ------------------------------------------
# Auto-fixing bad obs shape 143 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 176 → 121
# Auto-fixing bad obs shape 165 → 121
# Auto-fixing bad obs shape 330 → 121
# Auto-fixing bad obs shape 385 → 121
# Auto-fixing bad obs shape 143 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 176 → 121
# Auto-fixing bad obs shape 165 → 121
# Auto-fixing bad obs shape 330 → 121
# Auto-fixing bad obs shape 385 → 121
# Auto-fixing bad obs shape 143 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 132 → 121
# Auto-fixing bad obs shape 176 → 121
# Auto-fixing bad obs shape 165 → 121
# Auto-fixing bad obs shape 330 → 121
# Auto-fixing bad obs shape 385 → 121
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 257         |
# |    iterations           | 25          |
# |    time_elapsed         | 199         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.01170769  |
# |    clip_fraction        | 0.154       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -14.6       |
# |    explained_variance   | 0.335       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 32          |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0133     |
# |    reward               | -1.319107   |
# |    reward_max           | 11.942863   |
# |    reward_mean          | -0.10066085 |
# |    reward_min           | -48.07092   |
# |    std                  | 1.05        |
# |    value_loss           | 45.8        |
# -----------------------------------------

# %% [markdown]
# ### Agent 3: TD3

# %%
agent = DRLAgent(env = env_train)
TD3_PARAMS = {"batch_size": 100,
              "buffer_size": 1000000,
              "learning_rate": 0.001}

model_td3 = agent.get_model("td3",model_kwargs = TD3_PARAMS)

  # set up logger
tmp_path = RESULTS_DIR + '/td3'
new_logger_td3 = configure(tmp_path, ["stdout", "csv", "tensorboard"])
  # Set new logger
model_td3.set_logger(new_logger_td3)
# Out:
# {'batch_size': 100, 'buffer_size': 1000000, 'learning_rate': 0.001}
# Using cpu device
# Logging to results/td3

# %%
trained_td3 = agent.train_model(model=model_td3,
                             tb_log_name='td3',
                             total_timesteps=50000)
# Out:
# Streaming output truncated to the last 5000 lines.
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# ------------------------------------
# | time/              |             |
# |    episodes        | 60          |
# |    fps             | 28          |
# |    time_elapsed    | 1617        |
# |    total_timesteps | 45360       |
# | train/             |             |
# |    actor_loss      | 19          |
# |    critic_loss     | 0.175       |
# |    learning_rate   | 0.001       |
# |    n_updates       | 45259       |
# |    reward          | 0.078876905 |
# |    reward_max      | None        |
# |    reward_mean     | None        |
# |    reward_min      | None        |
# ------------------------------------
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Auto-fixing bad obs shape 143 → 121
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Auto-fixing bad obs shape 132 → 121
# Logging Error: 'rollout_buffer'
# Auto-fixing bad obs shape 132 → 121
# Logging Error: 'rollout_buffer'
# Auto-fixing bad obs shape 132 → 121
# Logging Error: 'rollout_buffer'
# Auto-fixing bad obs shape 176 → 121
# Logging Error: 'rollout_buffer'
# Auto-fixing bad obs shape 165 → 121
# Logging Error: 'rollout_buffer'
# Auto-fixing bad obs shape 330 → 121
# Logging Error: 'rollout_buffer'
# Auto-fixing bad obs shape 385 → 121
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Auto-fixing bad obs shape 143 → 121
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Auto-fixing bad obs shape 132 → 121
# Logging Error: 'rollout_buffer'
# Auto-fixing bad obs shape 132 → 121
# Logging Error: 'rollout_buffer'
# Auto-fixing bad obs shape 132 → 121
# Logging Error: 'rollout_buffer'
# Auto-fixing bad obs shape 176 → 121
# Logging Error: 'rollout_buffer'
# Auto-fixing bad obs shape 165 → 121
# Logging Error: 'rollout_buffer'
# Auto-fixing bad obs shape 330 → 121
# Logging Error: 'rollout_buffer'
# Auto-fixing bad obs shape 385 → 121
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# ...
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Auto-fixing bad obs shape 143 → 121
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Auto-fixing bad obs shape 132 → 121
# Logging Error: 'rollout_buffer'

# %% [markdown]
# ## In-sample Performance
#
# Assume that the initial capital is $1,000,000.

# %% [markdown]
# ### Set turbulence threshold
# Set the turbulence threshold to be greater than the maximum of insample turbulence data. If current turbulence index is greater than the threshold, then we assume that the current market is volatile

# %%
data_risk_indicator = processed_full[(processed_full.date<TRAIN_END_DATE) & (processed_full.date>=TRAIN_START_DATE)]
insample_risk_indicator = data_risk_indicator.drop_duplicates(subset=['date'])

# %%
insample_risk_indicator.vix.describe()
# Out:
# count    756.000000
# mean      24.848664
# std        8.759434
# min       12.100000
# 25%       19.367501
# 50%       23.134999
# 75%       27.990000
# max       82.690002
# Name: vix, dtype: float64

# %%
insample_risk_indicator.vix.quantile(0.996)
# Out:
# 75.40060119628913

# %%
insample_risk_indicator.turbulence.describe()
# Out:
# count    756.000000
# mean       7.637635
# std       16.377620
# min        0.000000
# 25%        0.000000
# 50%        4.191969
# 75%        9.347991
# max      293.467726
# Name: turbulence, dtype: float64

# %%
insample_risk_indicator.turbulence.quantile(0.996)
# Out:
# 102.95684474843861

# %% [markdown]
# ### Trading (Out-of-sample Performance)
#
# We update periodically in order to take full advantage of the data, e.g., retrain quarterly, monthly or weekly. We also tune the parameters along the way, in this notebook we use the in-sample data from 2009-01 to 2020-07 to tune the parameters once, so there is some alpha decay here as the length of trade date extends.
#
# Numerous hyperparameters – e.g. the learning rate, the total number of samples to train on – influence the learning process and are usually determined by testing some variations.

# %%
e_trade_gym = StockTradingEnv(df = trade, turbulence_threshold = 70,risk_indicator_col='vix', **env_kwargs)

# %%
trade.head()
# Out:
#          date    tic        open        high         low       close  \
# 0  2023-01-03   AAPL  128.613978  129.226044  122.582112  123.470604
# 0  2023-01-03   AMZN   85.459999   86.959999   84.209999   85.820000
# 0  2023-01-03     BA  192.949997  197.179993  192.399994  195.389999
# 0  2023-01-03    DIS   87.894196   88.872113   86.758227   87.884315
# 0  2023-01-03  GOOGL   89.055906   90.507209   87.992285   88.588715
#
#         volume  day      macd     boll_ub     boll_lb     rsi_30      cci_30  \
# 0  112117500.0  1.0 -4.648600  147.860275  121.091834  39.011473 -130.963621
# 0   76706000.0  1.0 -3.075118   93.357149   80.929850  41.195599  -71.360174
# 0    8624600.0  1.0  5.326285  196.702727  176.154272  62.905353  141.206999
# 0   14997100.0  1.0 -2.406148   95.859728   81.780766  44.489021  -57.420591
# 0   28131200.0  1.0 -2.129973   98.089498   83.452728  43.976971  -67.730627
#
#        dx_30  close_30_sma  close_60_sma   vix  turbulence
# 0  35.956352    138.293931    140.567286  22.9   29.954638
# 0  10.198927     89.424999     97.181000  22.9   29.954638
# 0  44.456630    182.859667    166.269167  22.9   29.954638
# 0   3.756592     91.139430     94.093272  22.9   29.954638
# 0   2.932357     92.974732     93.988818  22.9   29.954638

# %%
trained_moedl = trained_a2c
df_account_value_a2c, df_actions_a2c = DRLAgent.DRL_prediction(
    model=trained_moedl,
    environment = e_trade_gym)
# Out:
# hit end!

# %%
trained_moedl = trained_ppo
df_account_value_ppo, df_actions_ppo = DRLAgent.DRL_prediction(
    model=trained_moedl,
    environment = e_trade_gym)
# Out:
# hit end!

# %%
trained_moedl = trained_td3
df_account_value_td3, df_actions_td3 = DRLAgent.DRL_prediction(
    model=trained_moedl,
    environment = e_trade_gym)
# Out:
# hit end!

# %%
df_account_value_a2c.shape
# Out:
# (249, 2)

# %% [markdown]
# ### Trading (Out-of-sample Performance)
#
# We update periodically in order to take full advantage of the data, e.g., retrain quarterly, monthly or weekly. We also tune the parameters along the way, in this notebook we use the in-sample data from 2009-01 to 2020-07 to tune the parameters once, so there is some alpha decay here as the length of trade date extends.
#
# Numerous hyperparameters – e.g. the learning rate, the total number of samples to train on – influence the learning process and are usually determined by testing some variations.

# %%
df_result_a2c = df_account_value_a2c.set_index(df_account_value_a2c.columns[0])
df_result_ppo = df_account_value_ppo.set_index(df_account_value_ppo.columns[0])
df_result_td3 = df_account_value_td3.set_index(df_account_value_td3.columns[0])

result = pd.merge(df_result_a2c, df_result_ppo, left_index=True, right_index=True, suffixes=('_a2c', '_ppo'))
result = pd.merge(result, df_result_td3, left_index=True, right_index=True,suffixes=('', '_td3'))


df_account_value_a2c.to_csv("df_account_value_a2c.csv")
#baseline stats
print("==============Get Baseline Stats===========")
df_dji_ = get_baseline(
        ticker="^DJI",
        start = TRADE_START_DATE,
        end = TRADE_END_DATE)
stats = backtest_stats(df_dji_, value_col_name = 'close')
df_dji = pd.DataFrame()
df_dji['date'] = df_account_value_a2c['date']
df_dji['account_value'] = df_dji_['close'] / df_dji_['close'][0] * env_kwargs["initial_amount"]
df_dji.to_csv("df_dji.csv")
df_dji = df_dji.set_index(df_dji.columns[0])
df_dji.to_csv("df_dji+.csv")
result = pd.merge(result, df_dji, left_index=True, right_index=True, suffixes=('', '_dji'))
result.columns = ['a2c','ppo', 'tdr','dji']
print("result: ", result)
result.to_csv("result.csv")
# Out:
# ==============Get Baseline Stats===========
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (250, 8)
# Annual return          0.138579
# Cumulative returns     0.137407
# Annual volatility      0.114284
# Sharpe ratio           1.197347
# Calmar ratio           1.536735
# Stability              0.375744
# Max drawdown          -0.090178
# Omega ratio            1.213376
# Sortino ratio          1.790631
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             1.100346
# Daily value at risk   -0.013855
# dtype: float64
# result:                       a2c           ppo           tdr           dji
# date
# 2023-01-03  1.000000e+06  1.000000e+06  1.000000e+06  1.000000e+06
# 2023-01-04  9.991902e+05  9.998602e+05  1.000794e+06  1.004026e+06
# 2023-01-05  9.973156e+05  9.989222e+05  9.979884e+05  9.937744e+05
# 2023-01-06  1.000247e+06  1.000084e+06  1.005523e+06  1.014915e+06
# 2023-01-09  1.001255e+06  1.001690e+06  1.008177e+06  1.011506e+06
# ...                  ...           ...           ...           ...
# 2023-12-21  1.816149e+06  1.473002e+06  1.653741e+06  1.128800e+06
# 2023-12-22  1.815961e+06  1.471690e+06  1.650097e+06  1.128246e+06
# 2023-12-26  1.819696e+06  1.479875e+06  1.658804e+06  1.133055e+06
# 2023-12-27  1.825004e+06  1.487766e+06  1.664856e+06  1.136410e+06
# 2023-12-28  1.829121e+06  1.475698e+06  1.656544e+06  1.138028e+06
#
# [249 rows x 4 columns]

# %%
# %matplotlib inline
plt.rcParams["figure.figsize"] = (15,5)
plt.figure();
result.plot(title="Backtest Results: A2C vs PPO vs TD3");
