# %% [markdown]
# <a href="https://colab.research.google.com/github/hab5510/finrl_project/blob/main/FinRL_with_SentimentAnalysis_averaging.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/AI4Finance-Foundation/FinRL-Tutorials/blob/master/1-Introduction/Stock_NeurIPS2018_SB3.py">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# # Deep Reinforcement Learning for Stock Trading with Sentiment Analysis, Multiple Stock Trading
#
# * **Pytorch Version**

# %% [markdown]
# # Content

# %% [markdown]
# * [1. Task Description](#0)
# * [2. Install Python packages](#1)
#     * [2.1. Install Packages](#1.1)
#     * [2.2. A List of Python Packages](#1.2)
#     * [2.3. Import Packages](#1.3)
#     * [2.4. Create Folders](#1.4)
# * [3. Download and Preprocess Data](#2)
# * [4. Preprocess Data](#3)
#     * [4.1. Technical Indicators](#3.1)
#     * [4.2. Perform Feature Engineering](#3.2)
# * [5. Build Market Environment in OpenAI Gym-style](#4)
#     * [5.1. Data Split](#4.1)
#     * [5.3. Environment for Training](#4.2)
# * [6. Train DRL Agents](#5)
# * [7. Backtesting Performance](#6)
#     * [7.1. BackTestStats](#6.1)
#     * [7.2. BackTestPlot](#6.2)

# %% [markdown]
# <a id='0'></a>
# # Part 1. Task Discription

# %% [markdown]
# We train a DRL agent for stock trading. This task is modeled as a Markov Decision Process (MDP), and the objective function is maximizing (expected) cumulative return.
#
# We specify the state-action-reward as follows:
#
# * **State s**: The state space represents an agent's perception of the market environment. Just like a human trader analyzing various information, here our agent passively observes many features and learns by interacting with the market environment (usually by replaying historical data).
#
# * **Action a**: The action space includes allowed actions that an agent can take at each state. For example, a ∈ {−1, 0, 1}, where −1, 0, 1 represent
# selling, holding, and buying. When an action operates multiple shares, a ∈{−k, ..., −1, 0, 1, ..., k}, e.g.. "Buy
# 10 shares of AAPL" or "Sell 10 shares of AAPL" are 10 or −10, respectively
#
# * **Reward function r(s, a, s′)**: Reward is an incentive for an agent to learn a better policy. For example, it can be the change of the portfolio value when taking a at state s and arriving at new state s',  i.e., r(s, a, s′) = v′ − v, where v′ and v represent the portfolio values at state s′ and s, respectively
#
#
# **Market environment**: 30 consituent stocks of Dow Jones Industrial Average (DJIA) index. Accessed at the starting date of the testing period.
#
#
# The data for this case study is obtained from Yahoo Finance API. The data contains Open-High-Low-Close price and volume.

# %% [markdown]
# <a id='1'></a>
# # Part 2. Install Python Packages

# %% [markdown]
# <a id='1.1'></a>
# ## 2.1. Install packages

# %%
# !pip install numpy==1.26.4 --force-reinstall
# Out:
# Collecting numpy==1.26.4
#   Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 65.0 MB/s eta 0:00:00
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchvision 0.17.2+cpu requires torch==2.2.2, but you have torch 2.7.1 which is incompatible.
# gradio 5.31.0 requires huggingface-hub>=0.28.1, but you have huggingface-hub 0.27.1 which is incompatible.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# fastai 2.7.19 requires torch<2.7,>=1.10, but you have torch 2.7.1 which is incompatible.
# sentence-transformers 4.1.0 requires transformers<5.0.0,>=4.41.0, but you have transformers 4.40.1 which is incompatible.
# Successfully installed numpy-1.26.4

# %%
# !pip install --upgrade pip

# !pip install torch==2.2.2 torchvision==0.17.2 torchaudio==2.2.2 --extra-index-url https://download.pytorch.org/whl/cpu
# !pip install stable-baselines3==2.2.1 sb3-contrib==2.2.1 gymnasium==0.29.1

# !pip install git+https://github.com/AI4Finance-Foundation/FinRL.git

# !pip install transformers==4.41.0 tokenizers==0.19.1 huggingface-hub==0.28.1
# Out:
# Requirement already satisfied: pip in /usr/local/lib/python3.11/dist-packages (25.1.1)
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cpu
# Requirement already satisfied: torch==2.2.2 in /usr/local/lib/python3.11/dist-packages (2.2.2+cpu)
# Requirement already satisfied: torchvision==0.17.2 in /usr/local/lib/python3.11/dist-packages (0.17.2+cpu)
# Requirement already satisfied: torchaudio==2.2.2 in /usr/local/lib/python3.11/dist-packages (2.2.2+cpu)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch==2.2.2) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from torch==2.2.2) (4.14.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.11/dist-packages (from torch==2.2.2) (1.14.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch==2.2.2) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch==2.2.2) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch==2.2.2) (2025.3.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torchvision==0.17.2) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from torchvision==0.17.2) (11.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch==2.2.2) (3.0.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy->torch==2.2.2) (1.3.0)
# Requirement already satisfied: stable-baselines3==2.2.1 in /usr/local/lib/python3.11/dist-packages (2.2.1)
# Requirement already satisfied: sb3-contrib==2.2.1 in /usr/local/lib/python3.11/dist-packages (2.2.1)
# Requirement already satisfied: gymnasium==0.29.1 in /usr/local/lib/python3.11/dist-packages (0.29.1)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.11/dist-packages (from stable-baselines3==2.2.1) (1.26.4)
# Requirement already satisfied: torch>=1.13 in /usr/local/lib/python3.11/dist-packages (from stable-baselines3==2.2.1) (2.2.2+cpu)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.11/dist-packages (from stable-baselines3==2.2.1) (3.1.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from stable-baselines3==2.2.1) (2.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from stable-baselines3==2.2.1) (3.10.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium==0.29.1) (4.14.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from gymnasium==0.29.1) (0.0.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.13->stable-baselines3==2.2.1) (3.18.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.11/dist-packages (from torch>=1.13->stable-baselines3==2.2.1) (1.14.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.13->stable-baselines3==2.2.1) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13->stable-baselines3==2.2.1) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.13->stable-baselines3==2.2.1) (2025.3.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.13->stable-baselines3==2.2.1) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3==2.2.1) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3==2.2.1) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3==2.2.1) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3==2.2.1) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3==2.2.1) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3==2.2.1) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3==2.2.1) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3==2.2.1) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->stable-baselines3==2.2.1) (1.17.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->stable-baselines3==2.2.1) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->stable-baselines3==2.2.1) (2025.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy->torch>=1.13->stable-baselines3==2.2.1) (1.3.0)
# Collecting git+https://github.com/AI4Finance-Foundation/FinRL.git
#   Cloning https://github.com/AI4Finance-Foundation/FinRL.git to /tmp/pip-req-build-3uaiajzp
#   Running command git clone --filter=blob:none --quiet https://github.com/AI4Finance-Foundation/FinRL.git /tmp/pip-req-build-3uaiajzp
#   Resolved https://github.com/AI4Finance-Foundation/FinRL.git to commit 74f9fe43758b5e5b79b2f269ce80bb0a54e72582
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: alpaca-py<0.38,>=0.37 in /usr/local/lib/python3.11/dist-packages (from finrl==0.3.8) (0.37.0)
# Requirement already satisfied: alpaca-trade-api<4,>=3 in /usr/local/lib/python3.11/dist-packages (from finrl==0.3.8) (3.2.0)
# Requirement already satisfied: ccxt<4,>=3 in /usr/local/lib/python3.11/dist-packages (from finrl==0.3.8) (3.1.60)
# Collecting elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git (from finrl==0.3.8)
#   Cloning https://github.com/AI4Finance-Foundation/ElegantRL.git to /tmp/pip-install-_jhxnxdn/elegantrl_c8c50ee59f6a43f89dba0d6ed77733cf
#   Running command git clone --filter=blob:none --quiet https://github.com/AI4Finance-Foundation/ElegantRL.git /tmp/pip-install-_jhxnxdn/elegantrl_c8c50ee59f6a43f89dba0d6ed77733cf
#   Resolved https://github.com/AI4Finance-Foundation/ElegantRL.git to commit 8ea76afc3e7f1564ae9f0e69e70254116d575fe9
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: jqdatasdk<2,>=1 in /usr/local/lib/python3.11/dist-packages (from finrl==0.3.8) (1.9.7)
# Requirement already satisfied: pyfolio-reloaded<0.10,>=0.9 in /usr/local/lib/python3.11/dist-packages (from finrl==0.3.8) (0.9.9)
# Requirement already satisfied: pyportfolioopt<2,>=1 in /usr/local/lib/python3.11/dist-packages (from finrl==0.3.8) (1.5.6)
# Requirement already satisfied: ray<3,>=2 in /usr/local/lib/python3.11/dist-packages (from ray[default,tune]<3,>=2->finrl==0.3.8) (2.47.1)
# Requirement already satisfied: scikit-learn<2,>=1 in /usr/local/lib/python3.11/dist-packages (from finrl==0.3.8) (1.6.1)
# Requirement already satisfied: selenium<5,>=4 in /usr/local/lib/python3.11/dist-packages (from finrl==0.3.8) (4.32.0)
# Requirement already satisfied: stable-baselines3>=2.0.0a5 in /usr/local/lib/python3.11/dist-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (2.2.1)
# Requirement already satisfied: stockstats<0.6,>=0.5 in /usr/local/lib/python3.11/dist-packages (from finrl==0.3.8) (0.5.4)
# Requirement already satisfied: webdriver-manager<5,>=4 in /usr/local/lib/python3.11/dist-packages (from finrl==0.3.8) (4.0.2)
# Requirement already satisfied: wrds<4,>=3 in /usr/local/lib/python3.11/dist-packages (from finrl==0.3.8) (3.3.0)
# Requirement already satisfied: yfinance<0.3,>=0.2 in /usr/local/lib/python3.11/dist-packages (from finrl==0.3.8) (0.2.58)
# Requirement already satisfied: th in /usr/local/lib/python3.11/dist-packages (from elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git->finrl==0.3.8) (0.4.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git->finrl==0.3.8) (1.26.4)
# Requirement already satisfied: gymnasium in /usr/local/lib/python3.11/dist-packages (from elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git->finrl==0.3.8) (0.29.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git->finrl==0.3.8) (3.10.0)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.3 in /usr/local/lib/python3.11/dist-packages (from alpaca-py<0.38,>=0.37->finrl==0.3.8) (1.0.3)
# Requirement already satisfied: pandas>=1.5.3 in /usr/local/lib/python3.11/dist-packages (from alpaca-py<0.38,>=0.37->finrl==0.3.8) (2.2.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.3 in /usr/local/lib/python3.11/dist-packages (from alpaca-py<0.38,>=0.37->finrl==0.3.8) (2.11.7)
# Requirement already satisfied: requests<3.0.0,>=2.30.0 in /usr/local/lib/python3.11/dist-packages (from alpaca-py<0.38,>=0.37->finrl==0.3.8) (2.32.3)
# Requirement already satisfied: sseclient-py<2.0.0,>=1.7.2 in /usr/local/lib/python3.11/dist-packages (from alpaca-py<0.38,>=0.37->finrl==0.3.8) (1.8.0)
# Requirement already satisfied: websockets>=10.4 in /usr/local/lib/python3.11/dist-packages (from alpaca-py<0.38,>=0.37->finrl==0.3.8) (10.4)
# Requirement already satisfied: urllib3<2,>1.24 in /usr/local/lib/python3.11/dist-packages (from alpaca-trade-api<4,>=3->finrl==0.3.8) (1.26.20)
# Requirement already satisfied: websocket-client<2,>=0.56.0 in /usr/local/lib/python3.11/dist-packages (from alpaca-trade-api<4,>=3->finrl==0.3.8) (1.8.0)
# Requirement already satisfied: aiohttp<4,>=3.8.3 in /usr/local/lib/python3.11/dist-packages (from alpaca-trade-api<4,>=3->finrl==0.3.8) (3.11.15)
# Requirement already satisfied: PyYAML==6.0.1 in /usr/local/lib/python3.11/dist-packages (from alpaca-trade-api<4,>=3->finrl==0.3.8) (6.0.1)
# Requirement already satisfied: deprecation==2.1.0 in /usr/local/lib/python3.11/dist-packages (from alpaca-trade-api<4,>=3->finrl==0.3.8) (2.1.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from deprecation==2.1.0->alpaca-trade-api<4,>=3->finrl==0.3.8) (24.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4,>=3.8.3->alpaca-trade-api<4,>=3->finrl==0.3.8) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4,>=3.8.3->alpaca-trade-api<4,>=3->finrl==0.3.8) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4,>=3.8.3->alpaca-trade-api<4,>=3->finrl==0.3.8) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4,>=3.8.3->alpaca-trade-api<4,>=3->finrl==0.3.8) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4,>=3.8.3->alpaca-trade-api<4,>=3->finrl==0.3.8) (6.4.4)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4,>=3.8.3->alpaca-trade-api<4,>=3->finrl==0.3.8) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4,>=3.8.3->alpaca-trade-api<4,>=3->finrl==0.3.8) (1.20.1)
# Requirement already satisfied: setuptools>=60.9.0 in /usr/local/lib/python3.11/dist-packages (from ccxt<4,>=3->finrl==0.3.8) (75.2.0)
# Requirement already satisfied: certifi>=2018.1.18 in /usr/local/lib/python3.11/dist-packages (from ccxt<4,>=3->finrl==0.3.8) (2025.6.15)
# Requirement already satisfied: cryptography>=2.6.1 in /usr/local/lib/python3.11/dist-packages (from ccxt<4,>=3->finrl==0.3.8) (43.0.3)
# Requirement already satisfied: aiodns>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from ccxt<4,>=3->finrl==0.3.8) (3.5.0)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from jqdatasdk<2,>=1->finrl==0.3.8) (1.17.0)
# Requirement already satisfied: SQLAlchemy>=1.2.8 in /usr/local/lib/python3.11/dist-packages (from jqdatasdk<2,>=1->finrl==0.3.8) (2.0.41)
# Requirement already satisfied: pymysql>=0.7.6 in /usr/local/lib/python3.11/dist-packages (from jqdatasdk<2,>=1->finrl==0.3.8) (1.1.1)
# Requirement already satisfied: thriftpy2!=0.5.1,>=0.3.9 in /usr/local/lib/python3.11/dist-packages (from jqdatasdk<2,>=1->finrl==0.3.8) (0.5.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.0.3->alpaca-py<0.38,>=0.37->finrl==0.3.8) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.0.3->alpaca-py<0.38,>=0.37->finrl==0.3.8) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.0.3->alpaca-py<0.38,>=0.37->finrl==0.3.8) (4.14.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.0.3->alpaca-py<0.38,>=0.37->finrl==0.3.8) (0.4.1)
# Requirement already satisfied: ipython>=3.2.3 in /usr/local/lib/python3.11/dist-packages (from pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (7.34.0)
# Requirement already satisfied: pytz>=2014.10 in /usr/local/lib/python3.11/dist-packages (from pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (2025.2)
# Requirement already satisfied: scipy>=0.14.0 in /usr/local/lib/python3.11/dist-packages (from pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (1.15.3)
# Requirement already satisfied: seaborn>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (0.13.2)
# Requirement already satisfied: empyrical-reloaded>=0.5.9 in /usr/local/lib/python3.11/dist-packages (from pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (0.5.12)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.5.3->alpaca-py<0.38,>=0.37->finrl==0.3.8) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.5.3->alpaca-py<0.38,>=0.37->finrl==0.3.8) (2025.2)
# Requirement already satisfied: cvxpy>=1.1.19 in /usr/local/lib/python3.11/dist-packages (from pyportfolioopt<2,>=1->finrl==0.3.8) (1.6.6)
# Requirement already satisfied: ecos<3.0.0,>=2.0.14 in /usr/local/lib/python3.11/dist-packages (from pyportfolioopt<2,>=1->finrl==0.3.8) (2.0.14)
# Requirement already satisfied: plotly<6.0.0,>=5.0.0 in /usr/local/lib/python3.11/dist-packages (from pyportfolioopt<2,>=1->finrl==0.3.8) (5.24.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly<6.0.0,>=5.0.0->pyportfolioopt<2,>=1->finrl==0.3.8) (8.5.0)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.11/dist-packages (from ray<3,>=2->ray[default,tune]<3,>=2->finrl==0.3.8) (8.2.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from ray<3,>=2->ray[default,tune]<3,>=2->finrl==0.3.8) (3.18.0)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.11/dist-packages (from ray<3,>=2->ray[default,tune]<3,>=2->finrl==0.3.8) (4.24.0)
# Requirement already satisfied: protobuf!=3.19.5,>=3.15.3 in /usr/local/lib/python3.11/dist-packages (from ray<3,>=2->ray[default,tune]<3,>=2->finrl==0.3.8) (5.29.5)
# Requirement already satisfied: aiohttp_cors in /usr/local/lib/python3.11/dist-packages (from ray[default,tune]<3,>=2->finrl==0.3.8) (0.8.1)
# Requirement already satisfied: colorful in /usr/local/lib/python3.11/dist-packages (from ray[default,tune]<3,>=2->finrl==0.3.8) (0.5.6)
# Requirement already satisfied: py-spy>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from ray[default,tune]<3,>=2->finrl==0.3.8) (0.4.0)
# Requirement already satisfied: grpcio>=1.42.0 in /usr/local/lib/python3.11/dist-packages (from ray[default,tune]<3,>=2->finrl==0.3.8) (1.73.0)
# Requirement already satisfied: opencensus in /usr/local/lib/python3.11/dist-packages (from ray[default,tune]<3,>=2->finrl==0.3.8) (0.11.4)
# Requirement already satisfied: opentelemetry-sdk in /usr/local/lib/python3.11/dist-packages (from ray[default,tune]<3,>=2->finrl==0.3.8) (1.34.1)
# Requirement already satisfied: opentelemetry-exporter-prometheus in /usr/local/lib/python3.11/dist-packages (from ray[default,tune]<3,>=2->finrl==0.3.8) (0.55b1)
# Requirement already satisfied: opentelemetry-proto in /usr/local/lib/python3.11/dist-packages (from ray[default,tune]<3,>=2->finrl==0.3.8) (1.34.1)
# Requirement already satisfied: prometheus_client>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from ray[default,tune]<3,>=2->finrl==0.3.8) (0.22.1)
# Requirement already satisfied: smart_open in /usr/local/lib/python3.11/dist-packages (from ray[default,tune]<3,>=2->finrl==0.3.8) (7.1.0)
# Requirement already satisfied: virtualenv!=20.21.1,>=20.0.24 in /usr/local/lib/python3.11/dist-packages (from ray[default,tune]<3,>=2->finrl==0.3.8) (20.31.2)
# Requirement already satisfied: tensorboardX>=1.9 in /usr/local/lib/python3.11/dist-packages (from ray[default,tune]<3,>=2->finrl==0.3.8) (2.6.4)
# Requirement already satisfied: pyarrow>=9.0.0 in /usr/local/lib/python3.11/dist-packages (from ray[default,tune]<3,>=2->finrl==0.3.8) (18.1.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from ray[default,tune]<3,>=2->finrl==0.3.8) (2025.3.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.30.0->alpaca-py<0.38,>=0.37->finrl==0.3.8) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.30.0->alpaca-py<0.38,>=0.37->finrl==0.3.8) (3.10)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn<2,>=1->finrl==0.3.8) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn<2,>=1->finrl==0.3.8) (3.6.0)
# Requirement already satisfied: trio~=0.17 in /usr/local/lib/python3.11/dist-packages (from selenium<5,>=4->finrl==0.3.8) (0.30.0)
# Requirement already satisfied: trio-websocket~=0.9 in /usr/local/lib/python3.11/dist-packages (from selenium<5,>=4->finrl==0.3.8) (0.12.2)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.11/dist-packages (from trio~=0.17->selenium<5,>=4->finrl==0.3.8) (2.4.0)
# Requirement already satisfied: outcome in /usr/local/lib/python3.11/dist-packages (from trio~=0.17->selenium<5,>=4->finrl==0.3.8) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from trio~=0.17->selenium<5,>=4->finrl==0.3.8) (1.3.1)
# Requirement already satisfied: wsproto>=0.14 in /usr/local/lib/python3.11/dist-packages (from trio-websocket~=0.9->selenium<5,>=4->finrl==0.3.8) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in /usr/local/lib/python3.11/dist-packages (from urllib3[socks]<3,>=1.26->selenium<5,>=4->finrl==0.3.8) (1.7.1)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.11/dist-packages (from webdriver-manager<5,>=4->finrl==0.3.8) (1.1.1)
# Requirement already satisfied: psycopg2-binary<2.10,>=2.9 in /usr/local/lib/python3.11/dist-packages (from wrds<4,>=3->finrl==0.3.8) (2.9.10)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from SQLAlchemy>=1.2.8->jqdatasdk<2,>=1->finrl==0.3.8) (3.2.3)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.11/dist-packages (from yfinance<0.3,>=0.2->finrl==0.3.8) (0.0.11)
# Requirement already satisfied: platformdirs>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from yfinance<0.3,>=0.2->finrl==0.3.8) (4.3.8)
# Requirement already satisfied: frozendict>=2.3.4 in /usr/local/lib/python3.11/dist-packages (from yfinance<0.3,>=0.2->finrl==0.3.8) (2.4.6)
# Requirement already satisfied: peewee>=3.16.2 in /usr/local/lib/python3.11/dist-packages (from yfinance<0.3,>=0.2->finrl==0.3.8) (3.17.3)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /usr/local/lib/python3.11/dist-packages (from yfinance<0.3,>=0.2->finrl==0.3.8) (4.13.4)
# Requirement already satisfied: curl_cffi>=0.7 in /usr/local/lib/python3.11/dist-packages (from yfinance<0.3,>=0.2->finrl==0.3.8) (0.11.4)
# Requirement already satisfied: pycares>=4.9.0 in /usr/local/lib/python3.11/dist-packages (from aiodns>=1.1.1->ccxt<4,>=3->finrl==0.3.8) (4.9.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4>=4.11.1->yfinance<0.3,>=0.2->finrl==0.3.8) (2.7)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.11/dist-packages (from cryptography>=2.6.1->ccxt<4,>=3->finrl==0.3.8) (1.17.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.12->cryptography>=2.6.1->ccxt<4,>=3->finrl==0.3.8) (2.22)
# Requirement already satisfied: osqp>=0.6.2 in /usr/local/lib/python3.11/dist-packages (from cvxpy>=1.1.19->pyportfolioopt<2,>=1->finrl==0.3.8) (1.0.4)
# Requirement already satisfied: clarabel>=0.5.0 in /usr/local/lib/python3.11/dist-packages (from cvxpy>=1.1.19->pyportfolioopt<2,>=1->finrl==0.3.8) (0.11.1)
# Requirement already satisfied: scs>=3.2.4.post1 in /usr/local/lib/python3.11/dist-packages (from cvxpy>=1.1.19->pyportfolioopt<2,>=1->finrl==0.3.8) (3.2.7.post2)
# Requirement already satisfied: bottleneck>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from empyrical-reloaded>=0.5.9->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (1.4.2)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.11/dist-packages (from ipython>=3.2.3->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (0.19.2)
# Requirement already satisfied: decorator in /usr/local/lib/python3.11/dist-packages (from ipython>=3.2.3->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.11/dist-packages (from ipython>=3.2.3->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.11/dist-packages (from ipython>=3.2.3->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from ipython>=3.2.3->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (3.0.51)
# Requirement already satisfied: pygments in /usr/local/lib/python3.11/dist-packages (from ipython>=3.2.3->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (2.19.2)
# Requirement already satisfied: backcall in /usr/local/lib/python3.11/dist-packages (from ipython>=3.2.3->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.11/dist-packages (from ipython>=3.2.3->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.11/dist-packages (from ipython>=3.2.3->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (4.9.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=3.2.3->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.11/dist-packages (from jedi>=0.16->ipython>=3.2.3->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (0.8.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git->finrl==0.3.8) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git->finrl==0.3.8) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git->finrl==0.3.8) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git->finrl==0.3.8) (1.4.8)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git->finrl==0.3.8) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git->finrl==0.3.8) (3.2.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from osqp>=0.6.2->cvxpy>=1.1.19->pyportfolioopt<2,>=1->finrl==0.3.8) (3.1.6)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.11/dist-packages (from pexpect>4.3->ipython>=3.2.3->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (0.7.0)
# Requirement already satisfied: torch>=1.13 in /usr/local/lib/python3.11/dist-packages (from stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (2.2.2+cpu)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.11/dist-packages (from stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (3.1.1)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from gymnasium->elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git->finrl==0.3.8) (0.0.4)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.11/dist-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (4.11.0.86)
# Requirement already satisfied: pygame in /usr/local/lib/python3.11/dist-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (2.6.1)
# Requirement already satisfied: tensorboard>=2.9.1 in /usr/local/lib/python3.11/dist-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (2.18.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (5.9.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (4.67.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (13.9.4)
# Requirement already satisfied: shimmy~=1.3.0 in /usr/local/lib/python3.11/dist-packages (from shimmy[atari]~=1.3.0; extra == "extra"->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (1.3.0)
# Requirement already satisfied: autorom~=0.6.1 in /usr/local/lib/python3.11/dist-packages (from autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (0.6.1)
# Requirement already satisfied: AutoROM.accept-rom-license in /usr/local/lib/python3.11/dist-packages (from autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (0.6.1)
# Requirement already satisfied: ale-py~=0.8.1 in /usr/local/lib/python3.11/dist-packages (from shimmy[atari]~=1.3.0; extra == "extra"->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (0.8.1)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.11/dist-packages (from ale-py~=0.8.1->shimmy[atari]~=1.3.0; extra == "extra"->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (6.5.2)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.11/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (1.4.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (3.8.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (3.1.3)
# Requirement already satisfied: Cython>=3.0.10 in /usr/local/lib/python3.11/dist-packages (from thriftpy2!=0.5.1,>=0.3.9->jqdatasdk<2,>=1->finrl==0.3.8) (3.0.12)
# Requirement already satisfied: ply<4.0,>=3.4 in /usr/local/lib/python3.11/dist-packages (from thriftpy2!=0.5.1,>=0.3.9->jqdatasdk<2,>=1->finrl==0.3.8) (3.11)
# Requirement already satisfied: sympy in /usr/local/lib/python3.11/dist-packages (from torch>=1.13->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (1.14.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.13->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (3.5)
# Requirement already satisfied: distlib<1,>=0.3.7 in /usr/local/lib/python3.11/dist-packages (from virtualenv!=20.21.1,>=20.0.24->ray[default,tune]<3,>=2->finrl==0.3.8) (0.3.9)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (3.0.2)
# Requirement already satisfied: h11<1,>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium<5,>=4->finrl==0.3.8) (0.16.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema->ray<3,>=2->ray[default,tune]<3,>=2->finrl==0.3.8) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema->ray<3,>=2->ray[default,tune]<3,>=2->finrl==0.3.8) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema->ray<3,>=2->ray[default,tune]<3,>=2->finrl==0.3.8) (0.25.1)
# Requirement already satisfied: opencensus-context>=0.1.3 in /usr/local/lib/python3.11/dist-packages (from opencensus->ray[default,tune]<3,>=2->finrl==0.3.8) (0.1.3)
# Requirement already satisfied: google-api-core<3.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from opencensus->ray[default,tune]<3,>=2->finrl==0.3.8) (2.25.1)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<3,>=2->finrl==0.3.8) (1.70.0)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /usr/local/lib/python3.11/dist-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<3,>=2->finrl==0.3.8) (1.26.1)
# Requirement already satisfied: google-auth<3.0.0,>=2.14.1 in /usr/local/lib/python3.11/dist-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<3,>=2->finrl==0.3.8) (2.38.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from google-auth<3.0.0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<3,>=2->finrl==0.3.8) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth<3.0.0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<3,>=2->finrl==0.3.8) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth<3.0.0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<3,>=2->finrl==0.3.8) (4.9.1)
# Requirement already satisfied: pyasn1>=0.1.3 in /usr/local/lib/python3.11/dist-packages (from rsa<5,>=3.1.4->google-auth<3.0.0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<3,>=2->finrl==0.3.8) (0.6.1)
# Requirement already satisfied: opentelemetry-api~=1.12 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-exporter-prometheus->ray[default,tune]<3,>=2->finrl==0.3.8) (1.34.1)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-api~=1.12->opentelemetry-exporter-prometheus->ray[default,tune]<3,>=2->finrl==0.3.8) (8.7.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api~=1.12->opentelemetry-exporter-prometheus->ray[default,tune]<3,>=2->finrl==0.3.8) (3.23.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.55b1 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-sdk->ray[default,tune]<3,>=2->finrl==0.3.8) (0.55b1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (3.0.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (0.1.2)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.11/dist-packages (from smart_open->ray[default,tune]<3,>=2->finrl==0.3.8) (1.17.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy->torch>=1.13->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (1.3.0)
# Requirement already satisfied: niltype<2.0,>=0.3 in /usr/local/lib/python3.11/dist-packages (from th->elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git->finrl==0.3.8) (1.0.2)
# Collecting transformers==4.41.0
#   Downloading transformers-4.41.0-py3-none-any.whl.metadata (43 kB)
# Requirement already satisfied: tokenizers==0.19.1 in /usr/local/lib/python3.11/dist-packages (0.19.1)
# Collecting huggingface-hub==0.28.1
#   Downloading huggingface_hub-0.28.1-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers==4.41.0) (3.18.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers==4.41.0) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers==4.41.0) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers==4.41.0) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers==4.41.0) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers==4.41.0) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from transformers==4.41.0) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers==4.41.0) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub==0.28.1) (2025.3.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub==0.28.1) (4.14.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.41.0) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.41.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.41.0) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.41.0) (2025.6.15)
# Downloading transformers-4.41.0-py3-none-any.whl (9.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 82.0 MB/s eta 0:00:00
# Downloading huggingface_hub-0.28.1-py3-none-any.whl (464 kB)
# Installing collected packages: huggingface-hub, transformers
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface-hub 0.28.0
#     Uninstalling huggingface-hub-0.28.0:
#       Successfully uninstalled huggingface-hub-0.28.0
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.40.1
#     Uninstalling transformers-4.40.1:
#       Successfully uninstalled transformers-4.40.1
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [transformers]
# Successfully installed huggingface-hub-0.28.1 transformers-4.41.0

# %% [markdown]
# <a id='1.2'></a>
# ## 2.2. A list of Python packages
# * Yahoo Finance API
# * pandas
# * numpy
# * matplotlib
# * stockstats
# * OpenAI gym
# * stable-baselines
# * tensorflow
# * pyfolio

# %% [markdown]
# <a id='1.3'></a>
# ## 2.3. Import Packages

# %%
# !pip install pandas_market_calendars
# Out:
# Collecting pandas_market_calendars
#   Downloading pandas_market_calendars-5.1.1-py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: pandas>=1.1 in /usr/local/lib/python3.11/dist-packages (from pandas_market_calendars) (2.2.2)
# Requirement already satisfied: tzdata in /usr/local/lib/python3.11/dist-packages (from pandas_market_calendars) (2025.2)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.11/dist-packages (from pandas_market_calendars) (2.9.0.post0)
# Collecting exchange-calendars>=3.3 (from pandas_market_calendars)
#   Downloading exchange_calendars-4.10.1-py3-none-any.whl.metadata (37 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from exchange-calendars>=3.3->pandas_market_calendars) (1.26.4)
# Collecting pyluach (from exchange-calendars>=3.3->pandas_market_calendars)
#   Downloading pyluach-2.2.0-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: toolz in /usr/local/lib/python3.11/dist-packages (from exchange-calendars>=3.3->pandas_market_calendars) (0.12.1)
# Collecting korean_lunar_calendar (from exchange-calendars>=3.3->pandas_market_calendars)
#   Downloading korean_lunar_calendar-0.3.1-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1->pandas_market_calendars) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil->pandas_market_calendars) (1.17.0)
# Downloading pandas_market_calendars-5.1.1-py3-none-any.whl (127 kB)
# Downloading exchange_calendars-4.10.1-py3-none-any.whl (200 kB)
# Downloading korean_lunar_calendar-0.3.1-py3-none-any.whl (9.0 kB)
# Downloading pyluach-2.2.0-py3-none-any.whl (25 kB)
# Installing collected packages: korean_lunar_calendar, pyluach, exchange-calendars, pandas_market_calendars
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [pandas_market_calendars]
# Successfully installed exchange-calendars-4.10.1 korean_lunar_calendar-0.3.1 pandas_market_calendars-5.1.1 pyluach-2.2.0

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# matplotlib.use('Agg')
import datetime

# %matplotlib inline
from finrl.meta.preprocessor.yahoodownloader import YahooDownloader
from finrl.meta.preprocessor.preprocessors import FeatureEngineer, data_split
from finrl.meta.env_stock_trading.env_stocktrading import StockTradingEnv
from finrl.agents.stablebaselines3.models import DRLAgent
from stable_baselines3.common.logger import configure
from finrl.meta.data_processor import DataProcessor

from finrl.plot import backtest_stats, backtest_plot, get_daily_return, get_baseline
from pprint import pprint

import sys
sys.path.append("../FinRL")

import itertools
# Out:
# /usr/local/lib/python3.11/dist-packages/pandas_datareader/compat/__init__.py:11: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   PANDAS_VERSION = LooseVersion(pd.__version__)
# /usr/local/lib/python3.11/dist-packages/pyfolio/pos.py:25: UserWarning: Module "zipline.assets" not found; multipliers will not be applied to position notionals.
#   warnings.warn(

# %% [markdown]
# <a id='1.4'></a>
# ## 2.4. Create Folders

# %%
from finrl import config
from finrl import config_tickers
import os
from finrl.main import check_and_make_directories
from finrl.config import (
    DATA_SAVE_DIR,
    TRAINED_MODEL_DIR,
    TENSORBOARD_LOG_DIR,
    RESULTS_DIR,
    INDICATORS,
    TRAIN_START_DATE,
    TRAIN_END_DATE,
    TEST_START_DATE,
    TEST_END_DATE,
    TRADE_START_DATE,
    TRADE_END_DATE,
)
check_and_make_directories([DATA_SAVE_DIR, TRAINED_MODEL_DIR, TENSORBOARD_LOG_DIR, RESULTS_DIR])

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# <a id='2'></a>
# # Part 3. Download Data
# Yahoo Finance provides stock data, financial news, financial reports, etc. Yahoo Finance is free.
# * FinRL uses a class **YahooDownloader** in FinRL-Meta to fetch data via Yahoo Finance API
# * Call Limit: Using the Public API (without authentication), you are limited to 2,000 requests per hour per IP (or up to a total of 48,000 requests a day).

# %% [markdown]
# -----
# class YahooDownloader:
#     Retrieving daily stock data from
#     Yahoo Finance API
#
#     Attributes
#     ----------
#         start_date : str
#             start date of the data (modified from config.py)
#         end_date : str
#             end date of the data (modified from config.py)
#         ticker_list : list
#             a list of stock tickers (modified from config.py)
#
#     Methods
#     -------
#     fetch_data()

# %%
TRAIN_START_DATE = '2020-01-01'
TRAIN_END_DATE = '2023-01-01'
TRADE_START_DATE = '2023-01-01'
TRADE_END_DATE = '2023-12-31'

# %%
top10_tickers = ['AAPL','MSFT','AMZN','GOOGL','META',
                 'NVDA','JPM','TSLA','BA','DIS']

df = YahooDownloader(start_date = TRAIN_START_DATE,
                     end_date = TRADE_END_DATE,
                     ticker_list = top10_tickers).fetch_data()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (10060, 8)

# %%
df.shape
# Out:
# (10060, 8)

# %%
df.sort_values(['date','tic'],ignore_index=True).head()
# Out:
# Price        date       close        high         low        open     volume  \
# 0      2020-01-02   72.620842   72.681289   71.373218   71.627092  135480400
# 1      2020-01-02   94.900497   94.900497   93.207497   93.750000   80580000
# 2      2020-01-02  331.348572  331.378393  325.761816  326.606765    4544400
# 3      2020-01-02  145.769913  145.769913  142.720753  142.907625    9502100
# 4      2020-01-02   68.026016   68.026016   66.923134   67.018562   27278000
#
# Price    tic  day
# 0       AAPL    3
# 1       AMZN    3
# 2         BA    3
# 3        DIS    3
# 4      GOOGL    3

# %% [markdown]
# # Part 4: Preprocess Data
# We need to check for missing data and do feature engineering to convert the data point into a state.
# * **Adding technical indicators**. In practical trading, various information needs to be taken into account, such as historical prices, current holding shares, technical indicators, etc. Here, we demonstrate two trend-following technical indicators: MACD and RSI.
# * **Adding turbulence index**. Risk-aversion reflects whether an investor prefers to protect the capital. It also influences one's trading strategy when facing different market volatility level. To control the risk in a worst-case scenario, such as financial crisis of 2007–2008, FinRL employs the turbulence index that measures extreme fluctuation of asset price.

# %%
fe = FeatureEngineer(
                    use_technical_indicator=True,
                    tech_indicator_list = INDICATORS,
                    use_vix=True,
                    use_turbulence=True,
                    user_defined_feature = False)

processed = fe.preprocess_data(df)
# Out:
# Successfully added technical indicators
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (1005, 8)
# Successfully added vix
# Successfully added turbulence index

# %% [markdown]
# ## Adding Sentiment Analysis Score

# %% [markdown]
# The dataset used here is a Financial News Dataset **FNSPID** from https://github.com/Zdong104/FNSPID_Financial_News_Dataset.
# It is available at https://huggingface.co/datasets/Zihan1004/FNSPIDfrom where it was directly downloaded as csv and uploaded below.
#
# >
# FNSPID (Financial News and Stock Price Integration Dataset), is a comprehensive financial dataset designed to enhance stock market predictions by combining quantitative and qualitative data. It contains 29.7 million stock prices and 15.7 million financial news records for 4,775 S&P500 companies from 1999 to 2023, gathered from four stock market news websites. This dataset stands out for its scale, diversity, and unique incorporation of sentiment information from financial news. Research using FNSPID has shown that its extensive size and quality can significantly improve the accuracy of market predictions. Furthermore, integrating sentiment scores into analyses modestly boosts the performance of transformer-based models. FNSPID also introduces a reproducible method for dataset updates, offering valuable resources for financial research, including complete work, code, documentation, and examples available online. This dataset presents new opportunities for advancing predictive modeling and analysis in the financial research community.

# %%
import pandas as pd

with open("/content/drive/MyDrive/fnspid_news.csv", "r") as f:
    header = f.readline().strip().split(",")
print("CSV columns:", header[:20])    # show first 20 column names
# Out:
# CSV columns: ['Unnamed: 0', 'Date', 'Article_title', 'Stock_symbol', 'Url', 'Publisher', 'Author', 'Article', 'Lsa_summary', 'Luhn_summary', 'Textrank_summary', 'Lexrank_summary']

# %%
import pandas as pd

FILE       = "/content/drive/MyDrive/fnspid_news.csv"
COLS       = ["Date", "Article_title", "Stock_symbol"]
TOP10      = set(['AAPL','MSFT','AMZN','GOOGL','META',
                  'NVDA','JPM','TSLA','BA','DIS'])
DATE_MIN   = "2020-01-01"
DATE_MAX   = "2023-12-31"

chunksize  = 250_000

keep_rows  = []             # list of filtered chunks

for i,chunk in enumerate(pd.read_csv(FILE,
                                     usecols=COLS,
                                     chunksize=chunksize,
                                     dtype={"Stock_symbol":"category"},
                                     engine="c",
                                     low_memory=True)):
    # fast date filter (string compare is OK before to_datetime)
    mask_date   = (chunk["Date"] >= DATE_MIN) & (chunk["Date"] <= DATE_MAX)
    mask_ticker = chunk["Stock_symbol"].isin(TOP10)
    sub         = chunk.loc[mask_date & mask_ticker, COLS]
    if not sub.empty:
        keep_rows.append(sub)
    print(f"processed chunk {i+1}, kept {len(sub)} rows")

# concatenate all kept pieces
df_news = pd.concat(keep_rows, ignore_index=True)

# rename & convert date
df_news = df_news.rename(columns={
    "Date": "date",
    "Article_title": "headline",
    "Stock_symbol": "ticker"
})
df_news["date"] = pd.to_datetime(df_news["date"])

print("Final shape:", df_news.shape)
df_news.head()
# Out:
# processed chunk 1, kept 13647 rows
# processed chunk 2, kept 4035 rows
# processed chunk 3, kept 1732 rows
# processed chunk 4, kept 6128 rows
# processed chunk 5, kept 0 rows
# processed chunk 6, kept 8737 rows
# processed chunk 7, kept 8716 rows
# processed chunk 8, kept 0 rows
# processed chunk 9, kept 8712 rows
# processed chunk 10, kept 441 rows
# processed chunk 11, kept 288 rows
# processed chunk 12, kept 10 rows
# processed chunk 13, kept 524 rows
# processed chunk 14, kept 309 rows
# processed chunk 15, kept 1142 rows
# processed chunk 16, kept 0 rows
# processed chunk 17, kept 0 rows
# processed chunk 18, kept 0 rows
# processed chunk 19, kept 32 rows
# processed chunk 20, kept 0 rows
# processed chunk 21, kept 747 rows
# processed chunk 22, kept 175 rows
# processed chunk 23, kept 650 rows
# processed chunk 24, kept 0 rows
# processed chunk 25, kept 0 rows
# processed chunk 26, kept 0 rows
# processed chunk 27, kept 0 rows
# processed chunk 28, kept 0 rows
# processed chunk 29, kept 0 rows
# processed chunk 30, kept 0 rows
# processed chunk 31, kept 0 rows
# processed chunk 32, kept 0 rows
# processed chunk 33, kept 0 rows
# processed chunk 34, kept 0 rows
# processed chunk 35, kept 0 rows
# processed chunk 36, kept 0 rows
# processed chunk 37, kept 0 rows
# processed chunk 38, kept 0 rows
# processed chunk 39, kept 0 rows
# processed chunk 40, kept 0 rows
# processed chunk 41, kept 0 rows
# processed chunk 42, kept 0 rows
# processed chunk 43, kept 0 rows
# processed chunk 44, kept 0 rows
# processed chunk 45, kept 0 rows
# processed chunk 46, kept 0 rows
# processed chunk 47, kept 0 rows
# processed chunk 48, kept 0 rows
# processed chunk 49, kept 0 rows
# processed chunk 50, kept 0 rows
# processed chunk 51, kept 0 rows
# processed chunk 52, kept 0 rows
# processed chunk 53, kept 0 rows
# processed chunk 54, kept 0 rows
# processed chunk 55, kept 0 rows
# processed chunk 56, kept 0 rows
# processed chunk 57, kept 0 rows
# processed chunk 58, kept 0 rows
# processed chunk 59, kept 0 rows
# processed chunk 60, kept 0 rows
# processed chunk 61, kept 0 rows
# processed chunk 62, kept 0 rows
# processed chunk 63, kept 0 rows
# Final shape: (56025, 3)
#                        date  \
# 0 2023-12-16 22:00:00+00:00
# 1 2023-12-16 22:00:00+00:00
# 2 2023-12-16 21:00:00+00:00
# 3 2023-12-16 21:00:00+00:00
# 4 2023-12-16 21:00:00+00:00
#
#                                             headline ticker
# 0  My 6 Largest Portfolio Holdings Heading Into 2...   AAPL
# 1  Brokers Suggest Investing in Apple (AAPL): Rea...   AAPL
# 2                      Company News for Dec 19, 2023   AAPL
# 3  NVIDIA (NVDA) Up 243% YTD: Will It Carry Momen...   AAPL
# 4  Pre-Market Most Active for Dec 19, 2023 : BMY,...   AAPL

# %%
import torch, time
from transformers import AutoTokenizer, AutoModelForSequenceClassification
import pandas as pd

# Load FinBERT
tokenizer = AutoTokenizer.from_pretrained("yiyanghkust/finbert-tone")
model     = AutoModelForSequenceClassification.from_pretrained("yiyanghkust/finbert-tone")
model.eval()

def classify_headlines(texts, batch_size=8, log_every=500):
    results, t0 = [], time.time()
    for i in range(0, len(texts), batch_size):
        batch = texts[i:i+batch_size]
        encodings = tokenizer(batch, padding=True, truncation=True,
                              max_length=48, return_tensors="pt")
        with torch.no_grad():
            logits = model(**encodings).logits
        preds = torch.argmax(logits, dim=1).tolist()
        results.extend({0:-1, 1:0, 2:1}[p] for p in preds)
        if i % log_every == 0 and i > 0:
            print(f"{i}/{len(texts)} processed ({time.time()-t0:.1f}s)")
    return results
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/file_download.py:795: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json:   0%|          | 0.00/533 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/439M [00:00<?, ?B/s]

# %%
df_news.head()
# Out:
#                        date  \
# 0 2023-12-16 22:00:00+00:00
# 1 2023-12-16 22:00:00+00:00
# 2 2023-12-16 21:00:00+00:00
# 3 2023-12-16 21:00:00+00:00
# 4 2023-12-16 21:00:00+00:00
#
#                                             headline ticker
# 0  My 6 Largest Portfolio Holdings Heading Into 2...   AAPL
# 1  Brokers Suggest Investing in Apple (AAPL): Rea...   AAPL
# 2                      Company News for Dec 19, 2023   AAPL
# 3  NVIDIA (NVDA) Up 243% YTD: Will It Carry Momen...   AAPL
# 4  Pre-Market Most Active for Dec 19, 2023 : BMY,...   AAPL

# %%
df_news["score"] = classify_headlines(df_news["headline"].tolist())
# Out:
# 1000/56025 processed (107.6s)
# 2000/56025 processed (204.3s)
# 3000/56025 processed (308.4s)
# 4000/56025 processed (402.5s)
# 5000/56025 processed (498.3s)
# 6000/56025 processed (598.1s)
# 7000/56025 processed (700.8s)
# 8000/56025 processed (796.5s)
# 9000/56025 processed (897.4s)
# 10000/56025 processed (992.1s)
# 11000/56025 processed (1083.1s)
# 12000/56025 processed (1179.4s)
# 13000/56025 processed (1277.3s)
# 14000/56025 processed (1367.9s)
# 15000/56025 processed (1444.5s)
# 16000/56025 processed (1533.0s)
# 17000/56025 processed (1618.6s)
# 18000/56025 processed (1697.7s)
# 19000/56025 processed (1779.3s)
# 20000/56025 processed (1861.5s)
# 21000/56025 processed (1944.1s)
# 22000/56025 processed (2025.7s)
# 23000/56025 processed (2101.9s)
# 24000/56025 processed (2179.5s)
# 25000/56025 processed (2259.9s)
# 26000/56025 processed (2345.3s)
# 27000/56025 processed (2434.3s)
# 28000/56025 processed (2524.6s)
# 29000/56025 processed (2607.8s)
# 30000/56025 processed (2693.0s)
# 31000/56025 processed (2777.8s)
# 32000/56025 processed (2863.2s)
# 33000/56025 processed (2948.9s)
# 34000/56025 processed (3033.9s)
# 35000/56025 processed (3122.5s)
# 36000/56025 processed (3207.2s)
# 37000/56025 processed (3298.1s)
# 38000/56025 processed (3382.5s)
# 39000/56025 processed (3466.2s)
# 40000/56025 processed (3545.6s)
# 41000/56025 processed (3629.7s)
# 42000/56025 processed (3755.0s)
# 43000/56025 processed (3833.8s)
# 44000/56025 processed (3940.7s)
# 45000/56025 processed (4045.5s)
# 46000/56025 processed (4142.8s)
# 47000/56025 processed (4238.6s)
# 48000/56025 processed (4348.2s)
# 49000/56025 processed (4454.8s)
# 50000/56025 processed (4556.0s)
# 51000/56025 processed (4639.3s)
# 52000/56025 processed (4736.4s)
# 53000/56025 processed (4857.6s)
# 54000/56025 processed (4989.4s)
# 55000/56025 processed (5104.7s)
# 56000/56025 processed (5202.4s)

# %%
df_news.to_csv("scored_news.csv", index=False)       #  saves 56 k rows with sentiment

# %%
df_news = pd.read_csv("scored_news.csv")

# %%
daily_sent = (df_news[["date","ticker","score"]]
              .groupby(["date","ticker"]).mean().reset_index()
              .rename(columns={"score":"sentiment_score"}))
daily_sent.to_csv("daily_sentiment.csv", index=False)    # tiny (~10 k rows)

# %%
# Daily mean
daily_sent = (df_news[["date", "ticker", "score"]]
              .groupby(["date", "ticker"]).mean()
              .rename(columns={"score": "sentiment_score"})
              .reset_index())

# Apply rolling average
daily_sent['date'] = pd.to_datetime(daily_sent['date'])
daily_sent = daily_sent.sort_values(['ticker', 'date'])
daily_sent['sentiment_score'] = daily_sent.groupby('ticker')['sentiment_score'].transform(
    lambda x: x.rolling(window=3, min_periods=1).mean()
)

daily_sent.to_csv("daily_sentiment_rolling_average.csv", index=False)

# %%
daily_sent = pd.read_csv("daily_sentiment_rolling_average.csv")

processed["date"]  = pd.to_datetime(processed["date"]).dt.strftime("%Y-%m-%d")
daily_sent["date"] = pd.to_datetime(daily_sent["date"]).dt.strftime("%Y-%m-%d")

processed = processed.merge(
    daily_sent,
    left_on=["date", "tic"],
    right_on=["date", "ticker"],
    how="left"
)

# Fill NaN sentiment with 0
processed["sentiment_score"] = processed["sentiment_score"].fillna(0)

# Drop the extra 'ticker' column if it exists
if "ticker" in processed.columns:
    processed = processed.drop(columns=["ticker"])

# %%
# build processed_full so the RL environment sees every (date, ticker)
list_ticker = processed["tic"].unique().tolist()
list_date   = list(pd.date_range(processed['date'].min(),
                                 processed['date'].max()).astype(str))
combination = list(itertools.product(list_date, list_ticker))

processed_full = (
    pd.DataFrame(combination, columns=["date", "tic"])
      .merge(processed, on=["date", "tic"], how="left")
)
processed_full = processed_full[processed_full['date'].isin(processed['date'])]
processed_full = processed_full.sort_values(['date', 'tic'])
processed_full = processed_full.fillna(0)

# %%
processed_full.to_csv("processed_full_rolling_average.csv", index=False)

# %% [markdown]
# <a id='4'></a>
# # Part 5. Build A Market Environment in OpenAI Gym-style
# The training process involves observing stock price change, taking an action and reward's calculation. By interacting with the market environment, the agent will eventually derive a trading strategy that may maximize (expected) rewards.
#
# Our market environment, based on OpenAI Gym, simulates stock markets with historical market data.

# %% [markdown]
# ## Data Split
# We split the data into training set and testing set as follows:
#
# Training data period: 2009-01-01 to 2020-07-01
#
# Trading data period: 2020-07-01 to 2021-10-31

# %%
INDICATORS = [
    'macd', 'boll_ub', 'boll_lb', 'rsi_30', 'cci_30', 'dx_30',
    'close_30_sma', 'close_60_sma', 'sentiment_score', 'vix', 'turbulence'
]

# %%
# Keep only the valid columns

VALID_COLUMNS = ['date', 'tic', 'open', 'high', 'low', 'close', 'volume','day'] + INDICATORS
processed_full = pd.read_csv("processed_full_rolling_average.csv")
processed_full = processed_full[VALID_COLUMNS]
processed_full.dropna(inplace=True)

# %%
processed_full.sort_values(['date','tic'],ignore_index=True).head(20)
# Out:
#           date    tic        open        high         low       close  \
# 0   2020-01-02   AAPL   71.627092   72.681289   71.373218   72.620842
# 1   2020-01-02   AMZN   93.750000   94.900497   93.207497   94.900497
# 2   2020-01-02     BA  326.606765  331.378393  325.761816  331.348572
# 3   2020-01-02    DIS  143.517032  146.391525  143.329363  146.391525
# 4   2020-01-02  GOOGL   67.018569   68.026024   66.923141   68.026024
# 5   2020-01-02    JPM  119.621142  120.742147  119.167612  120.733582
# 6   2020-01-02   META  205.621925  208.645331  205.144548  208.635391
# 7   2020-01-02   MSFT  151.289093  153.147093  150.860326  153.042282
# 8   2020-01-02   NVDA    5.942872    5.971746    5.892343    5.971746
# 9   2020-01-02   TSLA   28.299999   28.713333   28.114000   28.684000
# 10  2020-01-03   AAPL   71.847102   72.676431   71.689942   71.914803
# 11  2020-01-03   AMZN   93.224998   94.309998   93.224998   93.748497
# 12  2020-01-03     BA  328.674494  332.909308  328.346428  330.791901
# 13  2020-01-03    DIS  144.613479  146.095175  144.267759  144.712265
# 14  2020-01-03  GOOGL   66.998186   68.278009   66.964384   67.670151
# 15  2020-01-03    JPM  118.416865  119.906761  118.055157  119.140282
# 16  2020-01-03   META  206.079438  209.252020  205.820847  207.531464
# 17  2020-01-03   MSFT  150.850807  152.403898  150.603064  151.136642
# 18  2020-01-03   NVDA    5.852018    5.919972    5.827126    5.876163
# 19  2020-01-03   TSLA   29.366667   30.266666   29.128000   29.534000
#
#          volume  day      macd     boll_ub     boll_lb  rsi_30     cci_30  \
# 0   135480400.0  3.0  0.000000   73.266313   71.269332     0.0 -66.666667
# 1    80580000.0  3.0  0.000000   73.266313   71.269332     0.0 -66.666667
# 2     4544400.0  3.0  0.000000   73.266313   71.269332     0.0 -66.666667
# 3     9502100.0  3.0  0.000000   73.266313   71.269332     0.0 -66.666667
# 4    27278000.0  3.0  0.000000   73.266313   71.269332     0.0 -66.666667
# 5    10803700.0  3.0  0.000000   73.266313   71.269332     0.0 -66.666667
# 6    12077100.0  3.0  0.000000   73.266313   71.269332     0.0 -66.666667
# 7    22622100.0  3.0  0.000000   73.266313   71.269332     0.0 -66.666667
# 8   237536000.0  3.0  0.000000   73.266313   71.269332     0.0 -66.666667
# 9   142981500.0  3.0  0.000000   73.266313   71.269332     0.0 -66.666667
# 10  146322800.0  4.0 -0.015841   73.266313   71.269332     0.0 -66.666667
# 11   75288000.0  4.0 -0.025846   95.953672   92.695323     0.0 -66.666667
# 12    3875900.0  4.0 -0.012489  331.857488  330.282984     0.0  66.666667
# 13    7320200.0  4.0 -0.037676  147.926728  143.177063     0.0 -66.666667
# 14   23408000.0  4.0 -0.007984   68.351368   67.344807     0.0 -66.666667
# 15   10386800.0  4.0 -0.035747  122.190198  117.683665     0.0 -66.666667
# 16   11188400.0  4.0 -0.024768  209.644617  206.522238     0.0  66.666667
# 17   21116200.0  4.0 -0.042755  154.784444  149.394481     0.0 -66.666667
# 18  205384000.0  4.0 -0.002145    6.059131    5.788778     0.0 -66.666667
# 19  266677500.0  4.0  0.019071   30.311082   27.906918   100.0  66.666667
#
#     dx_30  close_30_sma  close_60_sma  sentiment_score    vix  turbulence
# 0   100.0     72.620842     72.620842         0.000000  12.47         0.0
# 1   100.0     94.900497     94.900497         0.000000  12.47         0.0
# 2   100.0    331.348572    331.348572        -1.000000  12.47         0.0
# 3   100.0    146.391525    146.391525        -0.800000  12.47         0.0
# 4   100.0     68.026024     68.026024        -0.666667  12.47         0.0
# 5   100.0    120.733582    120.733582        -0.250000  12.47         0.0
# 6   100.0    208.635391    208.635391         0.000000  12.47         0.0
# 7   100.0    153.042282    153.042282         0.000000  12.47         0.0
# 8   100.0      5.971746      5.971746        -1.000000  12.47         0.0
# 9   100.0     28.684000     28.684000        -0.500000  12.47         0.0
# 10  100.0     72.267822     72.267822         0.000000  14.02         0.0
# 11  100.0     94.324497     94.324497         0.000000  14.02         0.0
# 12  100.0    331.070236    331.070236         1.000000  14.02         0.0
# 13  100.0    145.551895    145.551895        -0.750000  14.02         0.0
# 14  100.0     67.848087     67.848087        -0.333333  14.02         0.0
# 15  100.0    119.936932    119.936932        -0.750000  14.02         0.0
# 16  100.0    208.083427    208.083427         0.000000  14.02         0.0
# 17  100.0    152.089462    152.089462         0.000000  14.02         0.0
# 18  100.0      5.923954      5.923954        -1.000000  14.02         0.0
# 19  100.0     29.109000     29.109000        -0.615385  14.02         0.0

# %%
train = data_split(processed_full, TRAIN_START_DATE,TRAIN_END_DATE)
trade = data_split(processed_full, TRADE_START_DATE,TRADE_END_DATE)
print(len(train))
print(len(trade))
# Out:
# 7617
# 2490

# %%
train.tail()
# Out:
#            date   tic        open        high         low       close  \
# 755  2022-12-30   JPM  124.543618  125.969014  124.196653  125.753334
# 755  2022-12-30  META  117.515305  119.762968  117.097591  119.683403
# 755  2022-12-30  MSFT  233.466236  235.181386  231.947100  235.044174
# 755  2022-12-30  NVDA   14.321270   14.616008   14.220360   14.601022
# 755  2022-12-30  TSLA  119.949997  124.480003  119.750000  123.180000
#
#           volume  day       macd     boll_ub     boll_lb     rsi_30  \
# 755    9292500.0  4.0   0.423459  126.849694  120.917210  57.143969
# 755   19583800.0  4.0   0.952232  122.984848  111.411237  49.419033
# 755   21938500.0  4.0  -1.366759  253.270814  227.343649  48.258154
# 755  310490000.0  4.0  -0.309794   18.503088   13.800796  47.045446
# 755  157777300.0  4.0 -19.258998  202.513339   99.254662  32.790586
#
#          cci_30      dx_30  close_30_sma  close_60_sma  sentiment_score  \
# 755   20.441582  11.345634    124.882475    119.589300         0.000000
# 755   78.427242   9.186731    115.435047    115.697441         0.000000
# 755  -86.505168   5.313384    240.472866    234.587172        -0.351010
# 755 -141.558902  13.239348     16.120590     14.735053        -0.380556
# 755 -121.998583  47.953532    161.267667    186.598834        -0.284461
#
#        vix  turbulence
# 755  21.67    0.766236
# 755  21.67    0.766236
# 755  21.67    0.766236
# 755  21.67    0.766236
# 755  21.67    0.766236

# %%
trade.head()
# Out:
#          date    tic        open        high         low       close  \
# 0  2023-01-03   AAPL  128.613985  129.226052  122.582119  123.470612
# 0  2023-01-03   AMZN   85.459999   86.959999   84.209999   85.820000
# 0  2023-01-03     BA  192.949997  197.179993  192.399994  195.389999
# 0  2023-01-03    DIS   87.520969   88.494734   86.389825   87.511131
# 0  2023-01-03  GOOGL   89.055891   90.507194   87.992270   88.588699
#
#         volume  day      macd     boll_ub     boll_lb     rsi_30      cci_30  \
# 0  112117500.0  1.0 -4.648598  147.860259  121.091850  39.011477 -130.963663
# 0   76706000.0  1.0 -3.075118   93.357149   80.929850  41.195599  -71.360174
# 0    8624600.0  1.0  5.326285  196.702727  176.154272  62.905353  141.206999
# 0   14997100.0  1.0 -2.395932   95.452683   81.433499  44.489017  -57.420619
# 0   28131200.0  1.0 -2.129973   98.089503   83.452727  43.976950  -67.730895
#
#        dx_30  close_30_sma  close_60_sma  sentiment_score   vix  turbulence
# 0  35.956413    138.293931    140.567288        -0.467607  22.9   29.954523
# 0  10.198927     89.424999     97.181000         0.000000  22.9   29.954523
# 0  44.456630    182.859667    166.269167         0.000000  22.9   29.954523
# 0   3.756663     90.752426     93.693725        -0.333333  22.9   29.954523
# 0   2.932446     92.974732     93.988817         0.000000  22.9   29.954523

# %%
stock_dimension = len(train.tic.unique())
state_space = 1 + 2*stock_dimension + len(INDICATORS)*stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")
# Out:
# Stock Dimension: 10, State Space: 131

# %%
from finrl.meta.env_stock_trading.env_stocktrading import StockTradingEnv
import numpy as np

EXPECTED_STATE_DIM = state_space

def force_fixed_state(obs):
    obs = np.asarray(obs, dtype=np.float32).flatten()
    if obs.shape[0] != EXPECTED_STATE_DIM:
        print(f"Auto-fixing bad obs shape {obs.shape[0]} → {EXPECTED_STATE_DIM}")
        if obs.shape[0] < EXPECTED_STATE_DIM:
            # Pad with zeros
            obs = np.pad(obs, (0, EXPECTED_STATE_DIM - obs.shape[0]), mode='constant')
        else:
            # Truncate
            obs = obs[:EXPECTED_STATE_DIM]
    return obs.reshape(1, -1)


class PatchedStockTradingEnv(StockTradingEnv):
    def reset(self, *, seed=None, options=None):
        obs, info = super().reset(seed=seed, options=options)
        obs = force_fixed_state(obs)
        return obs, info

    def step(self, action):
        obs, reward, terminated, truncated, info = super().step(action)
        obs = force_fixed_state(obs)
        return obs, reward, terminated, truncated, info

# %%
buy_cost_list = sell_cost_list = [0.001] * stock_dimension
num_stock_shares = [0] * stock_dimension

env_kwargs = {
    "hmax": 100,
    "initial_amount": 1000000,
    "num_stock_shares": num_stock_shares,
    "buy_cost_pct": buy_cost_list,
    "sell_cost_pct": sell_cost_list,
    "state_space": state_space,
    "stock_dim": stock_dimension,
    "tech_indicator_list": INDICATORS,
    "action_space": stock_dimension,
    "reward_scaling": 1e-4
}

from stable_baselines3.common.vec_env import DummyVecEnv

env_train = DummyVecEnv([lambda: PatchedStockTradingEnv(df=train, **env_kwargs)])

# %% [markdown]
# ## Environment for Training

# %%
obs = env_train.reset()
print("obs shape:", obs.shape, "dtype:", obs.dtype)

action = np.zeros(stock_dimension)
obs, reward, done, info = env_train.step(action)
print("step shape:", obs.shape, "dtype:", obs.dtype)
# Out:
# obs shape: (1, 131) dtype: float32
# step shape: (1, 131) dtype: float32
# /usr/local/lib/python3.11/dist-packages/finrl/meta/env_stock_trading/env_stocktrading.py:328: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   sell_index = argsort_actions[: np.where(actions < 0)[0].shape[0]]

# %%
obs = env_train.reset()
print("Training reset shape:", obs.shape, obs.dtype)

obs, reward, done, info = env_train.step(np.zeros(stock_dimension))
print("Training step shape:", obs.shape, obs.dtype)
# Out:
# Training reset shape: (1, 131) float32
# Training step shape: (1, 131) float32

# %% [markdown]
# <a id='5'></a>
# # Part 6: Train  DRL Agents
# * The DRL algorithms are from **Stable Baselines 3**.
# * FinRL includes fine-tuned standard DRL algorithms, such as DQN, DDPG, Multi-Agent DDPG, PPO, SAC, A2C and TD3.

# %% [markdown]
# ### Agent Training: 3 algorithms (A2C,PPO, TD3)

# %% [markdown]
# ### Agent 1: A2C

# %%
agent = DRLAgent(env = env_train)
model_a2c = agent.get_model("a2c")


# set up logger
tmp_path = RESULTS_DIR + '/a2c'
new_logger_a2c = configure(tmp_path, ["stdout", "csv", "tensorboard"])
# Set new logger
model_a2c.set_logger(new_logger_a2c)
# Out:
# {'n_steps': 5, 'ent_coef': 0.01, 'learning_rate': 0.0007}
# Using cpu device
# Logging to results/a2c

# %%
print(repr(env_train.reset()))
# Out:
# array([[ 1.0000000e+06,  7.2620842e+01,  9.4900497e+01,  3.3134857e+02,
#          1.4576991e+02,  6.8026016e+01,  1.2073355e+02,  2.0863541e+02,
#          1.5304231e+02,  5.9717469e+00,  2.8684000e+01,  0.0000000e+00,
#          0.0000000e+00,  0.0000000e+00,  0.0000000e+00,  0.0000000e+00,
#          0.0000000e+00,  0.0000000e+00,  0.0000000e+00,  0.0000000e+00,
#          0.0000000e+00,  0.0000000e+00,  0.0000000e+00,  0.0000000e+00,
#          0.0000000e+00,  0.0000000e+00,  0.0000000e+00,  0.0000000e+00,
#          0.0000000e+00,  0.0000000e+00,  0.0000000e+00,  7.3266296e+01,
#          7.3266296e+01,  7.3266296e+01,  7.3266296e+01,  7.3266296e+01,
#          7.3266296e+01,  7.3266296e+01,  7.3266296e+01,  7.3266296e+01,
#          7.3266296e+01,  7.1269363e+01,  7.1269363e+01,  7.1269363e+01,
#          7.1269363e+01,  7.1269363e+01,  7.1269363e+01,  7.1269363e+01,
#          7.1269363e+01,  7.1269363e+01,  7.1269363e+01,  0.0000000e+00,
#          0.0000000e+00,  0.0000000e+00,  0.0000000e+00,  0.0000000e+00,
#          0.0000000e+00,  0.0000000e+00,  0.0000000e+00,  0.0000000e+00,
#          0.0000000e+00, -6.6666664e+01, -6.6666664e+01, -6.6666664e+01,
#         -6.6666664e+01, -6.6666664e+01, -6.6666664e+01, -6.6666664e+01,
#         -6.6666664e+01, -6.6666664e+01, -6.6666664e+01,  1.0000000e+02,
#          1.0000000e+02,  1.0000000e+02,  1.0000000e+02,  1.0000000e+02,
#          1.0000000e+02,  1.0000000e+02,  1.0000000e+02,  1.0000000e+02,
#          1.0000000e+02,  7.2620842e+01,  9.4900497e+01,  3.3134857e+02,
#          1.4576991e+02,  6.8026016e+01,  1.2073355e+02,  2.0863541e+02,
#          1.5304231e+02,  5.9717469e+00,  2.8684000e+01,  7.2620842e+01,
#          9.4900497e+01,  3.3134857e+02,  1.4576991e+02,  6.8026016e+01,
#          1.2073355e+02,  2.0863541e+02,  1.5304231e+02,  5.9717469e+00,
#          2.8684000e+01,  0.0000000e+00,  0.0000000e+00, -1.0000000e+00,
#         -4.0000001e-01, -8.3333331e-01, -2.5000000e-01,  0.0000000e+00,
#          0.0000000e+00, -1.0000000e+00, -5.0000000e-01,  1.2470000e+01,
#          1.2470000e+01,  1.2470000e+01,  1.2470000e+01,  1.2470000e+01,
#          1.2470000e+01,  1.2470000e+01,  1.2470000e+01,  1.2470000e+01,
#          1.2470000e+01,  0.0000000e+00,  0.0000000e+00,  0.0000000e+00,
#          0.0000000e+00,  0.0000000e+00,  0.0000000e+00,  0.0000000e+00,
#          0.0000000e+00,  0.0000000e+00,  0.0000000e+00]], dtype=float32)

# %%
trained_a2c  = agent.train_model(model=model_a2c,
                             tb_log_name='a2c',
                             total_timesteps=50000)
# Out:
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# --------------------------------------
# | time/                 |            |
# |    fps                | 233        |
# |    iterations         | 100        |
# |    time_elapsed       | 2          |
# |    total_timesteps    | 500        |
# | train/                |            |
# |    entropy_loss       | -14.1      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 99         |
# |    policy_loss        | -23.1      |
# |    reward             | 1.1639003  |
# |    reward_max         | 2.862803   |
# |    reward_mean        | 1.3240483  |
# |    reward_min         | -1.5119096 |
# |    std                | 0.988      |
# |    value_loss         | 3.66       |
# --------------------------------------
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# ---------------------------------------
# | time/                 |             |
# |    fps                | 205         |
# |    iterations         | 200         |
# |    time_elapsed       | 4           |
# |    total_timesteps    | 1000        |
# | train/                |             |
# |    entropy_loss       | -14.1       |
# |    explained_variance | 0.000753    |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 199         |
# |    policy_loss        | -9.58       |
# |    reward             | 1.554598    |
# |    reward_max         | 1.554598    |
# |    reward_mean        | 0.71902794  |
# |    reward_min         | -0.29313245 |
# |    std                | 0.994       |
# |    value_loss         | 1.43        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 206        |
# |    iterations         | 300        |
# |    time_elapsed       | 7          |
# |    total_timesteps    | 1500       |
# | train/                |            |
# |    entropy_loss       | -14.1      |
# |    explained_variance | -0.0515    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 299        |
# |    policy_loss        | -34.6      |
# |    reward             | -0.6565694 |
# |    reward_max         | 0.7757004  |
# |    reward_mean        | -0.4281107 |
# |    reward_min         | -1.4715533 |
# |    std                | 0.988      |
# |    value_loss         | 5.92       |
# --------------------------------------
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# ---------------------------------------
# | time/                 |             |
# |    fps                | 214         |
# |    iterations         | 400         |
# |    time_elapsed       | 9           |
# |    total_timesteps    | 2000        |
# | train/                |             |
# |    entropy_loss       | -14.1       |
# |    explained_variance | -0.00191    |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 399         |
# |    policy_loss        | -21.1       |
# |    reward             | 1.1706471   |
# |    reward_max         | 2.883033    |
# |    reward_mean        | -0.35937268 |
# |    reward_min         | -4.7363887  |
# |    std                | 0.987       |
# |    value_loss         | 4.84        |
# ---------------------------------------
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# --------------------------------------
# | time/                 |            |
# |    fps                | 221        |
# |    iterations         | 500        |
# |    time_elapsed       | 11         |
# |    total_timesteps    | 2500       |
# | train/                |            |
# |    entropy_loss       | -14.1      |
# |    explained_variance | -0.0416    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 499        |
# |    policy_loss        | 60.9       |
# |    reward             | -1.1291457 |
# |    reward_max         | 1.2794226  |
# |    reward_mean        | 0.18516184 |
# |    reward_min         | -1.2874274 |
# |    std                | 0.987      |
# |    value_loss         | 24         |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 226         |
# |    iterations         | 600         |
# |    time_elapsed       | 13          |
# |    total_timesteps    | 3000        |
# | train/                |             |
# |    entropy_loss       | -14         |
# |    explained_variance | -0.224      |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 599         |
# |    policy_loss        | -29.4       |
# |    reward             | -0.27060813 |
# |    reward_max         | 2.2134259   |
# |    reward_mean        | 0.070428975 |
# |    reward_min         | -2.06373    |
# |    std                | 0.983       |
# |    value_loss         | 4.37        |
# ---------------------------------------
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# ---------------------------------------
# | time/                 |             |
# |    fps                | 230         |
# |    iterations         | 700         |
# |    time_elapsed       | 15          |
# |    total_timesteps    | 3500        |
# | train/                |             |
# |    entropy_loss       | -14         |
# |    explained_variance | -0.0385     |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 699         |
# |    policy_loss        | -34.6       |
# |    reward             | 1.4626068   |
# |    reward_max         | 1.4626068   |
# |    reward_mean        | 0.7473507   |
# |    reward_min         | -0.38322106 |
# |    std                | 0.986       |
# |    value_loss         | 13.5        |
# ---------------------------------------
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# --------------------------------------
# | time/                 |            |
# |    fps                | 225        |
# |    iterations         | 800        |
# |    time_elapsed       | 17         |
# |    total_timesteps    | 4000       |
# | train/                |            |
# |    entropy_loss       | -14.1      |
# |    explained_variance | 0.377      |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 799        |
# |    policy_loss        | 7.7        |
# |    reward             | 0.56311476 |
# |    reward_max         | 0.9461698  |
# |    reward_mean        | 0.18926212 |
# |    reward_min         | -0.5106177 |
# |    std                | 0.987      |
# |    value_loss         | 0.688      |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 217         |
# |    iterations         | 900         |
# |    time_elapsed       | 20          |
# |    total_timesteps    | 4500        |
# | train/                |             |
# |    entropy_loss       | -14.1       |
# |    explained_variance | -3.03       |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 899         |
# |    policy_loss        | -24         |
# |    reward             | -0.69732153 |
# |    reward_max         | 0.2772484   |
# |    reward_mean        | -0.12094993 |
# |    reward_min         | -0.69732153 |
# |    std                | 0.989       |
# |    value_loss         | 3.33        |
# ---------------------------------------
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# --------------------------------------
# | time/                 |            |
# |    fps                | 220        |
# |    iterations         | 1000       |
# |    time_elapsed       | 22         |
# |    total_timesteps    | 5000       |
# | train/                |            |
# |    entropy_loss       | -14.1      |
# |    explained_variance | 0.178      |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 999        |
# |    policy_loss        | 37.1       |
# |    reward             | 1.4645327  |
# |    reward_max         | 2.713065   |
# |    reward_mean        | 1.0607395  |
# |    reward_min         | -1.1224985 |
# |    std                | 0.991      |
# |    value_loss         | 9.42       |
# --------------------------------------
# day: 755, episode: 10
# begin_total_asset: 1000000.00
# end_total_asset: 148898.53
# total_reward: -851101.47
# total_cost: 19919.97
# total_trades: 5305
# Sharpe: 0.167
# =================================
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# ---------------------------------------
# | time/                 |             |
# |    fps                | 221         |
# |    iterations         | 1100        |
# |    time_elapsed       | 24          |
# |    total_timesteps    | 5500        |
# | train/                |             |
# |    entropy_loss       | -14.1       |
# |    explained_variance | -0.297      |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1099        |
# |    policy_loss        | -14.1       |
# |    reward             | -1.1779265  |
# |    reward_max         | 0.35870522  |
# |    reward_mean        | -0.18151426 |
# |    reward_min         | -1.1779265  |
# |    std                | 0.992       |
# |    value_loss         | 1.89        |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 222         |
# |    iterations         | 1200        |
# |    time_elapsed       | 26          |
# |    total_timesteps    | 6000        |
# | train/                |             |
# |    entropy_loss       | -14.1       |
# |    explained_variance | -0.141      |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1199        |
# |    policy_loss        | 14          |
# |    reward             | -0.42717642 |
# |    reward_max         | 1.1169808   |
# |    reward_mean        | -0.16432913 |
# |    reward_min         | -2.0076253  |
# |    std                | 0.995       |
# |    value_loss         | 1.6         |
# ---------------------------------------
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# --------------------------------------
# | time/                 |            |
# |    fps                | 224        |
# |    iterations         | 1300       |
# |    time_elapsed       | 28         |
# |    total_timesteps    | 6500       |
# | train/                |            |
# |    entropy_loss       | -14.1      |
# |    explained_variance | -0.0445    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1299       |
# |    policy_loss        | 5.29       |
# |    reward             | 1.815874   |
# |    reward_max         | 1.815874   |
# |    reward_mean        | 1.0206243  |
# |    reward_min         | 0.35084975 |
# |    std                | 0.996      |
# |    value_loss         | 0.277      |
# --------------------------------------
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# ---------------------------------------
# | time/                 |             |
# |    fps                | 225         |
# |    iterations         | 1400        |
# |    time_elapsed       | 30          |
# |    total_timesteps    | 7000        |
# | train/                |             |
# |    entropy_loss       | -14.2       |
# |    explained_variance | 0.014       |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1399        |
# |    policy_loss        | -1.14       |
# |    reward             | 0.51804054  |
# |    reward_max         | 0.70715314  |
# |    reward_mean        | 0.20617034  |
# |    reward_min         | -0.73704004 |
# |    std                | 0.997       |
# |    value_loss         | 0.535       |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 220         |
# |    iterations         | 1500        |
# |    time_elapsed       | 34          |
# |    total_timesteps    | 7500        |
# | train/                |             |
# |    entropy_loss       | -14.2       |
# |    explained_variance | 0.0383      |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1499        |
# |    policy_loss        | -34.4       |
# |    reward             | -0.46247324 |
# |    reward_max         | 1.2766477   |
# |    reward_mean        | -1.0288577  |
# |    reward_min         | -3.9241815  |
# |    std                | 0.998       |
# |    value_loss         | 6.92        |
# ---------------------------------------
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# ---------------------------------------
# | time/                 |             |
# |    fps                | 221         |
# |    iterations         | 1600        |
# |    time_elapsed       | 36          |
# |    total_timesteps    | 8000        |
# | train/                |             |
# |    entropy_loss       | -14.2       |
# |    explained_variance | 0.17        |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1599        |
# |    policy_loss        | 4.31        |
# |    reward             | -0.39886552 |
# |    reward_max         | 1.1412567   |
# |    reward_mean        | 0.22075827  |
# |    reward_min         | -0.80439687 |
# |    std                | 0.998       |
# |    value_loss         | 0.515       |
# ---------------------------------------
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# ---------------------------------------
# | time/                 |             |
# |    fps                | 223         |
# |    iterations         | 1700        |
# |    time_elapsed       | 38          |
# |    total_timesteps    | 8500        |
# | train/                |             |
# |    entropy_loss       | -14.2       |
# |    explained_variance | 0.153       |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1699        |
# |    policy_loss        | 12          |
# |    reward             | 0.35186368  |
# |    reward_max         | 0.9005781   |
# |    reward_mean        | -0.36320093 |
# |    reward_min         | -2.335113   |
# |    std                | 1           |
# |    value_loss         | 3           |
# ---------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 225           |
# |    iterations         | 1800          |
# |    time_elapsed       | 39            |
# |    total_timesteps    | 9000          |
# | train/                |               |
# |    entropy_loss       | -14.2         |
# |    explained_variance | 0.0125        |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 1799          |
# |    policy_loss        | -0.633        |
# |    reward             | -0.0014347758 |
# |    reward_max         | 1.6618531     |
# |    reward_mean        | 0.48385808    |
# |    reward_min         | -0.27825144   |
# |    std                | 1             |
# |    value_loss         | 2.82          |
# -----------------------------------------
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# ---------------------------------------
# | time/                 |             |
# |    fps                | 227         |
# |    iterations         | 1900        |
# |    time_elapsed       | 41          |
# |    total_timesteps    | 9500        |
# | train/                |             |
# |    entropy_loss       | -14.2       |
# |    explained_variance | -3          |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1899        |
# |    policy_loss        | 17.2        |
# |    reward             | 0.101836726 |
# |    reward_max         | 0.45998138  |
# |    reward_mean        | -0.11559895 |
# |    reward_min         | -1.270888   |
# |    std                | 1           |
# |    value_loss         | 1.72        |
# ---------------------------------------
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# --------------------------------------
# | time/                 |            |
# |    fps                | 228        |
# |    iterations         | 2000       |
# |    time_elapsed       | 43         |
# |    total_timesteps    | 10000      |
# | train/                |            |
# |    entropy_loss       | -14.2      |
# |    explained_variance | 0.15       |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1999       |
# |    policy_loss        | 73.4       |
# |    reward             | -7.056088  |
# |    reward_max         | 0.86127573 |
# |    reward_mean        | -2.6342862 |
# |    reward_min         | -7.056088  |
# |    std                | 1          |
# |    value_loss         | 28.4       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 225        |
# |    iterations         | 2100       |
# |    time_elapsed       | 46         |
# |    total_timesteps    | 10500      |
# | train/                |            |
# |    entropy_loss       | -14.2      |
# |    explained_variance | 0.0495     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 2099       |
# |    policy_loss        | -2.13      |
# |    reward             | 0.3860885  |
# |    reward_max         | 0.3860885  |
# |    reward_mean        | -0.9115301 |
# |    reward_min         | -2.0468035 |
# |    std                | 1.01       |
# |    value_loss         | 1.05       |
# --------------------------------------
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# --------------------------------------
# | time/                 |            |
# |    fps                | 223        |
# |    iterations         | 2200       |
# |    time_elapsed       | 49         |
# |    total_timesteps    | 11000      |
# | train/                |            |
# |    entropy_loss       | -14.3      |
# |    explained_variance | -0.174     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 2199       |
# |    policy_loss        | -28.7      |
# |    reward             | -0.7620822 |
# |    reward_max         | 1.9310255  |
# |    reward_mean        | 0.40560964 |
# |    reward_min         | -0.7620822 |
# |    std                | 1.01       |
# |    value_loss         | 7.99       |
# --------------------------------------
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# ---------------------------------------
# | time/                 |             |
# |    fps                | 225         |
# |    iterations         | 2300        |
# |    time_elapsed       | 51          |
# |    total_timesteps    | 11500       |
# | train/                |             |
# |    entropy_loss       | -14.3       |
# |    explained_variance | -0.471      |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 2299        |
# |    policy_loss        | 31.9        |
# |    reward             | 1.4872031   |
# |    reward_max         | 1.99543     |
# |    reward_mean        | 0.86489093  |
# |    reward_min         | -0.10140895 |
# |    std                | 1.01        |
# |    value_loss         | 4.55        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 226        |
# |    iterations         | 2400       |
# |    time_elapsed       | 53         |
# |    total_timesteps    | 12000      |
# | train/                |            |
# |    entropy_loss       | -14.3      |
# |    explained_variance | -0.226     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 2399       |
# |    policy_loss        | -46.2      |
# |    reward             | -0.5395314 |
# |    reward_max         | 2.6417632  |
# |    reward_mean        | 0.922922   |
# |    reward_min         | -1.5058522 |
# |    std                | 1.01       |
# |    value_loss         | 13.1       |
# --------------------------------------
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# ----------------------------------------
# | time/                 |              |
# |    fps                | 226          |
# |    iterations         | 2500         |
# |    time_elapsed       | 55           |
# |    total_timesteps    | 12500        |
# | train/                |              |
# |    entropy_loss       | -14.3        |
# |    explained_variance | 0.0534       |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 2499         |
# |    policy_loss        | 30.9         |
# |    reward             | -0.24511221  |
# |    reward_max         | 0.9268228    |
# |    reward_mean        | 0.0001919724 |
# |    reward_min         | -0.9895572   |
# |    std                | 1.02         |
# |    value_loss         | 6.61         |
# ----------------------------------------
# day: 755, episode: 20
# begin_total_asset: 1000000.00
# end_total_asset: 292034.08
# total_reward: -707965.92
# total_cost: 6733.69
# total_trades: 4364
# Sharpe: 0.085
# =================================
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# ---------------------------------------
# | time/                 |             |
# |    fps                | 227         |
# |    iterations         | 2600        |
# |    time_elapsed       | 57          |
# |    total_timesteps    | 13000       |
# | train/                |             |
# |    entropy_loss       | -14.3       |
# |    explained_variance | 0.0242      |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 2599        |
# |    policy_loss        | -10.3       |
# |    reward             | 0.015745606 |
# |    reward_max         | 0.3979983   |
# |    reward_mean        | 0.040448714 |
# |    reward_min         | -0.30204192 |
# |    std                | 1.01        |
# |    value_loss         | 0.816       |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 228        |
# |    iterations         | 2700       |
# |    time_elapsed       | 59         |
# |    total_timesteps    | 13500      |
# | train/                |            |
# |    entropy_loss       | -14.3      |
# |    explained_variance | -0.0614    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 2699       |
# |    policy_loss        | 49.7       |
# |    reward             | 2.6217225  |
# |    reward_max         | 2.6806583  |
# |    reward_mean        | 0.80466145 |
# |    reward_min         | -1.6504726 |
# |    std                | 1.02       |
# |    value_loss         | 17.4       |
# --------------------------------------
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# -----------------------------------------
# | time/                 |               |
# |    fps                | 225           |
# |    iterations         | 2800          |
# |    time_elapsed       | 62            |
# |    total_timesteps    | 14000         |
# | train/                |               |
# |    entropy_loss       | -14.3         |
# |    explained_variance | 0.0567        |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 2799          |
# |    policy_loss        | -17.2         |
# |    reward             | -0.29049072   |
# |    reward_max         | 1.0493293     |
# |    reward_mean        | 0.00078707637 |
# |    reward_min         | -0.348551     |
# |    std                | 1.01          |
# |    value_loss         | 2.08          |
# -----------------------------------------
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# ----------------------------------------
# | time/                 |              |
# |    fps                | 226          |
# |    iterations         | 2900         |
# |    time_elapsed       | 64           |
# |    total_timesteps    | 14500        |
# | train/                |              |
# |    entropy_loss       | -14.3        |
# |    explained_variance | 0.4          |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 2899         |
# |    policy_loss        | 27.3         |
# |    reward             | -0.059937872 |
# |    reward_max         | 0.34292954   |
# |    reward_mean        | -0.06729388  |
# |    reward_min         | -0.462241    |
# |    std                | 1.01         |
# |    value_loss         | 3.48         |
# ----------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 227        |
# |    iterations         | 3000       |
# |    time_elapsed       | 65         |
# |    total_timesteps    | 15000      |
# | train/                |            |
# |    entropy_loss       | -14.4      |
# |    explained_variance | 0.0768     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 2999       |
# |    policy_loss        | 8.23       |
# |    reward             | 0.7231085  |
# |    reward_max         | 2.3332622  |
# |    reward_mean        | 0.19331494 |
# |    reward_min         | -2.9908016 |
# |    std                | 1.02       |
# |    value_loss         | 0.587      |
# --------------------------------------
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# ---------------------------------------
# | time/                 |             |
# |    fps                | 229         |
# |    iterations         | 3100        |
# |    time_elapsed       | 67          |
# |    total_timesteps    | 15500       |
# | train/                |             |
# |    entropy_loss       | -14.4       |
# |    explained_variance | -0.124      |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 3099        |
# |    policy_loss        | 14.6        |
# |    reward             | -1.0117255  |
# |    reward_max         | 0.06661952  |
# |    reward_mean        | -0.48937854 |
# |    reward_min         | -1.3093612  |
# |    std                | 1.02        |
# |    value_loss         | 3.42        |
# ---------------------------------------
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# ---------------------------------------
# | time/                 |             |
# |    fps                | 230         |
# |    iterations         | 3200        |
# |    time_elapsed       | 69          |
# |    total_timesteps    | 16000       |
# | train/                |             |
# |    entropy_loss       | -14.4       |
# |    explained_variance | -0.539      |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 3199        |
# |    policy_loss        | 0.955       |
# |    reward             | 0.6489904   |
# |    reward_max         | 0.6489904   |
# |    reward_mean        | 0.075115375 |
# |    reward_min         | -0.57940364 |
# |    std                | 1.02        |
# |    value_loss         | 0.0368      |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 231         |
# |    iterations         | 3300        |
# |    time_elapsed       | 71          |
# |    total_timesteps    | 16500       |
# | train/                |             |
# |    entropy_loss       | -14.4       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 3299        |
# |    policy_loss        | -41.2       |
# |    reward             | 2.1628962   |
# |    reward_max         | 4.0775123   |
# |    reward_mean        | 1.3274432   |
# |    reward_min         | -0.19707477 |
# |    std                | 1.03        |
# |    value_loss         | 12.8        |
# ---------------------------------------
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# ---------------------------------------
# | time/                 |             |
# |    fps                | 229         |
# |    iterations         | 3400        |
# |    time_elapsed       | 74          |
# |    total_timesteps    | 17000       |
# | train/                |             |
# |    entropy_loss       | -14.4       |
# |    explained_variance | -1.02       |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 3399        |
# |    policy_loss        | 2.42        |
# |    reward             | 0.19956689  |
# |    reward_max         | 0.5815225   |
# |    reward_mean        | 0.11757418  |
# |    reward_min         | -0.93222183 |
# |    std                | 1.02        |
# |    value_loss         | 0.0804      |
# ---------------------------------------
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# --------------------------------------
# | time/                 |            |
# |    fps                | 227        |
# |    iterations         | 3500       |
# |    time_elapsed       | 76         |
# |    total_timesteps    | 17500      |
# | train/                |            |
# |    entropy_loss       | -14.4      |
# |    explained_variance | 0.143      |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 3499       |
# |    policy_loss        | -365       |
# |    reward             | 0.25572762 |
# |    reward_max         | 12.618893  |
# |    reward_mean        | 1.5265765  |
# |    reward_min         | -2.865281  |
# |    std                | 1.02       |
# |    value_loss         | 1e+03      |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 227         |
# |    iterations         | 3600        |
# |    time_elapsed       | 78          |
# |    total_timesteps    | 18000       |
# | train/                |             |
# |    entropy_loss       | -14.4       |
# |    explained_variance | -0.034      |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 3599        |
# |    policy_loss        | 55.9        |
# |    reward             | 0.19921578  |
# |    reward_max         | 1.5138882   |
# |    reward_mean        | -0.33687186 |
# |    reward_min         | -3.0704243  |
# |    std                | 1.02        |
# |    value_loss         | 13.6        |
# ---------------------------------------
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# --------------------------------------
# | time/                 |            |
# |    fps                | 228        |
# |    iterations         | 3700       |
# |    time_elapsed       | 81         |
# |    total_timesteps    | 18500      |
# | train/                |            |
# |    entropy_loss       | -14.4      |
# |    explained_variance | -0.477     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 3699       |
# |    policy_loss        | 21.2       |
# |    reward             | -0.9412858 |
# |    reward_max         | 0.75198984 |
# |    reward_mean        | 0.01199308 |
# |    reward_min         | -0.9412858 |
# |    std                | 1.02       |
# |    value_loss         | 2.54       |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 228         |
# |    iterations         | 3800        |
# |    time_elapsed       | 83          |
# |    total_timesteps    | 19000       |
# | train/                |             |
# |    entropy_loss       | -14.4       |
# |    explained_variance | -0.0669     |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 3799        |
# |    policy_loss        | 18.2        |
# |    reward             | 1.8588617   |
# |    reward_max         | 2.1935594   |
# |    reward_mean        | 1.0720913   |
# |    reward_min         | -0.65424675 |
# |    std                | 1.03        |
# |    value_loss         | 3.53        |
# ---------------------------------------
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# ----------------------------------------
# | time/                 |              |
# |    fps                | 229          |
# |    iterations         | 3900         |
# |    time_elapsed       | 85           |
# |    total_timesteps    | 19500        |
# | train/                |              |
# |    entropy_loss       | -14.4        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 3899         |
# |    policy_loss        | -69.6        |
# |    reward             | -0.022184532 |
# |    reward_max         | 2.3663027    |
# |    reward_mean        | -0.21121281  |
# |    reward_min         | -2.946457    |
# |    std                | 1.03         |
# |    value_loss         | 31.3         |
# ----------------------------------------
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# --------------------------------------
# | time/                 |            |
# |    fps                | 228        |
# |    iterations         | 4000       |
# |    time_elapsed       | 87         |
# |    total_timesteps    | 20000      |
# | train/                |            |
# |    entropy_loss       | -14.4      |
# |    explained_variance | -0.00103   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 3999       |
# |    policy_loss        | -10.6      |
# |    reward             | 1.3040745  |
# |    reward_max         | 1.3040745  |
# |    reward_mean        | -1.1940465 |
# |    reward_min         | -3.130516  |
# |    std                | 1.03       |
# |    value_loss         | 1.85       |
# --------------------------------------
# day: 755, episode: 30
# begin_total_asset: 1000000.00
# end_total_asset: 267153.27
# total_reward: -732846.73
# total_cost: 5312.55
# total_trades: 4488
# Sharpe: 0.257
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 226       |
# |    iterations         | 4100      |
# |    time_elapsed       | 90        |
# |    total_timesteps    | 20500     |
# | train/                |           |
# |    entropy_loss       | -14.4     |
# |    explained_variance | 0.00659   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4099      |
# |    policy_loss        | -70.8     |
# |    reward             | 2.7677886 |
# |    reward_max         | 2.9575005 |
# |    reward_mean        | 1.379165  |
# |    reward_min         | 0.2675043 |
# |    std                | 1.03      |
# |    value_loss         | 32.3      |
# -------------------------------------
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# --------------------------------------
# | time/                 |            |
# |    fps                | 226        |
# |    iterations         | 4200       |
# |    time_elapsed       | 92         |
# |    total_timesteps    | 21000      |
# | train/                |            |
# |    entropy_loss       | -14.4      |
# |    explained_variance | 9.53e-05   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 4199       |
# |    policy_loss        | -119       |
# |    reward             | 0.40666443 |
# |    reward_max         | 2.074035   |
# |    reward_mean        | 0.4232101  |
# |    reward_min         | -0.4350256 |
# |    std                | 1.02       |
# |    value_loss         | 67.6       |
# --------------------------------------
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# ---------------------------------------
# | time/                 |             |
# |    fps                | 227         |
# |    iterations         | 4300        |
# |    time_elapsed       | 94          |
# |    total_timesteps    | 21500       |
# | train/                |             |
# |    entropy_loss       | -14.4       |
# |    explained_variance | -0.00036    |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 4299        |
# |    policy_loss        | 4.58        |
# |    reward             | -0.53263354 |
# |    reward_max         | 0.6293435   |
# |    reward_mean        | -0.53309155 |
# |    reward_min         | -1.809189   |
# |    std                | 1.02        |
# |    value_loss         | 0.502       |
# ---------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 227          |
# |    iterations         | 4400         |
# |    time_elapsed       | 96           |
# |    total_timesteps    | 22000        |
# | train/                |              |
# |    entropy_loss       | -14.4        |
# |    explained_variance | -0.0402      |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 4399         |
# |    policy_loss        | 59.9         |
# |    reward             | 2.9064903    |
# |    reward_max         | 3.0265598    |
# |    reward_mean        | -0.030173969 |
# |    reward_min         | -4.4544873   |
# |    std                | 1.03         |
# |    value_loss         | 27.4         |
# ----------------------------------------
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# --------------------------------------
# | time/                 |            |
# |    fps                | 228        |
# |    iterations         | 4500       |
# |    time_elapsed       | 98         |
# |    total_timesteps    | 22500      |
# | train/                |            |
# |    entropy_loss       | -14.4      |
# |    explained_variance | -0.21      |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 4499       |
# |    policy_loss        | -29.2      |
# |    reward             | -1.8391862 |
# |    reward_max         | 1.7345997  |
# |    reward_mean        | -0.7122715 |
# |    reward_min         | -2.437386  |
# |    std                | 1.03       |
# |    value_loss         | 7.23       |
# --------------------------------------
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# ---------------------------------------
# | time/                 |             |
# |    fps                | 227         |
# |    iterations         | 4600        |
# |    time_elapsed       | 101         |
# |    total_timesteps    | 23000       |
# | train/                |             |
# |    entropy_loss       | -14.5       |
# |    explained_variance | 0.0138      |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 4599        |
# |    policy_loss        | 41.4        |
# |    reward             | 1.0890131   |
# |    reward_max         | 1.0890131   |
# |    reward_mean        | 0.117327355 |
# |    reward_min         | -0.8093925  |
# |    std                | 1.03        |
# |    value_loss         | 6.99        |
# ---------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 225          |
# |    iterations         | 4700         |
# |    time_elapsed       | 104          |
# |    total_timesteps    | 23500        |
# | train/                |              |
# |    entropy_loss       | -14.5        |
# |    explained_variance | 0.00304      |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 4699         |
# |    policy_loss        | 41.3         |
# |    reward             | -0.086152144 |
# |    reward_max         | 2.7724113    |
# |    reward_mean        | -0.34511825  |
# |    reward_min         | -4.3556705   |
# |    std                | 1.03         |
# |    value_loss         | 31.4         |
# ----------------------------------------
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# ---------------------------------------
# | time/                 |             |
# |    fps                | 225         |
# |    iterations         | 4800        |
# |    time_elapsed       | 106         |
# |    total_timesteps    | 24000       |
# | train/                |             |
# |    entropy_loss       | -14.5       |
# |    explained_variance | -0.0146     |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 4799        |
# |    policy_loss        | 108         |
# |    reward             | 0.4243235   |
# |    reward_max         | 4.4564567   |
# |    reward_mean        | 1.1590836   |
# |    reward_min         | -0.18001448 |
# |    std                | 1.03        |
# |    value_loss         | 54.7        |
# ---------------------------------------
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# --------------------------------------
# | time/                 |            |
# |    fps                | 226        |
# |    iterations         | 4900       |
# |    time_elapsed       | 108        |
# |    total_timesteps    | 24500      |
# | train/                |            |
# |    entropy_loss       | -14.5      |
# |    explained_variance | 0.000188   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 4899       |
# |    policy_loss        | 11.3       |
# |    reward             | -1.9301959 |
# |    reward_max         | 0.9158921  |
# |    reward_mean        | -0.8660856 |
# |    reward_min         | -2.9451761 |
# |    std                | 1.04       |
# |    value_loss         | 1.25       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 226        |
# |    iterations         | 5000       |
# |    time_elapsed       | 110        |
# |    total_timesteps    | 25000      |
# | train/                |            |
# |    entropy_loss       | -14.5      |
# |    explained_variance | -0.00345   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 4999       |
# |    policy_loss        | -106       |
# |    reward             | -5.9704967 |
# |    reward_max         | 8.386039   |
# |    reward_mean        | -2.8374503 |
# |    reward_min         | -12.097143 |
# |    std                | 1.04       |
# |    value_loss         | 77.6       |
# --------------------------------------
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# ...
# |    iterations         | 8400        |
# |    time_elapsed       | 187         |
# |    total_timesteps    | 42000       |
# | train/                |             |
# |    entropy_loss       | -15         |
# |    explained_variance | -0.373      |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 8399        |
# |    policy_loss        | 10.9        |
# |    reward             | 0.1728897   |
# |    reward_max         | 0.5036983   |
# |    reward_mean        | 0.13158648  |
# |    reward_min         | -0.21650077 |
# |    std                | 1.09        |
# |    value_loss         | 0.7         |
# ---------------------------------------
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# ----------------------------------------
# | time/                 |              |
# |    fps                | 224          |
# |    iterations         | 8500         |
# |    time_elapsed       | 189          |
# |    total_timesteps    | 42500        |
# | train/                |              |
# |    entropy_loss       | -15.1        |
# |    explained_variance | -2.11        |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 8499         |
# |    policy_loss        | 2.42         |
# |    reward             | 1.7408053    |
# |    reward_max         | 1.7408053    |
# |    reward_mean        | 0.6515118    |
# |    reward_min         | -0.043786492 |
# |    std                | 1.09         |
# |    value_loss         | 0.047        |
# ----------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 224         |
# |    iterations         | 8600        |
# |    time_elapsed       | 191         |
# |    total_timesteps    | 43000       |
# | train/                |             |
# |    entropy_loss       | -15.1       |
# |    explained_variance | -0.00912    |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 8599        |
# |    policy_loss        | 17          |
# |    reward             | -0.7030448  |
# |    reward_max         | 0.12983878  |
# |    reward_mean        | -0.39374393 |
# |    reward_min         | -0.778623   |
# |    std                | 1.09        |
# |    value_loss         | 1.5         |
# ---------------------------------------
# day: 755, episode: 60
# begin_total_asset: 1000000.00
# end_total_asset: 149133.33
# total_reward: -850866.67
# total_cost: 12511.49
# total_trades: 4571
# Sharpe: 0.187
# =================================
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# ---------------------------------------
# | time/                 |             |
# |    fps                | 224         |
# |    iterations         | 8700        |
# |    time_elapsed       | 193         |
# |    total_timesteps    | 43500       |
# | train/                |             |
# |    entropy_loss       | -15.1       |
# |    explained_variance | 0.22        |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 8699        |
# |    policy_loss        | 3.55        |
# |    reward             | -0.36452866 |
# |    reward_max         | 0.32349947  |
# |    reward_mean        | 0.025629314 |
# |    reward_min         | -0.36452866 |
# |    std                | 1.1         |
# |    value_loss         | 0.145       |
# ---------------------------------------
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# ---------------------------------------
# | time/                 |             |
# |    fps                | 224         |
# |    iterations         | 8800        |
# |    time_elapsed       | 195         |
# |    total_timesteps    | 44000       |
# | train/                |             |
# |    entropy_loss       | -15.1       |
# |    explained_variance | 0.331       |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 8799        |
# |    policy_loss        | 1.9         |
# |    reward             | -0.16396078 |
# |    reward_max         | 1.0359737   |
# |    reward_mean        | 0.25564405  |
# |    reward_min         | -0.16396078 |
# |    std                | 1.1         |
# |    value_loss         | 0.0221      |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 224         |
# |    iterations         | 8900        |
# |    time_elapsed       | 198         |
# |    total_timesteps    | 44500       |
# | train/                |             |
# |    entropy_loss       | -15.2       |
# |    explained_variance | -0.035      |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 8899        |
# |    policy_loss        | 0.484       |
# |    reward             | 0.19769889  |
# |    reward_max         | 0.7486941   |
# |    reward_mean        | 0.2263591   |
# |    reward_min         | 0.011473669 |
# |    std                | 1.11        |
# |    value_loss         | 0.423       |
# ---------------------------------------
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# ---------------------------------------
# | time/                 |             |
# |    fps                | 223         |
# |    iterations         | 9000        |
# |    time_elapsed       | 200         |
# |    total_timesteps    | 45000       |
# | train/                |             |
# |    entropy_loss       | -15.2       |
# |    explained_variance | 0.000386    |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 8999        |
# |    policy_loss        | 7.95        |
# |    reward             | 0.03967042  |
# |    reward_max         | 0.23409139  |
# |    reward_mean        | 0.041230567 |
# |    reward_min         | -0.16783527 |
# |    std                | 1.11        |
# |    value_loss         | 0.393       |
# ---------------------------------------
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# ----------------------------------------
# | time/                 |              |
# |    fps                | 223          |
# |    iterations         | 9100         |
# |    time_elapsed       | 203          |
# |    total_timesteps    | 45500        |
# | train/                |              |
# |    entropy_loss       | -15.2        |
# |    explained_variance | 0.195        |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 9099         |
# |    policy_loss        | -2.84        |
# |    reward             | -0.28640917  |
# |    reward_max         | 0.23023835   |
# |    reward_mean        | -0.007926216 |
# |    reward_min         | -0.28640917  |
# |    std                | 1.11         |
# |    value_loss         | 0.0494       |
# ----------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 224         |
# |    iterations         | 9200        |
# |    time_elapsed       | 205         |
# |    total_timesteps    | 46000       |
# | train/                |             |
# |    entropy_loss       | -15.3       |
# |    explained_variance | -0.00104    |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 9199        |
# |    policy_loss        | -7.69       |
# |    reward             | 0.8501464   |
# |    reward_max         | 0.8501464   |
# |    reward_mean        | 0.26618972  |
# |    reward_min         | -0.35372478 |
# |    std                | 1.12        |
# |    value_loss         | 0.334       |
# ---------------------------------------
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# ---------------------------------------
# | time/                 |             |
# |    fps                | 224         |
# |    iterations         | 9300        |
# |    time_elapsed       | 207         |
# |    total_timesteps    | 46500       |
# | train/                |             |
# |    entropy_loss       | -15.3       |
# |    explained_variance | 1.19e-07    |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 9299        |
# |    policy_loss        | -1.21       |
# |    reward             | -0.16678572 |
# |    reward_max         | 0.92783594  |
# |    reward_mean        | 0.17774518  |
# |    reward_min         | -0.20384362 |
# |    std                | 1.12        |
# |    value_loss         | 0.0359      |
# ---------------------------------------
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# ----------------------------------------
# | time/                 |              |
# |    fps                | 224          |
# |    iterations         | 9400         |
# |    time_elapsed       | 209          |
# |    total_timesteps    | 47000        |
# | train/                |              |
# |    entropy_loss       | -15.3        |
# |    explained_variance | -0.468       |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 9399         |
# |    policy_loss        | -8.14        |
# |    reward             | -0.037340634 |
# |    reward_max         | 0.4083668    |
# |    reward_mean        | 0.16380158   |
# |    reward_min         | -0.16511185  |
# |    std                | 1.12         |
# |    value_loss         | 0.553        |
# ----------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 224         |
# |    iterations         | 9500        |
# |    time_elapsed       | 211         |
# |    total_timesteps    | 47500       |
# | train/                |             |
# |    entropy_loss       | -15.3       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 9499        |
# |    policy_loss        | -1.05       |
# |    reward             | -0.28335387 |
# |    reward_max         | 0.84538394  |
# |    reward_mean        | -0.05547896 |
# |    reward_min         | -0.58703476 |
# |    std                | 1.13        |
# |    value_loss         | 0.0569      |
# ---------------------------------------
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# --------------------------------------
# | time/                 |            |
# |    fps                | 223        |
# |    iterations         | 9600       |
# |    time_elapsed       | 215        |
# |    total_timesteps    | 48000      |
# | train/                |            |
# |    entropy_loss       | -15.4      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 9599       |
# |    policy_loss        | 5.05       |
# |    reward             | 0.23016322 |
# |    reward_max         | 0.6381018  |
# |    reward_mean        | 0.12780623 |
# |    reward_min         | -0.5355717 |
# |    std                | 1.13       |
# |    value_loss         | 0.183      |
# --------------------------------------
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# ---------------------------------------
# | time/                 |             |
# |    fps                | 222         |
# |    iterations         | 9700        |
# |    time_elapsed       | 217         |
# |    total_timesteps    | 48500       |
# | train/                |             |
# |    entropy_loss       | -15.4       |
# |    explained_variance | 0.0188      |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 9699        |
# |    policy_loss        | -167        |
# |    reward             | 0.004206326 |
# |    reward_max         | 0.2726293   |
# |    reward_mean        | 0.11179604  |
# |    reward_min         | -0.08872541 |
# |    std                | 1.13        |
# |    value_loss         | 481         |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 223         |
# |    iterations         | 9800        |
# |    time_elapsed       | 219         |
# |    total_timesteps    | 49000       |
# | train/                |             |
# |    entropy_loss       | -15.4       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 9799        |
# |    policy_loss        | 0.698       |
# |    reward             | -1.0843222  |
# |    reward_max         | 0.12860079  |
# |    reward_mean        | -0.55784434 |
# |    reward_min         | -1.0843222  |
# |    std                | 1.14        |
# |    value_loss         | 0.114       |
# ---------------------------------------
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# ---------------------------------------
# | time/                 |             |
# |    fps                | 223         |
# |    iterations         | 9900        |
# |    time_elapsed       | 221         |
# |    total_timesteps    | 49500       |
# | train/                |             |
# |    entropy_loss       | -15.4       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 9899        |
# |    policy_loss        | 6.22        |
# |    reward             | -0.22296622 |
# |    reward_max         | 0.60757035  |
# |    reward_mean        | 0.2097674   |
# |    reward_min         | -0.22296622 |
# |    std                | 1.13        |
# |    value_loss         | 0.186       |
# ---------------------------------------
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# --------------------------------------
# | time/                 |            |
# |    fps                | 223        |
# |    iterations         | 10000      |
# |    time_elapsed       | 223        |
# |    total_timesteps    | 50000      |
# | train/                |            |
# |    entropy_loss       | -15.5      |
# |    explained_variance | 2.38e-07   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 9999       |
# |    policy_loss        | 47.4       |
# |    reward             | -20.135113 |
# |    reward_max         | 0.7863446  |
# |    reward_mean        | -9.133606  |
# |    reward_min         | -20.135113 |
# |    std                | 1.14       |
# |    value_loss         | 11         |
# --------------------------------------

# %% [markdown]
# ### Agent 2: DDPG

# %% [markdown]
# ### Agent 3: PPO

# %%
agent = DRLAgent(env = env_train)
PPO_PARAMS = {
    "n_steps": 2048,
    "ent_coef": 0.01,
    "learning_rate": 0.00025,
    "batch_size": 128,
}
model_ppo = agent.get_model("ppo",model_kwargs = PPO_PARAMS)

  # set up logger
tmp_path = RESULTS_DIR + '/ppo'
new_logger_ppo = configure(tmp_path, ["stdout", "csv", "tensorboard"])
  # Set new logger
model_ppo.set_logger(new_logger_ppo)
# Out:
# {'n_steps': 2048, 'ent_coef': 0.01, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to results/ppo

# %%
trained_ppo = agent.train_model(model=model_ppo,
                             tb_log_name='ppo',
                             total_timesteps=50000)
# Out:
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# day: 755, episode: 140
# begin_total_asset: 1000000.00
# end_total_asset: 196704.05
# total_reward: -803295.95
# total_cost: 51242.02
# total_trades: 6701
# Sharpe: -0.796
# =================================
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# -------------------------------------
# | time/              |              |
# |    fps             | 344          |
# |    iterations      | 1            |
# |    time_elapsed    | 5            |
# |    total_timesteps | 2048         |
# | train/             |              |
# |    reward          | -0.017617991 |
# |    reward_max      | 11.133389    |
# |    reward_mean     | -0.09066026  |
# |    reward_min      | -25.077055   |
# -------------------------------------
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 252         |
# |    iterations           | 2           |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.008952857 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -14.2       |
# |    explained_variance   | 0.0185      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 29          |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00935    |
# |    reward               | -0.83183444 |
# |    reward_max           | 7.2606483   |
# |    reward_mean          | -0.07123122 |
# |    reward_min           | -47.75908   |
# |    std                  | 1           |
# |    value_loss           | 38.4        |
# -----------------------------------------
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 245         |
# |    iterations           | 3           |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.007574577 |
# |    clip_fraction        | 0.0743      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -14.2       |
# |    explained_variance   | 0.0541      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 20.7        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0057     |
# |    reward               | 1.7658919   |
# |    reward_max           | 9.744812    |
# |    reward_mean          | -0.0485018  |
# |    reward_min           | -36.837997  |
# |    std                  | 1.01        |
# |    value_loss           | 30.4        |
# -----------------------------------------
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 254          |
# |    iterations           | 4            |
# |    time_elapsed         | 32           |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.008392396  |
# |    clip_fraction        | 0.0862       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -14.2        |
# |    explained_variance   | -0.0155      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 11           |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00619     |
# |    reward               | 1.3990601    |
# |    reward_max           | 10.056436    |
# |    reward_mean          | -0.048713654 |
# |    reward_min           | -37.717842   |
# |    std                  | 1.01         |
# |    value_loss           | 19.7         |
# ------------------------------------------
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# day: 755, episode: 150
# begin_total_asset: 1000000.00
# end_total_asset: 704438.96
# total_reward: -295561.04
# total_cost: 62302.53
# total_trades: 7147
# Sharpe: -0.143
# =================================
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 248         |
# |    iterations           | 5           |
# |    time_elapsed         | 41          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.007495628 |
# |    clip_fraction        | 0.0792      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -14.3       |
# |    explained_variance   | 0.00776     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 9.86        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00749    |
# |    reward               | 1.3071061   |
# |    reward_max           | 21.401539   |
# |    reward_mean          | -0.05505489 |
# |    reward_min           | -27.947111  |
# |    std                  | 1.01        |
# |    value_loss           | 27.8        |
# -----------------------------------------
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 253         |
# |    iterations           | 6           |
# |    time_elapsed         | 48          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.006928771 |
# |    clip_fraction        | 0.0813      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -14.3       |
# |    explained_variance   | 0.036       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 9.97        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00772    |
# |    reward               | -1.4116662  |
# |    reward_max           | 25.855803   |
# |    reward_mean          | -0.07491841 |
# |    reward_min           | -39.11239   |
# |    std                  | 1.02        |
# |    value_loss           | 25          |
# -----------------------------------------
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 249          |
# |    iterations           | 7            |
# |    time_elapsed         | 57           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.008392812  |
# |    clip_fraction        | 0.0903       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -14.4        |
# |    explained_variance   | 0.0233       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 5.37         |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00751     |
# |    reward               | -0.74684024  |
# |    reward_max           | 18.263178    |
# |    reward_mean          | -0.034744278 |
# |    reward_min           | -34.406662   |
# |    std                  | 1.02         |
# |    value_loss           | 34.5         |
# ------------------------------------------
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 250          |
# |    iterations           | 8            |
# |    time_elapsed         | 65           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.008183956  |
# |    clip_fraction        | 0.0779       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -14.4        |
# |    explained_variance   | -0.00352     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 11.1         |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00713     |
# |    reward               | -0.044909492 |
# |    reward_max           | 28.973164    |
# |    reward_mean          | -0.08746282  |
# |    reward_min           | -51.033176   |
# |    std                  | 1.02         |
# |    value_loss           | 23.5         |
# ------------------------------------------
# day: 755, episode: 160
# begin_total_asset: 1000000.00
# end_total_asset: 502294.20
# total_reward: -497705.80
# total_cost: 58768.09
# total_trades: 6950
# Sharpe: -0.326
# =================================
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 251          |
# |    iterations           | 9            |
# |    time_elapsed         | 73           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.009278198  |
# |    clip_fraction        | 0.0908       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -14.4        |
# |    explained_variance   | 0.0178       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 9.91         |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00882     |
# |    reward               | 1.1149628    |
# |    reward_max           | 8.4272375    |
# |    reward_mean          | -0.108772404 |
# |    reward_min           | -42.441956   |
# |    std                  | 1.02         |
# |    value_loss           | 57.9         |
# ------------------------------------------
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 249         |
# |    iterations           | 10          |
# |    time_elapsed         | 82          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.006996706 |
# |    clip_fraction        | 0.0808      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -14.4       |
# |    explained_variance   | 0.133       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 19.2        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00704    |
# |    reward               | 1.5989848   |
# |    reward_max           | 14.151515   |
# |    reward_mean          | -0.06294757 |
# |    reward_min           | -61.15806   |
# |    std                  | 1.02        |
# |    value_loss           | 49.4        |
# -----------------------------------------
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 253         |
# |    iterations           | 11          |
# |    time_elapsed         | 88          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.007909329 |
# |    clip_fraction        | 0.0691      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -14.4       |
# |    explained_variance   | 0.116       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 21.4        |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0068     |
# |    reward               | 0.29630554  |
# |    reward_max           | 44.139874   |
# |    reward_mean          | -0.07552251 |
# |    reward_min           | -42.700325  |
# |    std                  | 1.02        |
# |    value_loss           | 31.5        |
# -----------------------------------------
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# day: 755, episode: 170
# begin_total_asset: 1000000.00
# end_total_asset: 380743.29
# total_reward: -619256.71
# total_cost: 54846.16
# total_trades: 6919
# Sharpe: -0.486
# =================================
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 251         |
# |    iterations           | 12          |
# |    time_elapsed         | 97          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.012750616 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -14.4       |
# |    explained_variance   | 0.0256      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 41.6        |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00789    |
# |    reward               | -0.08725183 |
# |    reward_max           | 22.700462   |
# |    reward_mean          | -0.06344039 |
# |    reward_min           | -38.04338   |
# |    std                  | 1.03        |
# |    value_loss           | 44.1        |
# -----------------------------------------
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 253          |
# |    iterations           | 13           |
# |    time_elapsed         | 104          |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.009898525  |
# |    clip_fraction        | 0.114        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -14.5        |
# |    explained_variance   | 0.048        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 18           |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.0091      |
# |    reward               | 1.2824394    |
# |    reward_max           | 42.187744    |
# |    reward_mean          | -0.111880705 |
# |    reward_min           | -57.041916   |
# |    std                  | 1.03         |
# |    value_loss           | 34.1         |
# ------------------------------------------
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 253          |
# |    iterations           | 14           |
# |    time_elapsed         | 113          |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.008006992  |
# |    clip_fraction        | 0.0659       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -14.5        |
# |    explained_variance   | 0.0489       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 27.7         |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00861     |
# |    reward               | -0.050110947 |
# |    reward_max           | 24.982077    |
# |    reward_mean          | -0.0412745   |
# |    reward_min           | -41.540623   |
# |    std                  | 1.03         |
# |    value_loss           | 50.5         |
# ------------------------------------------
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 254         |
# |    iterations           | 15          |
# |    time_elapsed         | 120         |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.008799864 |
# |    clip_fraction        | 0.0926      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -14.5       |
# |    explained_variance   | 0.0187      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 5.58        |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00666    |
# |    reward               | -1.9721079  |
# |    reward_max           | 14.632912   |
# |    reward_mean          | -0.0712001  |
# |    reward_min           | -45.215557  |
# |    std                  | 1.03        |
# |    value_loss           | 21.8        |
# -----------------------------------------
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# day: 755, episode: 180
# begin_total_asset: 1000000.00
# end_total_asset: 661334.95
# total_reward: -338665.05
# total_cost: 58694.71
# total_trades: 6849
# Sharpe: -0.115
# =================================
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 254          |
# |    iterations           | 16           |
# |    time_elapsed         | 128          |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.010870991  |
# |    clip_fraction        | 0.118        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -14.5        |
# |    explained_variance   | 0.0464       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 31.5         |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.0111      |
# |    reward               | 0.36796242   |
# |    reward_max           | 15.91198     |
# |    reward_mean          | -0.047675695 |
# |    reward_min           | -48.12857    |
# |    std                  | 1.04         |
# |    value_loss           | 44.9         |
# ------------------------------------------
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 253          |
# |    iterations           | 17           |
# |    time_elapsed         | 137          |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.009599178  |
# |    clip_fraction        | 0.0954       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -14.6        |
# |    explained_variance   | 0.0508       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 18.7         |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00507     |
# |    reward               | 1.5183047    |
# |    reward_max           | 39.426132    |
# |    reward_mean          | -0.060058948 |
# |    reward_min           | -50.090195   |
# |    std                  | 1.04         |
# |    value_loss           | 27.4         |
# ------------------------------------------
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 254         |
# |    iterations           | 18          |
# |    time_elapsed         | 145         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.011650842 |
# |    clip_fraction        | 0.109       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -14.6       |
# |    explained_variance   | 0.0411      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 12.5        |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00996    |
# |    reward               | -1.1312126  |
# |    reward_max           | 19.395288   |
# |    reward_mean          | -0.06638936 |
# |    reward_min           | -43.59436   |
# |    std                  | 1.04        |
# |    value_loss           | 32.2        |
# -----------------------------------------
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 253          |
# |    iterations           | 19           |
# |    time_elapsed         | 153          |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.009158851  |
# |    clip_fraction        | 0.11         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -14.6        |
# |    explained_variance   | 0.0509       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 22.5         |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.0095      |
# |    reward               | 0.06474706   |
# |    reward_max           | 12.935092    |
# |    reward_mean          | -0.050029397 |
# |    reward_min           | -37.637897   |
# |    std                  | 1.04         |
# |    value_loss           | 36.8         |
# ------------------------------------------
# day: 755, episode: 190
# begin_total_asset: 1000000.00
# end_total_asset: 424588.57
# total_reward: -575411.43
# total_cost: 52485.65
# total_trades: 6808
# Sharpe: -0.506
# =================================
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 254          |
# |    iterations           | 20           |
# |    time_elapsed         | 160          |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.012350829  |
# |    clip_fraction        | 0.132        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -14.6        |
# |    explained_variance   | 0.00992      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 11.2         |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00669     |
# |    reward               | -0.14259046  |
# |    reward_max           | 22.236534    |
# |    reward_mean          | -0.085899025 |
# |    reward_min           | -48.875343   |
# |    std                  | 1.05         |
# |    value_loss           | 29.4         |
# ------------------------------------------
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 253         |
# |    iterations           | 21          |
# |    time_elapsed         | 169         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.012216192 |
# |    clip_fraction        | 0.118       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -14.6       |
# |    explained_variance   | 0.0897      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 17.3        |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0116     |
# |    reward               | 0.25379333  |
# |    reward_max           | 23.463915   |
# |    reward_mean          | -0.0361744  |
# |    reward_min           | -35.107975  |
# |    std                  | 1.05        |
# |    value_loss           | 36.7        |
# -----------------------------------------
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 255          |
# |    iterations           | 22           |
# |    time_elapsed         | 176          |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.011470038  |
# |    clip_fraction        | 0.125        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -14.7        |
# |    explained_variance   | 0.144        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 19.1         |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.0082      |
# |    reward               | 0.6885961    |
# |    reward_max           | 21.813004    |
# |    reward_mean          | -0.023325277 |
# |    reward_min           | -31.383163   |
# |    std                  | 1.05         |
# |    value_loss           | 23.2         |
# ------------------------------------------
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# day: 755, episode: 200
# begin_total_asset: 1000000.00
# end_total_asset: 1125697.19
# total_reward: 125697.19
# total_cost: 56746.37
# total_trades: 6954
# Sharpe: 0.283
# =================================
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 255         |
# |    iterations           | 23          |
# |    time_elapsed         | 184         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.010845624 |
# |    clip_fraction        | 0.12        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -14.7       |
# |    explained_variance   | -0.0235     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 5.47        |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0105     |
# |    reward               | 0.9219179   |
# |    reward_max           | 33.427948   |
# |    reward_mean          | -0.03303116 |
# |    reward_min           | -61.977737  |
# |    std                  | 1.05        |
# |    value_loss           | 15.6        |
# -----------------------------------------
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 255         |
# |    iterations           | 24          |
# |    time_elapsed         | 192         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.009679472 |
# |    clip_fraction        | 0.0895      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -14.7       |
# |    explained_variance   | 0.0205      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 9.63        |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0108     |
# |    reward               | -0.09019713 |
# |    reward_max           | 43.249954   |
# |    reward_mean          | -0.03761684 |
# |    reward_min           | -61.515812  |
# |    std                  | 1.05        |
# |    value_loss           | 25.5        |
# -----------------------------------------
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 256          |
# |    iterations           | 25           |
# |    time_elapsed         | 199          |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.009228985  |
# |    clip_fraction        | 0.0872       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -14.7        |
# |    explained_variance   | 0.0855       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 5.77         |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00978     |
# |    reward               | -2.3709235   |
# |    reward_max           | 26.02955     |
# |    reward_mean          | -0.062147398 |
# |    reward_min           | -64.288506   |
# |    std                  | 1.05         |
# |    value_loss           | 25.4         |
# ------------------------------------------

# %% [markdown]
# ### Agent 4: TD3

# %%
agent = DRLAgent(env = env_train)
TD3_PARAMS = {"batch_size": 100,
              "buffer_size": 1000000,
              "learning_rate": 0.001}

model_td3 = agent.get_model("td3",model_kwargs = TD3_PARAMS)

  # set up logger
tmp_path = RESULTS_DIR + '/td3'
new_logger_td3 = configure(tmp_path, ["stdout", "csv", "tensorboard"])
  # Set new logger
model_td3.set_logger(new_logger_td3)
# Out:
# {'batch_size': 100, 'buffer_size': 1000000, 'learning_rate': 0.001}
# Using cpu device
# Logging to results/td3

# %%
trained_td3 = agent.train_model(model=model_td3,
                             tb_log_name='td3',
                             total_timesteps=50000)
# Out:
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# Logging Error: 'rollout_buffer'
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# Logging Error: 'rollout_buffer'
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# Logging Error: 'rollout_buffer'
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# ----------------------------------
# | time/              |           |
# |    episodes        | 4         |
# |    fps             | 48        |
# |    time_elapsed    | 62        |
# |    total_timesteps | 3024      |
# | train/             |           |
# |    actor_loss      | 66.7      |
# |    critic_loss     | 2.24e+04  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 2268      |
# |    reward          | 0.0413073 |
# |    reward_max      | None      |
# |    reward_mean     | None      |
# |    reward_min      | None      |
# ----------------------------------
# Logging Error: 'rollout_buffer'
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# Logging Error: 'rollout_buffer'
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# Logging Error: 'rollout_buffer'
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# Logging Error: 'rollout_buffer'
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# ----------------------------------
# | time/              |           |
# |    episodes        | 8         |
# |    fps             | 40        |
# |    time_elapsed    | 148       |
# |    total_timesteps | 6048      |
# | train/             |           |
# |    actor_loss      | 56.5      |
# |    critic_loss     | 4.65e+03  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 5292      |
# |    reward          | 0.0413073 |
# |    reward_max      | None      |
# |    reward_mean     | None      |
# |    reward_min      | None      |
# ----------------------------------
# Logging Error: 'rollout_buffer'
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# Logging Error: 'rollout_buffer'
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# day: 755, episode: 80
# begin_total_asset: 1000000.00
# end_total_asset: 188308.76
# total_reward: -811691.24
# total_cost: 1214.32
# total_trades: 6806
# Sharpe: 0.016
# =================================
# Logging Error: 'rollout_buffer'
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# Logging Error: 'rollout_buffer'
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# ----------------------------------
# | time/              |           |
# |    episodes        | 12        |
# |    fps             | 38        |
# |    time_elapsed    | 236       |
# |    total_timesteps | 9072      |
# | train/             |           |
# |    actor_loss      | 45.5      |
# |    critic_loss     | 2.16e+03  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 8316      |
# |    reward          | 0.0413073 |
# |    reward_max      | None      |
# |    reward_mean     | None      |
# |    reward_min      | None      |
# ----------------------------------
# Logging Error: 'rollout_buffer'
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# Logging Error: 'rollout_buffer'
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# Logging Error: 'rollout_buffer'
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# Logging Error: 'rollout_buffer'
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# ----------------------------------
# | time/              |           |
# |    episodes        | 16        |
# |    fps             | 37        |
# |    time_elapsed    | 325       |
# |    total_timesteps | 12096     |
# | train/             |           |
# |    actor_loss      | 34.7      |
# |    critic_loss     | 1.03e+03  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 11340     |
# |    reward          | 0.0413073 |
# |    reward_max      | None      |
# |    reward_mean     | None      |
# |    reward_min      | None      |
# ----------------------------------
# Logging Error: 'rollout_buffer'
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# Logging Error: 'rollout_buffer'
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# Logging Error: 'rollout_buffer'
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# Logging Error: 'rollout_buffer'
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# day: 755, episode: 90
# begin_total_asset: 1000000.00
# end_total_asset: 188308.76
# total_reward: -811691.24
# total_cost: 1214.32
# total_trades: 6806
# Sharpe: 0.016
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 20        |
# |    fps             | 36        |
# |    time_elapsed    | 412       |
# |    total_timesteps | 15120     |
# | train/             |           |
# |    actor_loss      | 36        |
# |    critic_loss     | 331       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 14364     |
# |    reward          | 0.0413073 |
# |    reward_max      | None      |
# |    reward_mean     | None      |
# |    reward_min      | None      |
# ----------------------------------
# Logging Error: 'rollout_buffer'
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# Logging Error: 'rollout_buffer'
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# Logging Error: 'rollout_buffer'
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# Logging Error: 'rollout_buffer'
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# ----------------------------------
# | time/              |           |
# |    episodes        | 24        |
# |    fps             | 36        |
# |    time_elapsed    | 501       |
# |    total_timesteps | 18144     |
# | train/             |           |
# |    actor_loss      | 34.6      |
# |    critic_loss     | 366       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 17388     |
# |    reward          | 0.0413073 |
# |    reward_max      | None      |
# |    reward_mean     | None      |
# |    reward_min      | None      |
# ----------------------------------
# Logging Error: 'rollout_buffer'
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# Logging Error: 'rollout_buffer'
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# Logging Error: 'rollout_buffer'
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# Logging Error: 'rollout_buffer'
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# ----------------------------------
# | time/              |           |
# |    episodes        | 28        |
# |    fps             | 35        |
# |    time_elapsed    | 589       |
# |    total_timesteps | 21168     |
# | train/             |           |
# |    actor_loss      | 32.4      |
# |    critic_loss     | 76.8      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 20412     |
# |    reward          | 0.0413073 |
# |    reward_max      | None      |
# |    reward_mean     | None      |
# |    reward_min      | None      |
# ----------------------------------
# Logging Error: 'rollout_buffer'
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# Logging Error: 'rollout_buffer'
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# day: 755, episode: 100
# begin_total_asset: 1000000.00
# end_total_asset: 188308.76
# total_reward: -811691.24
# total_cost: 1214.32
# total_trades: 6806
# Sharpe: 0.016
# =================================
# Logging Error: 'rollout_buffer'
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# Logging Error: 'rollout_buffer'
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# ----------------------------------
# | time/              |           |
# |    episodes        | 32        |
# |    fps             | 35        |
# |    time_elapsed    | 677       |
# |    total_timesteps | 24192     |
# | train/             |           |
# |    actor_loss      | 30.7      |
# |    critic_loss     | 44        |
# |    learning_rate   | 0.001     |
# |    n_updates       | 23436     |
# |    reward          | 0.0413073 |
# |    reward_max      | None      |
# |    reward_mean     | None      |
# |    reward_min      | None      |
# ----------------------------------
# Logging Error: 'rollout_buffer'
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# Logging Error: 'rollout_buffer'
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# Logging Error: 'rollout_buffer'
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# Logging Error: 'rollout_buffer'
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# ----------------------------------
# | time/              |           |
# |    episodes        | 36        |
# |    fps             | 35        |
# |    time_elapsed    | 765       |
# |    total_timesteps | 27216     |
# | train/             |           |
# |    actor_loss      | 29.2      |
# |    critic_loss     | 15.9      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 26460     |
# |    reward          | 0.0413073 |
# |    reward_max      | None      |
# |    reward_mean     | None      |
# |    reward_min      | None      |
# ----------------------------------
# Logging Error: 'rollout_buffer'
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# Logging Error: 'rollout_buffer'
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# Logging Error: 'rollout_buffer'
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# Logging Error: 'rollout_buffer'
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# day: 755, episode: 110
# begin_total_asset: 1000000.00
# end_total_asset: 188308.76
# total_reward: -811691.24
# total_cost: 1214.32
# total_trades: 6806
# Sharpe: 0.016
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 40        |
# |    fps             | 35        |
# |    time_elapsed    | 854       |
# |    total_timesteps | 30240     |
# | train/             |           |
# |    actor_loss      | 30.2      |
# |    critic_loss     | 35.9      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 29484     |
# |    reward          | 0.0413073 |
# |    reward_max      | None      |
# |    reward_mean     | None      |
# |    reward_min      | None      |
# ----------------------------------
# Logging Error: 'rollout_buffer'
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# Logging Error: 'rollout_buffer'
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# Logging Error: 'rollout_buffer'
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# Logging Error: 'rollout_buffer'
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# ----------------------------------
# | time/              |           |
# |    episodes        | 44        |
# |    fps             | 35        |
# |    time_elapsed    | 942       |
# |    total_timesteps | 33264     |
# | train/             |           |
# |    actor_loss      | 28.3      |
# |    critic_loss     | 11        |
# |    learning_rate   | 0.001     |
# |    n_updates       | 32508     |
# |    reward          | 0.0413073 |
# |    reward_max      | None      |
# |    reward_mean     | None      |
# |    reward_min      | None      |
# ----------------------------------
# Logging Error: 'rollout_buffer'
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# Logging Error: 'rollout_buffer'
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# Logging Error: 'rollout_buffer'
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# Logging Error: 'rollout_buffer'
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# ----------------------------------
# | time/              |           |
# |    episodes        | 48        |
# |    fps             | 35        |
# |    time_elapsed    | 1030      |
# |    total_timesteps | 36288     |
# | train/             |           |
# |    actor_loss      | 29.6      |
# |    critic_loss     | 13.2      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 35532     |
# |    reward          | 0.0413073 |
# |    reward_max      | None      |
# |    reward_mean     | None      |
# |    reward_min      | None      |
# ----------------------------------
# Logging Error: 'rollout_buffer'
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# Logging Error: 'rollout_buffer'
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# day: 755, episode: 120
# begin_total_asset: 1000000.00
# end_total_asset: 188308.76
# total_reward: -811691.24
# total_cost: 1214.32
# total_trades: 6806
# Sharpe: 0.016
# =================================
# Logging Error: 'rollout_buffer'
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# Logging Error: 'rollout_buffer'
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# ----------------------------------
# | time/              |           |
# |    episodes        | 52        |
# |    fps             | 35        |
# |    time_elapsed    | 1121      |
# |    total_timesteps | 39312     |
# | train/             |           |
# |    actor_loss      | 28.7      |
# |    critic_loss     | 8.28      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 38556     |
# |    reward          | 0.0413073 |
# |    reward_max      | None      |
# |    reward_mean     | None      |
# |    reward_min      | None      |
# ----------------------------------
# Logging Error: 'rollout_buffer'
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# Logging Error: 'rollout_buffer'
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# Logging Error: 'rollout_buffer'
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# Logging Error: 'rollout_buffer'
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# ----------------------------------
# | time/              |           |
# |    episodes        | 56        |
# |    fps             | 34        |
# |    time_elapsed    | 1211      |
# |    total_timesteps | 42336     |
# | train/             |           |
# |    actor_loss      | 27.4      |
# |    critic_loss     | 5.72      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 41580     |
# |    reward          | 0.0413073 |
# |    reward_max      | None      |
# |    reward_mean     | None      |
# |    reward_min      | None      |
# ----------------------------------
# Logging Error: 'rollout_buffer'
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# Logging Error: 'rollout_buffer'
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# Logging Error: 'rollout_buffer'
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# Logging Error: 'rollout_buffer'
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# day: 755, episode: 130
# begin_total_asset: 1000000.00
# end_total_asset: 188308.76
# total_reward: -811691.24
# total_cost: 1214.32
# total_trades: 6806
# Sharpe: 0.016
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 60        |
# |    fps             | 34        |
# |    time_elapsed    | 1301      |
# |    total_timesteps | 45360     |
# | train/             |           |
# |    actor_loss      | 26.3      |
# |    critic_loss     | 4.46      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 44604     |
# |    reward          | 0.0413073 |
# |    reward_max      | None      |
# |    reward_mean     | None      |
# |    reward_min      | None      |
# ----------------------------------
# Logging Error: 'rollout_buffer'
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# Logging Error: 'rollout_buffer'
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# Logging Error: 'rollout_buffer'
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# Logging Error: 'rollout_buffer'
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# ----------------------------------
# | time/              |           |
# |    episodes        | 64        |
# |    fps             | 34        |
# |    time_elapsed    | 1392      |
# |    total_timesteps | 48384     |
# | train/             |           |
# |    actor_loss      | 25.2      |
# |    critic_loss     | 2.72      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 47628     |
# |    reward          | 0.0413073 |
# |    reward_max      | None      |
# |    reward_mean     | None      |
# |    reward_min      | None      |
# ----------------------------------
# Logging Error: 'rollout_buffer'
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# Logging Error: 'rollout_buffer'
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# Logging Error: 'rollout_buffer'
# Auto-fixing bad obs shape 155 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 143 → 131
# Auto-fixing bad obs shape 191 → 131
# Auto-fixing bad obs shape 179 → 131
# Auto-fixing bad obs shape 359 → 131
# Auto-fixing bad obs shape 419 → 131
# Logging Error: 'rollout_buffer'

# %% [markdown]
# ## In-sample Performance
#
# Assume that the initial capital is $1,000,000.

# %% [markdown]
# ### Set turbulence threshold
# Set the turbulence threshold to be greater than the maximum of insample turbulence data. If current turbulence index is greater than the threshold, then we assume that the current market is volatile

# %%
data_risk_indicator = processed_full[(processed_full.date<TRAIN_END_DATE) & (processed_full.date>=TRAIN_START_DATE)]
insample_risk_indicator = data_risk_indicator.drop_duplicates(subset=['date'])

# %%
insample_risk_indicator.vix.describe()
# Out:
# count    756.000000
# mean      24.848664
# std        8.759434
# min       12.100000
# 25%       19.367501
# 50%       23.134999
# 75%       27.990000
# max       82.690002
# Name: vix, dtype: float64

# %%
insample_risk_indicator.vix.quantile(0.996)
# Out:
# 75.40060119628913

# %%
insample_risk_indicator.turbulence.describe()
# Out:
# count    756.000000
# mean       7.637635
# std       16.377618
# min        0.000000
# 25%        0.000000
# 50%        4.191949
# 75%        9.348000
# max      293.467524
# Name: turbulence, dtype: float64

# %%
insample_risk_indicator.turbulence.quantile(0.996)
# Out:
# 102.95672241439526

# %% [markdown]
# ### Trading (Out-of-sample Performance)
#
# We update periodically in order to take full advantage of the data, e.g., retrain quarterly, monthly or weekly. We also tune the parameters along the way, in this notebook we use the in-sample data from 2009-01 to 2020-07 to tune the parameters once, so there is some alpha decay here as the length of trade date extends.
#
# Numerous hyperparameters – e.g. the learning rate, the total number of samples to train on – influence the learning process and are usually determined by testing some variations.

# %%
e_trade_gym = StockTradingEnv(df = trade, turbulence_threshold = 70,risk_indicator_col='vix', **env_kwargs)

# %%
trade.head()
# Out:
#          date    tic        open        high         low       close  \
# 0  2023-01-03   AAPL  128.613985  129.226052  122.582119  123.470612
# 0  2023-01-03   AMZN   85.459999   86.959999   84.209999   85.820000
# 0  2023-01-03     BA  192.949997  197.179993  192.399994  195.389999
# 0  2023-01-03    DIS   87.520969   88.494734   86.389825   87.511131
# 0  2023-01-03  GOOGL   89.055891   90.507194   87.992270   88.588699
#
#         volume  day      macd     boll_ub     boll_lb     rsi_30      cci_30  \
# 0  112117500.0  1.0 -4.648598  147.860259  121.091850  39.011477 -130.963663
# 0   76706000.0  1.0 -3.075118   93.357149   80.929850  41.195599  -71.360174
# 0    8624600.0  1.0  5.326285  196.702727  176.154272  62.905353  141.206999
# 0   14997100.0  1.0 -2.395932   95.452683   81.433499  44.489017  -57.420619
# 0   28131200.0  1.0 -2.129973   98.089503   83.452727  43.976950  -67.730895
#
#        dx_30  close_30_sma  close_60_sma  sentiment_score   vix  turbulence
# 0  35.956413    138.293931    140.567288        -0.467607  22.9   29.954523
# 0  10.198927     89.424999     97.181000         0.000000  22.9   29.954523
# 0  44.456630    182.859667    166.269167         0.000000  22.9   29.954523
# 0   3.756663     90.752426     93.693725        -0.333333  22.9   29.954523
# 0   2.932446     92.974732     93.988817         0.000000  22.9   29.954523

# %%
trained_moedl = trained_a2c
df_account_value_a2c, df_actions_a2c = DRLAgent.DRL_prediction(
    model=trained_moedl,
    environment = e_trade_gym)
# Out:
# hit end!

# %%
trained_moedl = trained_ppo
df_account_value_ppo, df_actions_ppo = DRLAgent.DRL_prediction(
    model=trained_moedl,
    environment = e_trade_gym)
# Out:
# hit end!

# %%
trained_moedl = trained_td3
df_account_value_td3, df_actions_td3 = DRLAgent.DRL_prediction(
    model=trained_moedl,
    environment = e_trade_gym)
# Out:
# hit end!

# %%
df_account_value_a2c.shape
# Out:
# (249, 2)

# %% [markdown]
# <a id='6'></a>
# # Part 7: Backtesting Results
# Backtesting plays a key role in evaluating the performance of a trading strategy. Automated backtesting tool is preferred because it reduces the human error. We usually use the Quantopian pyfolio package to backtest our trading strategies. It is easy to use and consists of various individual plots that provide a comprehensive image of the performance of a trading strategy.

# %%
df_result_a2c = df_account_value_a2c.set_index(df_account_value_a2c.columns[0])
df_result_ppo = df_account_value_ppo.set_index(df_account_value_ppo.columns[0])
df_result_td3 = df_account_value_td3.set_index(df_account_value_td3.columns[0])

result = pd.merge(df_result_a2c, df_result_ppo, left_index=True, right_index=True, suffixes=('_a2c', '_ppo'))
result = pd.merge(result, df_result_td3, left_index=True, right_index=True,suffixes=('', '_td3'))


df_account_value_a2c.to_csv("df_account_value_a2c.csv")
#baseline stats
print("==============Get Baseline Stats===========")
df_dji_ = get_baseline(
        ticker="^DJI",
        start = TRADE_START_DATE,
        end = TRADE_END_DATE)
stats = backtest_stats(df_dji_, value_col_name = 'close')
df_dji = pd.DataFrame()
df_dji['date'] = df_account_value_a2c['date']
df_dji['account_value'] = df_dji_['close'] / df_dji_['close'][0] * env_kwargs["initial_amount"]
df_dji.to_csv("df_dji.csv")
df_dji = df_dji.set_index(df_dji.columns[0])
df_dji.to_csv("df_dji+.csv")
result = pd.merge(result, df_dji, left_index=True, right_index=True, suffixes=('', '_dji'))
result.columns = ['a2c','ppo', 'tdr','dji']
print("result: ", result)
result.to_csv("result.csv")
# Out:
# ==============Get Baseline Stats===========
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (250, 8)
# Annual return          0.138579
# Cumulative returns     0.137407
# Annual volatility      0.114284
# Sharpe ratio           1.197347
# Calmar ratio           1.536735
# Stability              0.375744
# Max drawdown          -0.090178
# Omega ratio            1.213376
# Sortino ratio          1.790631
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             1.100346
# Daily value at risk   -0.013855
# dtype: float64
# result:                       a2c           ppo           tdr           dji
# date
# 2023-01-03  1.000000e+06  1.000000e+06  1.000000e+06  1.000000e+06
# 2023-01-04  1.000697e+06  1.000064e+06  1.000103e+06  1.004026e+06
# 2023-01-05  9.991220e+05  9.999831e+05  9.967701e+05  9.937744e+05
# 2023-01-06  1.002722e+06  1.000555e+06  1.003270e+06  1.014915e+06
# 2023-01-09  1.006152e+06  1.000551e+06  1.007912e+06  1.011506e+06
# ...                  ...           ...           ...           ...
# 2023-12-21  1.668589e+06  1.240925e+06  1.727062e+06  1.128800e+06
# 2023-12-22  1.664104e+06  1.237161e+06  1.723938e+06  1.128246e+06
# 2023-12-26  1.672749e+06  1.239478e+06  1.730387e+06  1.133055e+06
# 2023-12-27  1.681127e+06  1.243565e+06  1.737066e+06  1.136410e+06
# 2023-12-28  1.685723e+06  1.248227e+06  1.731764e+06  1.138028e+06
#
# [249 rows x 4 columns]

# %%
# %matplotlib inline
plt.rcParams["figure.figsize"] = (15,5)
plt.figure();
result.plot(title="Backtest Results: A2C vs PPO vs TD3");
